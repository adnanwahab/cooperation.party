# %%
geoCoordCache
from collections import defaultdict

# %%
[get_lat_long(apt) for apt in apt_list]
# Out:
# [['139.82608000000002:35.71707'],
#  ['139.76917:35.738440000000004'],
#  ['139.79731:35.74475'],
#  ['139.72165:35.651109999999996'],
#  ['139.85166999999998:35.7385'],
#  ['139.74147:35.70263'],
#  ['139.69987:35.62198'],
#  ['139.70151:35.72415'],
#  ['139.70343:35.7241'],
#  ['139.85023999999999:35.736259999999994'],
#  ['139.704:35.698570000000004'],
#  ['139.70432:35.698479999999996'],
#  ['139.70433:35.69847'],
#  ['139.70433:35.698479999999996'],
#  ['139.61021000000002:35.65918'],
#  ['139.60846999999998:35.65933'],
#  ['139.70727:35.6944'],
#  ['139.72313:35.617940000000004'],
#  ['139.72722:35.658190000000005'],
#  ['139.65974:35.67273'],
#  ['139.65974:35.67273'],
#  ['139.68367:35.67191'],
#  ['139.70433:35.69847'],
#  ['139.70433:35.698479999999996'],
#  ['139.70435:35.698479999999996'],
#  ['139.70433:35.698479999999996'],
#  ['139.37936000000002:35.705690000000004'],
#  ['139.76445:35.72035'],
#  ['139.79121:35.79273'],
#  ['139.78049:35.72208'],
#  ['139.79205:35.79137'],
#  ['139.79263:35.79302'],
#  ['139.69196000000002:35.72097'],
#  ['139.63308999999998:35.78156'],
#  ['139.8515:35.738620000000004'],
#  ['139.63145:35.78116'],
#  ['139.6679:35.61728'],
#  ['139.70058:35.69746'],
#  ['139.78201:35.72672'],
#  ['139.48023:35.58911'],
#  ['139.73408:35.72784'],
#  ['139.65976:35.67276'],
#  ['139.85985:35.68358'],
#  ['139.67877:35.67205'],
#  ['139.716:35.76105'],
#  ['139.63076999999998:35.62942'],
#  ['139.70432:35.69847'],
#  ['139.70432:35.698479999999996'],
#  ['139.60045:35.70293'],
#  ['139.69009:35.68245'],
#  ['139.6551:35.706790000000005'],
#  ['139.65543:35.70686'],
#  ['139.59775:35.703990000000005'],
#  ['139.72204:35.64991'],
#  ['139.44681:35.765390000000004'],
#  ['139.78368:35.68577'],
#  ['139.67913000000001:35.678129999999996'],
#  ['139.73415:35.60033'],
#  ['139.7235:35.626329999999996'],
#  ['139.79878:35.71433'],
#  ['139.63328:35.73417'],
#  ['139.81931:35.6806'],
#  ['139.71652:35.760940000000005'],
#  ['139.48074:35.70919'],
#  ['139.59775:35.703990000000005'],
#  ['139.59775:35.703990000000005'],
#  ['139.75222:35.74576'],
#  ['139.71576000000002:35.761109999999995'],
#  ['139.39428:35.68587'],
#  ['139.53689:35.68002'],
#  ['139.63305:35.734140000000004'],
#  ['139.53855:35.6818'],
#  ['139.47982:35.75851'],
#  ['139.39461:35.68441'],
#  ['139.68657:35.73055'],
#  ['139.79048:35.72804'],
#  ['139.68059:35.677479999999996'],
#  ['139.67914:35.6929'],
#  ['139.76273:35.722390000000004'],
#  ['139.2863:35.63738'],
#  ['139.71597:35.76117'],
#  ['139.85163:35.73796'],
#  ['139.85173999999998:35.73816'],
#  ['139.67571:35.67923'],
#  ['139.79137:35.72951'],
#  ['139.6753:35.680679999999995'],
#  ['139.47711999999999:35.70009'],
#  ['139.84801000000002:35.734609999999996'],
#  ['139.68352:35.69185'],
#  ['139.74446:35.657090000000004'],
#  ['139.70609:35.701240000000006'],
#  ['139.74165:35.70608'],
#  ['139.74156000000002:35.705940000000005'],
#  ['139.78472:35.717690000000005'],
#  ['139.68331:35.69027'],
#  ['139.78471000000002:35.71894'],
#  ['139.78443000000001:35.71821'],
#  ['139.68374:35.69188'],
#  ['139.70703999999998:35.7042'],
#  ['139.8165:35.71162'],
#  ['139.81248:35.71197'],
#  ['139.81646:35.71158'],
#  ['139.48091000000002:35.71029'],
#  ['139.64664:35.707840000000004'],
#  ['139.75614:35.73677'],
#  ['139.8661:35.76838'],
#  ['139.78121000000002:35.696290000000005'],
#  ['139.74013:35.64054'],
#  ['139.7407:35.61412'],
#  ['139.70592:35.73214'],
#  ['139.79681000000002:35.69437']]

# %%
h3_cells

h3.h3_to_geo('873776054ffffff')
# Out:
# (40.17986113938729, -144.28698541105948)

# %%
import requests

geoCoordCache = {}

# %%
import concurrent.futures
import time 

_ = 'find 3-5 houses for 10 people and each house is close to the residents favorite preferences (two people like yoga, two people like kick boxing,  two people like rock climbing,  all of them like wind-surfing and they all dislike bars but half like libraries and the other half prefer bookstores and some prefer high rates of appreciation while others prefer to rent and some like disco and the others prefer country) - '
import h3
from compiled_functions import getAirbnbs
import re
documentContext = {}
#poi to OSM for now 
#how much would it cost to -> clone database of GM vs api requests 
#neighborhood characteristics -> family friendly, hipsterish, proximity to water, land usage, 
#80% of relevant data is the sorrounding neighborhood + commute to friends + 
#make it possible to paste "also please be 30 min drive from <address>""
# GPT_query = 'convert this sentence to a json of preferences'
preferences = {
'Yoga': [0.5, 1.5, 0.2, 1.0, 0.8, 0.3],  
'Kickboxing': [0.3, 0.7, 1.5, 2.0, 1.2, 1.8],
'RockClimbing': [1.2, 0.8, 0.4, 1.5, 0.6, 2.0],
'WindSurfing': [0.4, 0.3, 0.2, 0.8, 0.7, 1.0],
'Bars': [2.5, 3.0, 1.5, 2.2, 3.5, 3.8],
'Libraries': [0.5, 1.0, 1.2, 0.8, 1.5, 1.0],
'Bookstores': [1.0, 0.5, 0.7, 1.2, 0.4, 0.6],
'AppreciationRate': [5, 7, 4, 6, 8, 5],  
'Rent': [1000, 1100, 1050, 1150, 1200, 1250],
'Disco': [1.5, 2.0, 0.8, 0.6, 1.2, 1.0],
'Country': [0.8, 0.5, 1.0, 1.2, 0.9, 0.6]
}
preferences = {
'Yoga': [0.5, 1.5, 0.2, 1.0, 0.8, 0.3],  
'Kickboxing': [0.3, 0.7, 1.5, 2.0, 1.2, 1.8],
'RockClimbing': [1.2, 0.8, 0.4, 1.5, 0.6, 2.0],
'WindSurfing': [0.4, 0.3, 0.2, 0.8, 0.7, 1.0],
'Bars': [2.5, 3.0, 1.5, 2.2, 3.5, 3.8],
'Libraries': [0.5, 1.0, 1.2, 0.8, 1.5, 1.0],
'Bookstores': [1.0, 0.5, 0.7, 1.2, 0.4, 0.6],
'AppreciationRate': [5, 7, 4, 6, 8, 5],  
'Rent': [1000, 1100, 1050, 1150, 1200, 1250],
'Disco': [1.5, 2.0, 0.8, 0.6, 1.2, 1.0],
'Country': [0.8, 0.5, 1.0, 1.2, 0.9, 0.6]
}
preference_poi = ['restaurant', 'library', 'atm', 'vending_machine', 'bench', 'parking_space', 'bank', 'clinic', 'place_of_worship', 'research_institute']
preferences = {}
import random
for poi in preference_poi:
    preferences[poi] = [random.random() for _ in range(10)]
#10 people - 10 houses 
#10 houses 
#leave notebook on other url so anyone can add to it -> has to approved 
#main use case -> type a document or a bunch of random shit -> computer generates a workflow, app, tool or solves ur problem as long as its information only or remote code exeuctionable which seems to be 100% of problems from alan kay's thing sometimes between now and 2027
people_names = 'fred bob sally panda velma gis mercator machester last day'.split(' ')
import json
def get_room_id(url):
    match = re.search(r'rooms/(\d+)', url)
    if match: return match.group(1)
    else: return None

def get_lat_long(apt):
    _ = get_room_id(apt)
    val = json.load(open(f'data/airbnb/geocoordinates/{_}_geocoordinates.json'))
    val = val[0].split(':')
    val = [float(val[1]), float(val[0])]
    return val
#h3_coords = {}
h3_cells = {}
#hex_id => {poi_key: 123 }
import copy
def filter_by_poi(_, documentContext, sentence):
    poi = sentence.strip().split(' ')[2]
    if 'sliders' not in documentContext: documentContext['sliders'] = {}
    if poi not in documentContext['sliders']: documentContext['sliders'][poi] = .5
    if (_ == 'hello-world'): return {'component': '<slider>', 'data': _, 'label': poi}
    if (type(_) is not list): _ = _['data']
    return {'component': '<slider>', 'data': _, 'label': poi}

#def attempt_at_building_communities(_, documentContext):
#num_houses = re.find(r'find (\d)-(\d) houses')
num_houses = float(re.findall(r'find (\d-\d) houses', _)[0].split('-')[1])
city_name = 'Tokyo--Japan'
apt_list = json.load(open(f'data/airbnb/apt/{city_name}.json'))[:1000]
all_houses = apt_list
not_a_schema = {'component': '<slider>', 'data': all_houses}
coefficents = ['yoga', 'kick-boxing', 'rock_climbing', 'wind-surfing', 'bars', 'country', 'disco', 'bookstores']
coefficents = ['restaurant', 'library', 'atm', 'vending_machine', 'bench', 'parking_space', 'bank', 'clinic', 'place_of_worship', 'research_institute']

print('1')
for coeff in coefficents:
    filter_by_poi(not_a_schema, documentContext, f'i like ${coeff}')
#list of 10,000 airbnbs
#for each one, dont get the isochrone -> rank each one 
#h3 cell every square mile in tokyo with each POI 
#10,000 -> sorted in 10 different ways -> no extra used memory.
#10,000 * 10,000
h3_cells = {}
for apt in all_houses:
    coords = get_lat_long(apt)
    hex_id = h3.geo_to_h3(float(coords[0]), float(coords[1]), resolution=7)
    #if hex_id not in h3_cells: 
    h3_cells[hex_id] = {}
print('2')
# Out:
# 1
# 2

# %%
h3_cells
# Out:
# {'872f5a323ffffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5a32affffff': {'restaurant': 127,
#   'library': 127,
#   'atm': 127,
#   'vending_machine': 127,
#   'bench': 127,
#   'parking_space': 127,
#   'bank': 127,
#   'clinic': 127,
#   'place_of_worship': 127,
#   'research_institute': 127},
#  '872f5a305ffffff': {'restaurant': 127,
#   'library': 127,
#   'atm': 127,
#   'vending_machine': 127,
#   'bench': 127,
#   'parking_space': 127,
#   'bank': 127,
#   'clinic': 127,
#   'place_of_worship': 127,
#   'research_institute': 127},
#  '872f5aaddffffff': {'restaurant': 458,
#   'library': 458,
#   'atm': 458,
#   'vending_machine': 458,
#   'bench': 458,
#   'parking_space': 458,
#   'bank': 458,
#   'clinic': 458,
#   'place_of_worship': 458,
#   'research_institute': 458},
#  '872f5a331ffffff': {'restaurant': 56,
#   'library': 56,
#   'atm': 56,
#   'vending_machine': 56,
#   'bench': 56,
#   'parking_space': 56,
#   'bank': 56,
#   'clinic': 56,
#   'place_of_worship': 56,
#   'research_institute': 56},
#  '872f5a329ffffff': {'restaurant': 344,
#   'library': 344,
#   'atm': 344,
#   'vending_machine': 344,
#   'bench': 344,
#   'parking_space': 344,
#   'bank': 344,
#   'clinic': 344,
#   'place_of_worship': 344,
#   'research_institute': 344},
#  '872f5aac8ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5a370ffffff': {'restaurant': 150,
#   'library': 150,
#   'atm': 150,
#   'vending_machine': 150,
#   'bench': 150,
#   'parking_space': 150,
#   'bank': 150,
#   'clinic': 150,
#   'place_of_worship': 150,
#   'research_institute': 150},
#  '872f5a322ffffff': {'restaurant': 21,
#   'library': 21,
#   'atm': 21,
#   'vending_machine': 21,
#   'bench': 21,
#   'parking_space': 21,
#   'bank': 21,
#   'clinic': 21,
#   'place_of_worship': 21,
#   'research_institute': 21},
#  '872f5a375ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5a36cffffff': {'restaurant': 30,
#   'library': 30,
#   'atm': 30,
#   'vending_machine': 30,
#   'bench': 30,
#   'parking_space': 30,
#   'bank': 30,
#   'clinic': 30,
#   'place_of_worship': 30,
#   'research_institute': 30},
#  '872f5aaceffffff': {'restaurant': 106,
#   'library': 106,
#   'atm': 106,
#   'vending_machine': 106,
#   'bench': 106,
#   'parking_space': 106,
#   'bank': 106,
#   'clinic': 106,
#   'place_of_worship': 106,
#   'research_institute': 106},
#  '872f5aad8ffffff': {'restaurant': 458,
#   'library': 458,
#   'atm': 458,
#   'vending_machine': 458,
#   'bench': 458,
#   'parking_space': 458,
#   'bank': 458,
#   'clinic': 458,
#   'place_of_worship': 458,
#   'research_institute': 458},
#  '872f5a360ffffff': {'restaurant': 132,
#   'library': 132,
#   'atm': 132,
#   'vending_machine': 132,
#   'bench': 132,
#   'parking_space': 132,
#   'bank': 132,
#   'clinic': 132,
#   'place_of_worship': 132,
#   'research_institute': 132},
#  '872f5a366ffffff': {'restaurant': 40,
#   'library': 40,
#   'atm': 40,
#   'vending_machine': 40,
#   'bench': 40,
#   'parking_space': 40,
#   'bank': 40,
#   'clinic': 40,
#   'place_of_worship': 40,
#   'research_institute': 40},
#  '872f5bc8bffffff': {'restaurant': 14,
#   'library': 14,
#   'atm': 14,
#   'vending_machine': 14,
#   'bench': 14,
#   'parking_space': 14,
#   'bank': 14,
#   'clinic': 14,
#   'place_of_worship': 14,
#   'research_institute': 14},
#  '872f5a328ffffff': {'restaurant': 800,
#   'library': 800,
#   'atm': 800,
#   'vending_machine': 800,
#   'bench': 800,
#   'parking_space': 800,
#   'bank': 800,
#   'clinic': 800,
#   'place_of_worship': 800,
#   'research_institute': 800},
#  '872f5a31cffffff': {'restaurant': 37,
#   'library': 37,
#   'atm': 37,
#   'vending_machine': 37,
#   'bench': 37,
#   'parking_space': 37,
#   'bank': 37,
#   'clinic': 37,
#   'place_of_worship': 37,
#   'research_institute': 37},
#  '872f5a373ffffff': {'restaurant': 40,
#   'library': 40,
#   'atm': 40,
#   'vending_machine': 40,
#   'bench': 40,
#   'parking_space': 40,
#   'bank': 40,
#   'clinic': 40,
#   'place_of_worship': 40,
#   'research_institute': 40},
#  '872f5a35effffff': {'restaurant': 28,
#   'library': 28,
#   'atm': 28,
#   'vending_machine': 28,
#   'bench': 28,
#   'parking_space': 28,
#   'bank': 28,
#   'clinic': 28,
#   'place_of_worship': 28,
#   'research_institute': 28},
#  '872f5aac9ffffff': {'restaurant': 88,
#   'library': 88,
#   'atm': 88,
#   'vending_machine': 88,
#   'bench': 88,
#   'parking_space': 88,
#   'bank': 88,
#   'clinic': 88,
#   'place_of_worship': 88,
#   'research_institute': 88},
#  '872f5bc16ffffff': {'restaurant': 17,
#   'library': 17,
#   'atm': 17,
#   'vending_machine': 17,
#   'bench': 17,
#   'parking_space': 17,
#   'bank': 17,
#   'clinic': 17,
#   'place_of_worship': 17,
#   'research_institute': 17},
#  '872f5a376ffffff': {'restaurant': 458,
#   'library': 458,
#   'atm': 458,
#   'vending_machine': 458,
#   'bench': 458,
#   'parking_space': 458,
#   'bank': 458,
#   'clinic': 458,
#   'place_of_worship': 458,
#   'research_institute': 458},
#  '872f5a324ffffff': {'restaurant': 56,
#   'library': 56,
#   'atm': 56,
#   'vending_machine': 56,
#   'bench': 56,
#   'parking_space': 56,
#   'bank': 56,
#   'clinic': 56,
#   'place_of_worship': 56,
#   'research_institute': 56},
#  '872f5a309ffffff': {'restaurant': 106,
#   'library': 106,
#   'atm': 106,
#   'vending_machine': 106,
#   'bench': 106,
#   'parking_space': 106,
#   'bank': 106,
#   'clinic': 106,
#   'place_of_worship': 106,
#   'research_institute': 106},
#  '872f5bd90ffffff': {'restaurant': 28,
#   'library': 28,
#   'atm': 28,
#   'vending_machine': 28,
#   'bench': 28,
#   'parking_space': 28,
#   'bank': 28,
#   'clinic': 28,
#   'place_of_worship': 28,
#   'research_institute': 28},
#  '872f5a34cffffff': {'restaurant': 101,
#   'library': 101,
#   'atm': 101,
#   'vending_machine': 101,
#   'bench': 101,
#   'parking_space': 101,
#   'bank': 101,
#   'clinic': 101,
#   'place_of_worship': 101,
#   'research_institute': 101},
#  '872f5a344ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5bc9affffff': {'restaurant': 5,
#   'library': 5,
#   'atm': 5,
#   'vending_machine': 5,
#   'bench': 5,
#   'parking_space': 5,
#   'bank': 5,
#   'clinic': 5,
#   'place_of_worship': 5,
#   'research_institute': 5},
#  '872f5aad3ffffff': {'restaurant': 127,
#   'library': 127,
#   'atm': 127,
#   'vending_machine': 127,
#   'bench': 127,
#   'parking_space': 127,
#   'bank': 127,
#   'clinic': 127,
#   'place_of_worship': 127,
#   'research_institute': 127},
#  '872f5a362ffffff': {'restaurant': 88,
#   'library': 88,
#   'atm': 88,
#   'vending_machine': 88,
#   'bench': 88,
#   'parking_space': 88,
#   'bank': 88,
#   'clinic': 88,
#   'place_of_worship': 88,
#   'research_institute': 88},
#  '872f5aac1ffffff': {'restaurant': 50,
#   'library': 50,
#   'atm': 50,
#   'vending_machine': 50,
#   'bench': 50,
#   'parking_space': 50,
#   'bank': 50,
#   'clinic': 50,
#   'place_of_worship': 50,
#   'research_institute': 50},
#  '872f5a32effffff': {'restaurant': 37,
#   'library': 37,
#   'atm': 37,
#   'vending_machine': 37,
#   'bench': 37,
#   'parking_space': 37,
#   'bank': 37,
#   'clinic': 37,
#   'place_of_worship': 37,
#   'research_institute': 37},
#  '872f5a343ffffff': {'restaurant': 30,
#   'library': 30,
#   'atm': 30,
#   'vending_machine': 30,
#   'bench': 30,
#   'parking_space': 30,
#   'bank': 30,
#   'clinic': 30,
#   'place_of_worship': 30,
#   'research_institute': 30},
#  '872f5a325ffffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5bc82ffffff': {'restaurant': 46,
#   'library': 46,
#   'atm': 46,
#   'vending_machine': 46,
#   'bench': 46,
#   'parking_space': 46,
#   'bank': 46,
#   'clinic': 46,
#   'place_of_worship': 46,
#   'research_institute': 46},
#  '872f5a30cffffff': {'restaurant': 51,
#   'library': 51,
#   'atm': 51,
#   'vending_machine': 51,
#   'bench': 51,
#   'parking_space': 51,
#   'bank': 51,
#   'clinic': 51,
#   'place_of_worship': 51,
#   'research_institute': 51},
#  '872f5bc89ffffff': {'restaurant': 24,
#   'library': 24,
#   'atm': 24,
#   'vending_machine': 24,
#   'bench': 24,
#   'parking_space': 24,
#   'bank': 24,
#   'clinic': 24,
#   'place_of_worship': 24,
#   'research_institute': 24},
#  '872f5bcb0ffffff': {'restaurant': 10,
#   'library': 10,
#   'atm': 10,
#   'vending_machine': 10,
#   'bench': 10,
#   'parking_space': 10,
#   'bank': 10,
#   'clinic': 10,
#   'place_of_worship': 10,
#   'research_institute': 10},
#  '872f5a26dffffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5a32bffffff': {'restaurant': 344,
#   'library': 344,
#   'atm': 344,
#   'vending_machine': 344,
#   'bench': 344,
#   'parking_space': 344,
#   'bank': 344,
#   'clinic': 344,
#   'place_of_worship': 344,
#   'research_institute': 344},
#  '872f5bcc1ffffff': {'restaurant': 28,
#   'library': 28,
#   'atm': 28,
#   'vending_machine': 28,
#   'bench': 28,
#   'parking_space': 28,
#   'bank': 28,
#   'clinic': 28,
#   'place_of_worship': 28,
#   'research_institute': 28},
#  '872f5aadbffffff': {'restaurant': 106,
#   'library': 106,
#   'atm': 106,
#   'vending_machine': 106,
#   'bench': 106,
#   'parking_space': 106,
#   'bank': 106,
#   'clinic': 106,
#   'place_of_worship': 106,
#   'research_institute': 106},
#  '872f5a334ffffff': {'restaurant': 64,
#   'library': 64,
#   'atm': 64,
#   'vending_machine': 64,
#   'bench': 64,
#   'parking_space': 64,
#   'bank': 64,
#   'clinic': 64,
#   'place_of_worship': 64,
#   'research_institute': 64},
#  '872f5aad2ffffff': {'restaurant': 132,
#   'library': 132,
#   'atm': 132,
#   'vending_machine': 132,
#   'bench': 132,
#   'parking_space': 132,
#   'bank': 132,
#   'clinic': 132,
#   'place_of_worship': 132,
#   'research_institute': 132},
#  '872f5a364ffffff': {'restaurant': 40,
#   'library': 40,
#   'atm': 40,
#   'vending_machine': 40,
#   'bench': 40,
#   'parking_space': 40,
#   'bank': 40,
#   'clinic': 40,
#   'place_of_worship': 40,
#   'research_institute': 40},
#  '872f5a345ffffff': {'restaurant': 28,
#   'library': 28,
#   'atm': 28,
#   'vending_machine': 28,
#   'bench': 28,
#   'parking_space': 28,
#   'bank': 28,
#   'clinic': 28,
#   'place_of_worship': 28,
#   'research_institute': 28},
#  '872f5a340ffffff': {'restaurant': 59,
#   'library': 59,
#   'atm': 59,
#   'vending_machine': 59,
#   'bench': 59,
#   'parking_space': 59,
#   'bank': 59,
#   'clinic': 59,
#   'place_of_worship': 59,
#   'research_institute': 59},
#  '872f5a346ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5a326ffffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5a34dffffff': {'restaurant': 124,
#   'library': 124,
#   'atm': 124,
#   'vending_machine': 124,
#   'bench': 124,
#   'parking_space': 124,
#   'bank': 124,
#   'clinic': 124,
#   'place_of_worship': 124,
#   'research_institute': 124},
#  '872f5bdb6ffffff': {'restaurant': 40,
#   'library': 40,
#   'atm': 40,
#   'vending_machine': 40,
#   'bench': 40,
#   'parking_space': 40,
#   'bank': 40,
#   'clinic': 40,
#   'place_of_worship': 40,
#   'research_institute': 40},
#  '872f5a30dffffff': {'restaurant': 458,
#   'library': 458,
#   'atm': 458,
#   'vending_machine': 458,
#   'bench': 458,
#   'parking_space': 458,
#   'bank': 458,
#   'clinic': 458,
#   'place_of_worship': 458,
#   'research_institute': 458},
#  '872f5bc15ffffff': {'restaurant': 15,
#   'library': 15,
#   'atm': 15,
#   'vending_machine': 15,
#   'bench': 15,
#   'parking_space': 15,
#   'bank': 15,
#   'clinic': 15,
#   'place_of_worship': 15,
#   'research_institute': 15},
#  '872f5a333ffffff': {'restaurant': 56,
#   'library': 56,
#   'atm': 56,
#   'vending_machine': 56,
#   'bench': 56,
#   'parking_space': 56,
#   'bank': 56,
#   'clinic': 56,
#   'place_of_worship': 56,
#   'research_institute': 56},
#  '872f5a350ffffff': {'restaurant': 88,
#   'library': 88,
#   'atm': 88,
#   'vending_machine': 88,
#   'bench': 88,
#   'parking_space': 88,
#   'bank': 88,
#   'clinic': 88,
#   'place_of_worship': 88,
#   'research_institute': 88},
#  '872f5a269ffffff': {'restaurant': 15,
#   'library': 15,
#   'atm': 15,
#   'vending_machine': 15,
#   'bench': 15,
#   'parking_space': 15,
#   'bank': 15,
#   'clinic': 15,
#   'place_of_worship': 15,
#   'research_institute': 15},
#  '872f5a354ffffff': {'restaurant': 40,
#   'library': 40,
#   'atm': 40,
#   'vending_machine': 40,
#   'bench': 40,
#   'parking_space': 40,
#   'bank': 40,
#   'clinic': 40,
#   'place_of_worship': 40,
#   'research_institute': 40},
#  '872f5b529ffffff': {'restaurant': 23,
#   'library': 23,
#   'atm': 23,
#   'vending_machine': 23,
#   'bench': 23,
#   'parking_space': 23,
#   'bank': 23,
#   'clinic': 23,
#   'place_of_worship': 23,
#   'research_institute': 23},
#  '872f5aacaffffff': {'restaurant': 150,
#   'library': 150,
#   'atm': 150,
#   'vending_machine': 150,
#   'bench': 150,
#   'parking_space': 150,
#   'bank': 150,
#   'clinic': 150,
#   'place_of_worship': 150,
#   'research_institute': 150},
#  '872f5bc1affffff': {'restaurant': 0,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 2,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 2,
#   'research_institute': 2},
#  '872f5a363ffffff': {'restaurant': 38,
#   'library': 38,
#   'atm': 38,
#   'vending_machine': 38,
#   'bench': 38,
#   'parking_space': 38,
#   'bank': 38,
#   'clinic': 38,
#   'place_of_worship': 38,
#   'research_institute': 38},
#  '872f5a365ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5bc90ffffff': {'restaurant': 20,
#   'library': 20,
#   'atm': 20,
#   'vending_machine': 20,
#   'bench': 20,
#   'parking_space': 20,
#   'bank': 20,
#   'clinic': 20,
#   'place_of_worship': 20,
#   'research_institute': 20},
#  '872f5a320ffffff': {'restaurant': 21,
#   'library': 21,
#   'atm': 21,
#   'vending_machine': 21,
#   'bench': 21,
#   'parking_space': 21,
#   'bank': 21,
#   'clinic': 21,
#   'place_of_worship': 21,
#   'research_institute': 21},
#  '872f5a303ffffff': {'restaurant': 37,
#   'library': 37,
#   'atm': 37,
#   'vending_machine': 37,
#   'bench': 37,
#   'parking_space': 37,
#   'bank': 37,
#   'clinic': 37,
#   'place_of_worship': 37,
#   'research_institute': 37},
#  '872f5aadcffffff': {'restaurant': 344,
#   'library': 344,
#   'atm': 344,
#   'vending_machine': 344,
#   'bench': 344,
#   'parking_space': 344,
#   'bank': 344,
#   'clinic': 344,
#   'place_of_worship': 344,
#   'research_institute': 344},
#  '872f5a372ffffff': {'restaurant': 150,
#   'library': 150,
#   'atm': 150,
#   'vending_machine': 150,
#   'bench': 150,
#   'parking_space': 150,
#   'bank': 150,
#   'clinic': 150,
#   'place_of_worship': 150,
#   'research_institute': 150},
#  '872f5bc8dffffff': {'restaurant': 5,
#   'library': 5,
#   'atm': 5,
#   'vending_machine': 5,
#   'bench': 5,
#   'parking_space': 5,
#   'bank': 5,
#   'clinic': 5,
#   'place_of_worship': 5,
#   'research_institute': 5},
#  '872f5a32cffffff': {'restaurant': 37,
#   'library': 37,
#   'atm': 37,
#   'vending_machine': 37,
#   'bench': 37,
#   'parking_space': 37,
#   'bank': 37,
#   'clinic': 37,
#   'place_of_worship': 37,
#   'research_institute': 37},
#  '872f5bcb1ffffff': {'restaurant': 20,
#   'library': 20,
#   'atm': 20,
#   'vending_machine': 20,
#   'bench': 20,
#   'parking_space': 20,
#   'bank': 20,
#   'clinic': 20,
#   'place_of_worship': 20,
#   'research_institute': 20},
#  '872f5a32dffffff': {'restaurant': 51,
#   'library': 51,
#   'atm': 51,
#   'vending_machine': 51,
#   'bench': 51,
#   'parking_space': 51,
#   'bank': 51,
#   'clinic': 51,
#   'place_of_worship': 51,
#   'research_institute': 51},
#  '872f5aad9ffffff': {'restaurant': 150,
#   'library': 150,
#   'atm': 150,
#   'vending_machine': 150,
#   'bench': 150,
#   'parking_space': 150,
#   'bank': 150,
#   'clinic': 150,
#   'place_of_worship': 150,
#   'research_institute': 150},
#  '872f5a321ffffff': {'restaurant': 132,
#   'library': 132,
#   'atm': 132,
#   'vending_machine': 132,
#   'bench': 132,
#   'parking_space': 132,
#   'bank': 132,
#   'clinic': 132,
#   'place_of_worship': 132,
#   'research_institute': 132},
#  '872f5aadeffffff': {'restaurant': 51,
#   'library': 51,
#   'atm': 51,
#   'vending_machine': 51,
#   'bench': 51,
#   'parking_space': 51,
#   'bank': 51,
#   'clinic': 51,
#   'place_of_worship': 51,
#   'research_institute': 51},
#  '872f5aad1ffffff': {'restaurant': 127,
#   'library': 127,
#   'atm': 127,
#   'vending_machine': 127,
#   'bench': 127,
#   'parking_space': 127,
#   'bank': 127,
#   'clinic': 127,
#   'place_of_worship': 127,
#   'research_institute': 127},
#  '872f5bc10ffffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5a335ffffff': {'restaurant': 42,
#   'library': 42,
#   'atm': 42,
#   'vending_machine': 42,
#   'bench': 42,
#   'parking_space': 42,
#   'bank': 42,
#   'clinic': 42,
#   'place_of_worship': 42,
#   'research_institute': 42},
#  '872f5bca8ffffff': {'restaurant': 23,
#   'library': 23,
#   'atm': 23,
#   'vending_machine': 23,
#   'bench': 23,
#   'parking_space': 23,
#   'bank': 23,
#   'clinic': 23,
#   'place_of_worship': 23,
#   'research_institute': 23},
#  '872f5aaccffffff': {'restaurant': 106,
#   'library': 106,
#   'atm': 106,
#   'vending_machine': 106,
#   'bench': 106,
#   'parking_space': 106,
#   'bank': 106,
#   'clinic': 106,
#   'place_of_worship': 106,
#   'research_institute': 106},
#  '872f5a371ffffff': {'restaurant': 88,
#   'library': 88,
#   'atm': 88,
#   'vending_machine': 88,
#   'bench': 88,
#   'parking_space': 88,
#   'bank': 88,
#   'clinic': 88,
#   'place_of_worship': 88,
#   'research_institute': 88},
#  '872f5bd98ffffff': {'restaurant': 124,
#   'library': 124,
#   'atm': 124,
#   'vending_machine': 124,
#   'bench': 124,
#   'parking_space': 124,
#   'bank': 124,
#   'clinic': 124,
#   'place_of_worship': 124,
#   'research_institute': 124},
#  '872f5bcabffffff': {'restaurant': 5,
#   'library': 5,
#   'atm': 5,
#   'vending_machine': 5,
#   'bench': 5,
#   'parking_space': 5,
#   'bank': 5,
#   'clinic': 5,
#   'place_of_worship': 5,
#   'research_institute': 5},
#  '872f5bcb4ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5bcb5ffffff': {'restaurant': 42,
#   'library': 42,
#   'atm': 42,
#   'vending_machine': 42,
#   'bench': 42,
#   'parking_space': 42,
#   'bank': 42,
#   'clinic': 42,
#   'place_of_worship': 42,
#   'research_institute': 42},
#  '872f5aacbffffff': {'restaurant': 88,
#   'library': 88,
#   'atm': 88,
#   'vending_machine': 88,
#   'bench': 88,
#   'parking_space': 88,
#   'bank': 88,
#   'clinic': 88,
#   'place_of_worship': 88,
#   'research_institute': 88},
#  '872f5a361ffffff': {'restaurant': 38,
#   'library': 38,
#   'atm': 38,
#   'vending_machine': 38,
#   'bench': 38,
#   'parking_space': 38,
#   'bank': 38,
#   'clinic': 38,
#   'place_of_worship': 38,
#   'research_institute': 38},
#  '872f5bd96ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5aae9ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5a374ffffff': {'restaurant': 106,
#   'library': 106,
#   'atm': 106,
#   'vending_machine': 106,
#   'bench': 106,
#   'parking_space': 106,
#   'bank': 106,
#   'clinic': 106,
#   'place_of_worship': 106,
#   'research_institute': 106},
#  '872f5a30effffff': {'restaurant': 51,
#   'library': 51,
#   'atm': 51,
#   'vending_machine': 51,
#   'bench': 51,
#   'parking_space': 51,
#   'bank': 51,
#   'clinic': 51,
#   'place_of_worship': 51,
#   'research_institute': 51},
#  '872f5a330ffffff': {'restaurant': 42,
#   'library': 42,
#   'atm': 42,
#   'vending_machine': 42,
#   'bench': 42,
#   'parking_space': 42,
#   'bank': 42,
#   'clinic': 42,
#   'place_of_worship': 42,
#   'research_institute': 42},
#  '872f5a301ffffff': {'restaurant': 127,
#   'library': 127,
#   'atm': 127,
#   'vending_machine': 127,
#   'bench': 127,
#   'parking_space': 127,
#   'bank': 127,
#   'clinic': 127,
#   'place_of_worship': 127,
#   'research_institute': 127},
#  '872f5bc9effffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5bcceffffff': {'restaurant': 8,
#   'library': 8,
#   'atm': 8,
#   'vending_machine': 8,
#   'bench': 8,
#   'parking_space': 8,
#   'bank': 8,
#   'clinic': 8,
#   'place_of_worship': 8,
#   'research_institute': 8},
#  '872f5a368ffffff': {'restaurant': 33,
#   'library': 33,
#   'atm': 33,
#   'vending_machine': 33,
#   'bench': 33,
#   'parking_space': 33,
#   'bank': 33,
#   'clinic': 33,
#   'place_of_worship': 33,
#   'research_institute': 33},
#  '872f5aacdffffff': {'restaurant': 40,
#   'library': 40,
#   'atm': 40,
#   'vending_machine': 40,
#   'bench': 40,
#   'parking_space': 40,
#   'bank': 40,
#   'clinic': 40,
#   'place_of_worship': 40,
#   'research_institute': 40},
#  '872f5a36effffff': {'restaurant': 28,
#   'library': 28,
#   'atm': 28,
#   'vending_machine': 28,
#   'bench': 28,
#   'parking_space': 28,
#   'bank': 28,
#   'clinic': 28,
#   'place_of_worship': 28,
#   'research_institute': 28},
#  '872f5bd92ffffff': {'restaurant': 59,
#   'library': 59,
#   'atm': 59,
#   'vending_machine': 59,
#   'bench': 59,
#   'parking_space': 59,
#   'bank': 59,
#   'clinic': 59,
#   'place_of_worship': 59,
#   'research_institute': 59},
#  '872f5bd94ffffff': {'restaurant': 38,
#   'library': 38,
#   'atm': 38,
#   'vending_machine': 38,
#   'bench': 38,
#   'parking_space': 38,
#   'bank': 38,
#   'clinic': 38,
#   'place_of_worship': 38,
#   'research_institute': 38},
#  '872f5a300ffffff': {'restaurant': 132,
#   'library': 132,
#   'atm': 132,
#   'vending_machine': 132,
#   'bench': 132,
#   'parking_space': 132,
#   'bank': 132,
#   'clinic': 132,
#   'place_of_worship': 132,
#   'research_institute': 132},
#  '872f5aa98ffffff': {'restaurant': 12,
#   'library': 12,
#   'atm': 12,
#   'vending_machine': 12,
#   'bench': 12,
#   'parking_space': 12,
#   'bank': 12,
#   'clinic': 12,
#   'place_of_worship': 12,
#   'research_institute': 12},
#  '872f5a308ffffff': {'restaurant': 50,
#   'library': 50,
#   'atm': 50,
#   'vending_machine': 50,
#   'bench': 50,
#   'parking_space': 50,
#   'bank': 50,
#   'clinic': 50,
#   'place_of_worship': 50,
#   'research_institute': 50},
#  '872f5bcb3ffffff': {'restaurant': 14,
#   'library': 14,
#   'atm': 14,
#   'vending_machine': 14,
#   'bench': 14,
#   'parking_space': 14,
#   'bank': 14,
#   'clinic': 14,
#   'place_of_worship': 14,
#   'research_institute': 14},
#  '872f5a34bffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48},
#  '872f5a31dffffff': {'restaurant': 800,
#   'library': 800,
#   'atm': 800,
#   'vending_machine': 800,
#   'bench': 800,
#   'parking_space': 800,
#   'bank': 800,
#   'clinic': 800,
#   'place_of_worship': 800,
#   'research_institute': 800},
#  '872f5aaecffffff': {'restaurant': 344,
#   'library': 344,
#   'atm': 344,
#   'vending_machine': 344,
#   'bench': 344,
#   'parking_space': 344,
#   'bank': 344,
#   'clinic': 344,
#   'place_of_worship': 344,
#   'research_institute': 344},
#  '872f5a304ffffff': {'restaurant': 18,
#   'library': 18,
#   'atm': 18,
#   'vending_machine': 18,
#   'bench': 18,
#   'parking_space': 18,
#   'bank': 18,
#   'clinic': 18,
#   'place_of_worship': 18,
#   'research_institute': 18},
#  '872f5aaeaffffff': {'restaurant': 458,
#   'library': 458,
#   'atm': 458,
#   'vending_machine': 458,
#   'bench': 458,
#   'parking_space': 458,
#   'bank': 458,
#   'clinic': 458,
#   'place_of_worship': 458,
#   'research_institute': 458},
#  '872f5aae8ffffff': {'restaurant': 458,
#   'library': 458,
#   'atm': 458,
#   'vending_machine': 458,
#   'bench': 458,
#   'parking_space': 458,
#   'bank': 458,
#   'clinic': 458,
#   'place_of_worship': 458,
#   'research_institute': 458},
#  '872f5bcb2ffffff': {'restaurant': 10,
#   'library': 10,
#   'atm': 10,
#   'vending_machine': 10,
#   'bench': 10,
#   'parking_space': 10,
#   'bank': 10,
#   'clinic': 10,
#   'place_of_worship': 10,
#   'research_institute': 10},
#  '872f5bc18ffffff': {'restaurant': 5,
#   'library': 5,
#   'atm': 5,
#   'vending_machine': 5,
#   'bench': 5,
#   'parking_space': 5,
#   'bank': 5,
#   'clinic': 5,
#   'place_of_worship': 5,
#   'research_institute': 5},
#  '872f5aaebffffff': {'restaurant': 150,
#   'library': 150,
#   'atm': 150,
#   'vending_machine': 150,
#   'bench': 150,
#   'parking_space': 150,
#   'bank': 150,
#   'clinic': 150,
#   'place_of_worship': 150,
#   'research_institute': 150},
#  '872f5a341ffffff': {'restaurant': 30,
#   'library': 30,
#   'atm': 30,
#   'vending_machine': 30,
#   'bench': 30,
#   'parking_space': 30,
#   'bank': 30,
#   'clinic': 30,
#   'place_of_worship': 30,
#   'research_institute': 30},
#  '872f5a35cffffff': {'restaurant': 28,
#   'library': 28,
#   'atm': 28,
#   'vending_machine': 28,
#   'bench': 28,
#   'parking_space': 28,
#   'bank': 28,
#   'clinic': 28,
#   'place_of_worship': 28,
#   'research_institute': 28},
#  '872f5b56affffff': {'restaurant': 1,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 1,
#   'bench': 1,
#   'parking_space': 1,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 1,
#   'research_institute': 1},
#  '872f5aac3ffffff': {'restaurant': 344,
#   'library': 344,
#   'atm': 344,
#   'vending_machine': 344,
#   'bench': 344,
#   'parking_space': 344,
#   'bank': 344,
#   'clinic': 344,
#   'place_of_worship': 344,
#   'research_institute': 344},
#  '872f5aa99ffffff': {'restaurant': 19,
#   'library': 19,
#   'atm': 19,
#   'vending_machine': 19,
#   'bench': 19,
#   'parking_space': 19,
#   'bank': 19,
#   'clinic': 19,
#   'place_of_worship': 19,
#   'research_institute': 19},
#  '872f5aa8bffffff': {'restaurant': 56,
#   'library': 56,
#   'atm': 56,
#   'vending_machine': 56,
#   'bench': 56,
#   'parking_space': 56,
#   'bank': 56,
#   'clinic': 56,
#   'place_of_worship': 56,
#   'research_institute': 56},
#  '872f5bcddffffff': {'restaurant': 8,
#   'library': 8,
#   'atm': 8,
#   'vending_machine': 8,
#   'bench': 8,
#   'parking_space': 8,
#   'bank': 8,
#   'clinic': 8,
#   'place_of_worship': 8,
#   'research_institute': 8},
#  '872f5a348ffffff': {'restaurant': 124,
#   'library': 124,
#   'atm': 124,
#   'vending_machine': 124,
#   'bench': 124,
#   'parking_space': 124,
#   'bank': 124,
#   'clinic': 124,
#   'place_of_worship': 124,
#   'research_institute': 124},
#  '872f5a36affffff': {'restaurant': 61,
#   'library': 61,
#   'atm': 61,
#   'vending_machine': 61,
#   'bench': 61,
#   'parking_space': 61,
#   'bank': 61,
#   'clinic': 61,
#   'place_of_worship': 61,
#   'research_institute': 61},
#  '872f5b509ffffff': {'restaurant': 20,
#   'library': 20,
#   'atm': 20,
#   'vending_machine': 20,
#   'bench': 20,
#   'parking_space': 20,
#   'bank': 20,
#   'clinic': 20,
#   'place_of_worship': 20,
#   'research_institute': 20},
#  '872f5a355ffffff': {'restaurant': 132,
#   'library': 132,
#   'atm': 132,
#   'vending_machine': 132,
#   'bench': 132,
#   'parking_space': 132,
#   'bank': 132,
#   'clinic': 132,
#   'place_of_worship': 132,
#   'research_institute': 132},
#  '872f5bc83ffffff': {'restaurant': 15,
#   'library': 15,
#   'atm': 15,
#   'vending_machine': 15,
#   'bench': 15,
#   'parking_space': 15,
#   'bank': 15,
#   'clinic': 15,
#   'place_of_worship': 15,
#   'research_institute': 15},
#  '872f5bdb2ffffff': {'restaurant': 132,
#   'library': 132,
#   'atm': 132,
#   'vending_machine': 132,
#   'bench': 132,
#   'parking_space': 132,
#   'bank': 132,
#   'clinic': 132,
#   'place_of_worship': 132,
#   'research_institute': 132},
#  '872f5aadaffffff': {'restaurant': 50,
#   'library': 50,
#   'atm': 50,
#   'vending_machine': 50,
#   'bench': 50,
#   'parking_space': 50,
#   'bank': 50,
#   'clinic': 50,
#   'place_of_worship': 50,
#   'research_institute': 50},
#  '872f5aa8affffff': {'restaurant': 42,
#   'library': 42,
#   'atm': 42,
#   'vending_machine': 42,
#   'bench': 42,
#   'parking_space': 42,
#   'bank': 42,
#   'clinic': 42,
#   'place_of_worship': 42,
#   'research_institute': 42},
#  '872f5bcb6ffffff': {'restaurant': 48,
#   'library': 48,
#   'atm': 48,
#   'vending_machine': 48,
#   'bench': 48,
#   'parking_space': 48,
#   'bank': 48,
#   'clinic': 48,
#   'place_of_worship': 48,
#   'research_institute': 48}}

# %%
from collections import defaultdict
def fetch_coffee_shops(longitude, latitude, amenities=''):
    #if round(longitude, 2) in geoCoordCache: 
        #print('WE GOT THE CACHE', len(geoCoordCache[round(longitude, 1)]))
        #return geoCoordCache[round(longitude, 2)]
    # if (os.path.exists(f'data/airbnb/poi/{longitude}_{latitude}_places.json')):
    #     return json.load(open(f'data/airbnb/poi/{longitude}_{latitude}_places.json', 'r'))
   
    places = []
    query = f"""
    [out:json][timeout:25];
    (
        node["amenity"="{amenities}"]({latitude - 0.01},{longitude - 0.01},{latitude + 0.01},{longitude + 0.01});
    );
    out body;
    """ 
    overpass_url = "https://overpass-api.de/api/interpreter"
    response = requests.get(overpass_url, params={'data': query})

    if response.status_code == 200:
        data = response.json()
 
        coffee_shops = data['elements']
        places += coffee_shops
    #print(len(places), longitude, latitude)

    if len(places) > 0:
        #print(places)
        geoCoordCache[round(longitude, 2)] = places
    #json.dump(places, open(f'data/airbnb/poi/{listing}_places.json', 'w'))
    return places

def fetch_shops_for_cell(hex_id):
    results = {}
    ll = h3.h3_to_geo(hex_id)
    for key in coefficents:
        results[key] = len(fetch_coffee_shops(ll[1], ll[0], key))
        print(key, results[key])
    return (hex_id, results)

# Use ThreadPoolExecutor to parallelize the fetch_coffee_shops calls

before = time.time()
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    for hex_id, results in executor.map(fetch_shops_for_cell, h3_cells.keys()):
        h3_cells[hex_id] = results         
print(time.time() - before)

people_names = 'fred bob sally panda velma gis mercator machester last day'.split(' ')
#for coeff in documentContext['sliders']:
people_housing_list = {}

totals = defaultdict(int)
print('3')

for hex_id in h3_cells:
    for key in coefficents:
        totals[hex_id+key] += h3_cells[hex_id][key]
totals
# Out:
# restaurant 69
# restaurant 21
# restaurant 48
# restaurant 150
# restaurant 344
# restaurant 618
# library 4
# library 2
# library 2
# restaurant 18
# restaurant 56
# restaurant 127
# library 4
# restaurant 108
# library 1
# library 4
# library 2
# atm 4
# vending_machine 26
# atm 2
# library 2
# library 3
# atm 0
# library 3
# vending_machine 0
# atm 18
# atm 6
# atm 8
# bench 7
# atm 26
# bench 0
# vending_machine 261
# atm 12
# vending_machine 1
# vending_machine 44
# vending_machine 8
# vending_machine 17
# atm 0
# bench 2
# atm 4
# bench 16
# bench 26
# parking_space 0
# parking_space 0
# vending_machine 1
# vending_machine 7
# bench 79
# bench 52
# parking_space 0
# vending_machine 52
# bank 3
# bank 5
# bench 12
# bench 35
# clinic 1
# parking_space 0
# clinic 8
# parking_space 0
# parking_space 0
# parking_space 1
# place_of_worship 15
# bank 5
# bank 7
# place_of_worship 22
# bank 11
# bench 18
# research_institute 0
# research_institute 0
# clinic 1
# clinic 9
# parking_space 0
# clinic 2
# parking_space 0
# parking_space 1
# restaurant 30
# restaurant 106
# place_of_worship 16
# place_of_worship 14
# research_institute 0
# library 3
# research_institute 0
# bank 10
# place_of_worship 11
# bank 5
# research_institute 0
# clinic 2
# bank 5
# bank 13
# bank 29
# restaurant 458
# clinic 3
# clinic 9
# clinic 22
# atm 3
# library 2
# restaurant 74
# restaurant 132
# clinic 8
# place_of_worship 10
# library 4
# place_of_worship 32
# place_of_worship 29
# research_institute 0
# research_institute 0
# atm 7
# atm 0
# vending_machine 9
# place_of_worship 26
# research_institute 0
# library 2
# research_institute 0
# library 1
# restaurant 14
# place_of_worship 50
# library 1
# atm 5
# atm 3
# restaurant 40
# research_institute 0
# restaurant 800
# restaurant 37
# atm 0
# vending_machine 2
# vending_machine 48
# bench 30
# vending_machine 21
# bench 5
# library 2
# vending_machine 26
# restaurant 28
# library 1
# library 6
# atm 1
# atm 18
# vending_machine 1
# parking_space 0
# bench 2
# bench 38
# bench 1
# parking_space 0
# bank 12
# parking_space 0
# parking_space 0
# atm 3
# vending_machine 0
# library 1
# bench 43
# clinic 3
# bank 12
# vending_machine 777
# parking_space 0
# place_of_worship 12
# clinic 6
# parking_space 0
# bank 3
# bank 14
# clinic 0
# clinic 3
# bench 8
# vending_machine 4
# atm 0
# bank 3
# clinic 1
# research_institute 0
# place_of_worship 13
# bench 207
# place_of_worship 7
# place_of_worship 36
# research_institute 0
# parking_space 0
# research_institute 0
# restaurant 88
# research_institute 0
# bank 3
# parking_space 0
# restaurant 17
# vending_machine 13
# place_of_worship 7
# bench 0
# bank 31
# research_institute 0
# parking_space 0
# vending_machine 3
# place_of_worship 4
# library 1
# bench 21
# clinic 1
# bench 13
# restaurant 38
# bank 3
# place_of_worship 12
# atm 8
# research_institute 0
# atm 1
# parking_space 0
# parking_space 7
# place_of_worship 15
# library 3
# research_institute 0
# clinic 1
# vending_machine 33
# bench 9
# vending_machine 0
# bank 2
# research_institute 0
# bank 5
# atm 4
# parking_space 0
# bench 22
# place_of_worship 2
# clinicbench 0
#  4
# clinic 7
# vending_machine 20
# bank 7
# parking_space 0
# research_institute 0
# parking_space 0
# place_of_worship 7
# bench 14
# place_of_worship 5
# clinic 12
# place_of_worship 2
# bank 8
# bank 2
# research_institute 0
# research_institute 0
# parking_space 0
# bank 2
# research_institute 0
# clinic 5
# clinic 0
# clinic 4
# place_of_worship 7
# place_of_worship 4
# place_of_worship 19
# research_institute 0
# research_institute 0
# research_institute 0
# 286.07757925987244
# 3
# defaultdict(int,
#             {'872f5a323ffffffrestaurant': 18,
#              '872f5a323fffffflibrary': 2,
#              '872f5a323ffffffatm': 0,
#              '872f5a323ffffffvending_machine': 1,
#              '872f5a323ffffffbench': 35,
#              '872f5a323ffffffparking_space': 0,
#              '872f5a323ffffffbank': 5,
#              '872f5a323ffffffclinic': 1,
#              '872f5a323ffffffplace_of_worship': 16,
#              '872f5a323ffffffresearch_institute': 0,
#              '872f5a32affffffrestaurant': 127,
#              '872f5a32afffffflibrary': 4,
#              '872f5a32affffffatm': 8,
#              '872f5a32affffffvending_machine': 52,
#              '872f5a32affffffbench': 18,
#              '872f5a32affffffparking_space': 0,
#              '872f5a32affffffbank': 10,
#              '872f5a32affffffclinic': 8,
#              '872f5a32affffffplace_of_worship': 50,
#              '872f5a32affffffresearch_institute': 0,
#              '872f5a305ffffffrestaurant': 69,
#              '872f5a305fffffflibrary': 4,
#              '872f5a305ffffffatm': 4,
#              '872f5a305ffffffvending_machine': 26,
#              '872f5a305ffffffbench': 7,
#              '872f5a305ffffffparking_space': 0,
#              '872f5a305ffffffbank': 7,
#              '872f5a305ffffffclinic': 9,
#              '872f5a305ffffffplace_of_worship': 14,
#              '872f5a305ffffffresearch_institute': 0,
#              '872f5aaddffffffrestaurant': 108,
#              '872f5aaddfffffflibrary': 3,
#              '872f5aaddffffffatm': 4,
#              '872f5aaddffffffvending_machine': 7,
#              '872f5aaddffffffbench': 12,
#              '872f5aaddffffffparking_space': 0,
#              '872f5aaddffffffbank': 5,
#              '872f5aaddffffffclinic': 3,
#              '872f5aaddffffffplace_of_worship': 29,
#              '872f5aaddffffffresearch_institute': 0,
#              '872f5a331ffffffrestaurant': 56,
#              '872f5a331fffffflibrary': 3,
#              '872f5a331ffffffatm': 6,
#              '872f5a331ffffffvending_machine': 1,
#              '872f5a331ffffffbench': 2,
#              '872f5a331ffffffparking_space': 0,
#              '872f5a331ffffffbank': 5,
#              '872f5a331ffffffclinic': 8,
#              '872f5a331ffffffplace_of_worship': 22,
#              '872f5a331ffffffresearch_institute': 0,
#              '872f5a329ffffffrestaurant': 344,
#              '872f5a329fffffflibrary': 1,
#              '872f5a325ffffffatm': 1,
#              '872f5a325ffffffvending_machine': 5,
#              '872f5a325ffffffbench': 0,
#              '872f5a325ffffffparking_space': 1,
#              '872f5a325ffffffbank': 2,
#              '872f5a325ffffffclinic': 2,
#              '872f5a325ffffffplace_of_worship': 7,
#              '872f5a325ffffffresearch_institute': 0,
#              '872f5bc82ffffffrestaurant': 46,
#              '872f5bc82fffffflibrary': 4,
#              '872f5bc82ffffffatm': 0,
#              '872f5bc82ffffffvending_machine': 0,
#              '872f5bc82ffffffbench': 4,
#              '872f5bc82ffffffparking_space': 0,
#              '872f5bc82ffffffbank': 5,
#              '872f5bc82ffffffclinic': 7,
#              '872f5bc82ffffffplace_of_worship': 3,
#              '872f5bc82ffffffresearch_institute': 1,
#              '872f5a30cffffffrestaurant': 51,
#              '872f5a30cfffffflibrary': 4,
#              '872f5a30cffffffatm': 1,
#              '872f5a30cffffffvending_machine': 14,
#              '872f5a30cffffffbench': 2,
#              '872f5a30cffffffparking_space': 0,
#              '872f5a30cffffffbank': 8,
#              '872f5a30cffffffclinic': 2,
#              '872f5a30cffffffplace_of_worship': 12,
#              '872f5a30cffffffresearch_institute': 0,
#              '872f5bc89ffffffrestaurant': 24,
#              '872f5bc89fffffflibrary': 0,
#              '872f5bc89ffffffatm': 1,
#              '872f5bc89ffffffvending_machine': 10,
#              '872f5bc89ffffffbench': 7,
#              '872f5bc89ffffffparking_space': 1,
#              '872f5bc89ffffffbank': 0,
#              '872f5bc89ffffffclinic': 2,
#              '872f5bc89ffffffplace_of_worship': 3,
#              '872f5bc89ffffffresearch_institute': 0,
#              '872f5bcb0ffffffrestaurant': 10,
#              '872f5bcb0fffffflibrary': 1,
#              '872f5bcb0ffffffatm': 0,
#              '872f5bcb0ffffffvending_machine': 1,
#              '872f5bcb0ffffffbench': 14,
#              '872f5bcb0ffffffparking_space': 0,
#              '872f5bcb0ffffffbank': 0,
#              '872f5bcb0ffffffclinic': 0,
#              '872f5bcb0ffffffplace_of_worship': 5,
#              '872f5bcb0ffffffresearch_institute': 0,
#              '872f5a26dffffffrestaurant': 18,
#              '872f5a26dfffffflibrary': 0,
#              '872f5a26dffffffatm': 0,
#              '872f5a26dffffffvending_machine': 11,
#              '872f5a26dffffffbench': 0,
#              '872f5a26dffffffparking_space': 0,
#              '872f5a26dffffffbank': 2,
#              '872f5a26dffffffclinic': 4,
#              '872f5a26dffffffplace_of_worship': 2,
#              '872f5a26dffffffresearch_institute': 0,
#              '872f5a32bffffffrestaurant': 98,
#              '872f5a32bfffffflibrary': 5,
#              '872f5a32bffffffatm': 2,
#              '872f5a32bffffffvending_machine': 26,
#              '872f5a32bffffffbench': 148,
#              '872f5a32bffffffparking_space': 0,
#              '872f5a32bffffffbank': 11,
#              '872f5a32bffffffclinic': 6,
#              '872f5a32bffffffplace_of_worship': 60,
#              '872f5a32bffffffresearch_institute': 0,
#              '872f5bcc1ffffffrestaurant': 28,
#              '872f5bcc1fffffflibrary': 0,
#              '872f5bcc1ffffffatm': 3,
#              '872f5a346ffffffparking_space': 0,
#              '872f5a346ffffffbank': 5,
#              '872f5a346ffffffclinic': 2,
#              '872f5a346ffffffplace_of_worship': 16,
#              '872f5a346ffffffresearch_institute': 0,
#              '872f5a326ffffffrestaurant': 18,
#              '872f5a326fffffflibrary': 3,
#              '872f5a326ffffffatm': 0,
#              '872f5a326ffffffvending_machine': 0,
#              '872f5a326ffffffbench': 4,
#              '872f5a326ffffffparking_space': 1,
#              '872f5a326ffffffbank': 0,
#              '872f5a326ffffffclinic': 0,
#              '872f5a326ffffffplace_of_worship': 11,
#              '872f5a326ffffffresearch_institute': 0,
#              '872f5a34dffffffrestaurant': 124,
#              '872f5a34dfffffflibrary': 2,
#              '872f5a34dffffffatm': 2,
#              '872f5a34dffffffvending_machine': 22,
#              '872f5a34dffffffbench': 10,
#              '872f5a34dffffffparking_space': 0,
#              '872f5a34dffffffbank': 12,
#              '872f5a34dffffffclinic': 8,
#              '872f5a34dffffffplace_of_worship': 10,
#              '872f5a34dffffffresearch_institute': 0,
#              '872f5bdb6ffffffrestaurant': 13,
#              '872f5bdb6fffffflibrary': 0,
#              '872f5bdb6ffffffatm': 1,
#              '872f5bdb6ffffffvending_machine': 2,
#              '872f5bdb6ffffffbench': 9,
#              '872f5bdb6ffffffparking_space': 6,
#              '872f5bdb6ffffffbank': 5,
#              '872f5bdb6ffffffclinic': 0,
#              '872f5bdb6ffffffplace_of_worship': 18,
#              '872f5bdb6ffffffresearch_institute': 0,
#              '872f5a30dffffffrestaurant': 50,
#              '872f5a30dfffffflibrary': 2,
#              '872f5a30dffffffatm': 1,
#              '872f5a30dffffffvending_machine': 108,
#              '872f5a30dffffffbench': 30,
#              '872f5a30dffffffparking_space': 0,
#              '872f5a30dffffffbank': 8,
#              '872f5a30dffffffclinic': 7,
#              '872f5a30dffffffplace_of_worship': 35,
#              '872f5a30dffffffresearch_institute': 0,
#              '872f5bc15ffffffrestaurant': 15,
#              '872f5bc15fffffflibrary': 0,
#              '872f5bc15ffffffatm': 2,
#              '872f5bc15ffffffvending_machine': 2,
#              '872f5bc15ffffffbench': 6,
#              '872f5bc15ffffffparking_space': 0,
#              '872f5bc15ffffffbank': 2,
#              '872f5bc15ffffffclinic': 0,
#              '872f5bc15ffffffplace_of_worship': 6,
#              '872f5bc15ffffffresearch_institute': 0,
#              '872f5a333ffffffrestaurant': 53,
#              '872f5a333fffffflibrary': 1,
#              '872f5a333ffffffatm': 1,
#              '872f5a333ffffffvending_machine': 6,
#              '872f5a333ffffffbench': 0,
#              '872f5a333ffffffparking_space': 0,
#              '872f5a333ffffffbank': 6,
#              '872f5a333ffffffclinic': 3,
#              '872f5a333ffffffplace_of_worship': 16,
#              '872f5a333ffffffresearch_institute': 0,
#              '872f5a350ffffffrestaurant': 15,
#              '872f5a350fffffflibrary': 1,
#              '872f5a350ffffffatm': 2,
#              '872f5a350ffffffvending_machine': 4,
#              '872f5a350ffffffbench': 0,
#              '872f5a350ffffffparking_space': 0,
#              '872f5a350ffffffbank': 3,
#              '872f5bd94ffffffrestaurant': 7,
#              '872f5bd94fffffflibrary': 1,
#              '872f5bd94ffffffatm': 1,
#              '872f5bd94ffffffvending_machine': 0,
#              '872f5bd94ffffffbench': 19,
#              '872f5bd94ffffffparking_space': 0,
#              '872f5bd94ffffffbank': 5,
#              '872f5bd94ffffffclinic': 1,
#              '872f5bd94ffffffplace_of_worship': 11,
#              '872f5bd94ffffffresearch_institute': 0,
#              ...})

# %%
h3_cells
# Out:
# {'872f5a323ffffff': {'restaurant': 18,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 35,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  '872f5a32affffff': {'restaurant': 127,
#   'library': 4,
#   'atm': 8,
#   'vending_machine': 52,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 10,
#   'clinic': 8,
#   'place_of_worship': 50,
#   'research_institute': 0},
#  '872f5a305ffffff': {'restaurant': 69,
#   'library': 4,
#   'atm': 4,
#   'vending_machine': 26,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 7,
#   'clinic': 9,
#   'place_of_worship': 14,
#   'research_institute': 0},
#  '872f5aaddffffff': {'restaurant': 108,
#   'library': 3,
#   'atm': 4,
#   'vending_machine': 7,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 3,
#   'place_of_worship': 29,
#   'research_institute': 0},
#  '872f5a331ffffff': {'restaurant': 56,
#   'library': 3,
#   'atm': 6,
#   'vending_machine': 1,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 8,
#   'place_of_worship': 22,
#   'research_institute': 0},
#  '872f5a329ffffff': {'restaurant': 344,
#   'library': 1,
#   'atm': 26,
#   'vending_machine': 261,
#   'bench': 79,
#   'parking_space': 1,
#   'bank': 13,
#   'clinic': 9,
#   'place_of_worship': 32,
#   'research_institute': 0},
#  '872f5aac8ffffff': {'restaurant': 48,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 8,
#   'bench': 16,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 10,
#   'research_institute': 0},
#  '872f5a370ffffff': {'restaurant': 150,
#   'library': 2,
#   'atm': 12,
#   'vending_machine': 17,
#   'bench': 52,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 2,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5a322ffffff': {'restaurant': 21,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5a375ffffff': {'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  '872f5a36cffffff': {'restaurant': 30,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 2,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 0,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  '872f5aaceffffff': {'restaurant': 106,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 9,
#   'bench': 30,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 3,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5aad8ffffff': {'restaurant': 458,
#   'library': 4,
#   'atm': 7,
#   'vending_machine': 48,
#   'bench': 38,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 6,
#   'place_of_worship': 36,
#   'research_institute': 0},
#  '872f5a360ffffff': {'restaurant': 132,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 3,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5a366ffffff': {'restaurant': 74,
#   'library': 1,
#   'atm': 5,
#   'vending_machine': 26,
#   'bench': 43,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5bc8bffffff': {'restaurant': 14,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 1,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5a328ffffff': {'restaurant': 800,
#   'library': 6,
#   'atm': 18,
#   'vending_machine': 777,
#   'bench': 207,
#   'parking_space': 0,
#   'bank': 31,
#   'clinic': 31,
#   'place_of_worship': 56,
#   'research_institute': 0},
#  '872f5a31cffffff': {'restaurant': 37,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 8,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 27,
#   'research_institute': 0},
#  '872f5a373ffffff': {'restaurant': 40,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 3,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  '872f5a35effffff': {'restaurant': 28,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 13,
#   'bench': 17,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 5,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  '872f5aac9ffffff': {'restaurant': 88,
#   'library': 1,
#   'atm': 5,
#   'vending_machine': 1,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 11,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  '872f5bc16ffffff': {'restaurant': 17,
#   'library': 1,
#   'atm': 3,
#   'vending_machine': 26,
#   'bench': 6,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 4,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5a376ffffff': {'restaurant': 57,
#   'library': 4,
#   'atm': 6,
#   'vending_machine': 59,
#   'bench': 42,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5a324ffffff': {'restaurant': 12,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 1,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5a309ffffff': {'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  '872f5bd90ffffff': {'restaurant': 33,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 13,
#   'bench': 11,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 2,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  '872f5a34cffffff': {'restaurant': 101,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 10,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5a344ffffff': {'restaurant': 312,
#   'library': 2,
#   'atm': 9,
#   'vending_machine': 56,
#   'bench': 31,
#   'parking_space': 1,
#   'bank': 23,
#   'clinic': 5,
#   'place_of_worship': 31,
#   'research_institute': 0},
#  '872f5bc9affffff': {'restaurant': 5,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5aad3ffffff': {'restaurant': 141,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 11,
#   'bench': 37,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 4,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  '872f5a362ffffff': {'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  '872f5aac1ffffff': {'restaurant': 50,
#   'library': 0,
#   'atm': 6,
#   'vending_machine': 4,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5a32effffff': {'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  '872f5a343ffffff': {'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5a325ffffff': {'restaurant': 18,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 5,
#   'bench': 0,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5bc82ffffff': {'restaurant': 46,
#   'library': 4,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 7,
#   'place_of_worship': 3,
#   'research_institute': 1},
#  '872f5a30cffffff': {'restaurant': 51,
#   'library': 4,
#   'atm': 1,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 2,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5bc89ffffff': {'restaurant': 24,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 10,
#   'bench': 7,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 2,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  '872f5bcb0ffffff': {'restaurant': 10,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  '872f5a26dffffff': {'restaurant': 18,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 11,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 4,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5a32bffffff': {'restaurant': 98,
#   'library': 5,
#   'atm': 2,
#   'vending_machine': 26,
#   'bench': 148,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 6,
#   'place_of_worship': 60,
#   'research_institute': 0},
#  '872f5bcc1ffffff': {'restaurant': 28,
#   'library': 0,
#   'atm': 3,
#   'vending_machine': 30,
#   'bench': 1,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 1,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  '872f5aadbffffff': {'restaurant': 151,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 37,
#   'bench': 69,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 0,
#   'place_of_worship': 23,
#   'research_institute': 0},
#  '872f5a334ffffff': {'restaurant': 64,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  '872f5aad2ffffff': {'restaurant': 67,
#   'library': 2,
#   'atm': 5,
#   'vending_machine': 26,
#   'bench': 96,
#   'parking_space': 14,
#   'bank': 0,
#   'clinic': 3,
#   'place_of_worship': 34,
#   'research_institute': 0},
#  '872f5a364ffffff': {'restaurant': 217,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 43,
#   'bench': 27,
#   'parking_space': 2,
#   'bank': 6,
#   'clinic': 8,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5a345ffffff': {'restaurant': 183,
#   'library': 3,
#   'atm': 5,
#   'vending_machine': 3,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 1,
#   'place_of_worship': 17,
#   'research_institute': 0},
#  '872f5a340ffffff': {'restaurant': 59,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 2,
#   'bench': 1,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  '872f5a346ffffff': {'restaurant': 48,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 5,
#   'bench': 20,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  '872f5a326ffffff': {'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5a34dffffff': {'restaurant': 124,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 22,
#   'bench': 10,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 8,
#   'place_of_worship': 10,
#   'research_institute': 0},
#  '872f5bdb6ffffff': {'restaurant': 13,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 2,
#   'bench': 9,
#   'parking_space': 6,
#   'bank': 5,
#   'clinic': 0,
#   'place_of_worship': 18,
#   'research_institute': 0},
#  '872f5a30dffffff': {'restaurant': 50,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 108,
#   'bench': 30,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 7,
#   'place_of_worship': 35,
#   'research_institute': 0},
#  '872f5bc15ffffff': {'restaurant': 15,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 2,
#   'bench': 6,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  '872f5a333ffffff': {'restaurant': 53,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 6,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  '872f5a350ffffff': {'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5a269ffffff': {'restaurant': 4,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 11,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5a354ffffff': {'restaurant': 22,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 21,
#   'bench': 3,
#   'parking_space': 0,
#   'bank': 7,
#   'clinic': 3,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  '872f5b529ffffff': {'restaurant': 23,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 4,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5aacaffffff': {'restaurant': 129,
#   'library': 2,
#   'atm': 8,
#   'vending_machine': 24,
#   'bench': 18,
#   'parking_space': 1,
#   'bank': 9,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5bc1affffff': {'restaurant': 0,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  '872f5a363ffffff': {'restaurant': 38,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 9,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 3,
#   'place_of_worship': 10,
#   'research_institute': 0},
#  '872f5a365ffffff': {'restaurant': 116,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 13,
#   'clinic': 0,
#   'place_of_worship': 17,
#   'research_institute': 0},
#  '872f5bc90ffffff': {'restaurant': 24,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  '872f5a320ffffff': {'restaurant': 21,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 1,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5a303ffffff': {'restaurant': 44,
#   'library': 1,
#   'atm': 3,
#   'vending_machine': 2,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 5,
#   'place_of_worship': 18,
#   'research_institute': 0},
#  '872f5aadcffffff': {'restaurant': 218,
#   'library': 3,
#   'atm': 10,
#   'vending_machine': 79,
#   'bench': 97,
#   'parking_space': 0,
#   'bank': 13,
#   'clinic': 2,
#   'place_of_worship': 14,
#   'research_institute': 0},
#  '872f5a372ffffff': {'restaurant': 195,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 7,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 28,
#   'clinic': 3,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  '872f5bc8dffffff': {'restaurant': 10,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 3,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  '872f5a32cffffff': {'restaurant': 310,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 414,
#   'bench': 80,
#   'parking_space': 0,
#   'bank': 15,
#   'clinic': 3,
#   'place_of_worship': 21,
#   'research_institute': 0},
#  '872f5bcb1ffffff': {'restaurant': 20,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 2,
#   'bench': 15,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5a32dffffff': {'restaurant': 538,
#   'library': 2,
#   'atm': 27,
#   'vending_machine': 226,
#   'bench': 67,
#   'parking_space': 7,
#   'bank': 50,
#   'clinic': 15,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  '872f5aad9ffffff': {'restaurant': 382,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 39,
#   'bench': 13,
#   'parking_space': 2,
#   'bank': 13,
#   'clinic': 11,
#   'place_of_worship': 21,
#   'research_institute': 0},
#  '872f5a321ffffff': {'restaurant': 132,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 69,
#   'bench': 28,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 2,
#   'place_of_worship': 24,
#   'research_institute': 0},
#  '872f5aadeffffff': {'restaurant': 488,
#   'library': 2,
#   'atm': 14,
#   'vending_machine': 23,
#   'bench': 85,
#   'parking_space': 0,
#   'bank': 35,
#   'clinic': 8,
#   'place_of_worship': 25,
#   'research_institute': 0},
#  '872f5aad1ffffff': {'restaurant': 49,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 4,
#   'bench': 10,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  '872f5bc10ffffff': {'restaurant': 18,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  '872f5a335ffffff': {'restaurant': 11,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  '872f5bca8ffffff': {'restaurant': 23,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 2,
#   'place_of_worship': 1,
#   'research_institute': 0},
#  '872f5aaccffffff': {'restaurant': 41,
#   'library': 3,
#   'atm': 8,
#   'vending_machine': 38,
#   'bench': 18,
#   'parking_space': 4,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  '872f5a371ffffff': {'restaurant': 126,
#   'library': 4,
#   'atm': 6,
#   'vending_machine': 27,
#   'bench': 19,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 2,
#   'place_of_worship': 33,
#   'research_institute': 0},
#  '872f5bd98ffffff': {'restaurant': 42,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 6,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 14,
#   'place_of_worship': 10,
#   'research_institute': 0},
#  '872f5bcabffffff': {'restaurant': 5,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5bcb4ffffff': {'restaurant': 48,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 16,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 3,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  '872f5bcb5ffffff': {'restaurant': 42,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 14,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  '872f5aacbffffff': {'restaurant': 24,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 5,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  '872f5a361ffffff': {'restaurant': 86,
#   'library': 2,
#   'atm': 10,
#   'vending_machine': 5,
#   'bench': 15,
#   'parking_space': 0,
#   'bank': 9,
#   'clinic': 1,
#   'place_of_worship': 22,
#   'research_institute': 0},
#  '872f5bd96ffffff': {'restaurant': 25,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  '872f5aae9ffffff': {'restaurant': 46,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 35,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5a374ffffff': {'restaurant': 153,
#   'library': 5,
#   'atm': 6,
#   'vending_machine': 45,
#   'bench': 8,
#   'parking_space': 1,
#   'bank': 8,
#   'clinic': 4,
#   'place_of_worship': 42,
#   'research_institute': 0},
#  '872f5a30effffff': {'restaurant': 20,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5a330ffffff': {'restaurant': 42,
#   'library': 1,
#   'atm': 3,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 9,
#   'clinic': 1,
#   'place_of_worship': 24,
#   'research_institute': 0},
#  '872f5a301ffffff': {'restaurant': 30,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 2,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 8,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5bc9effffff': {'restaurant': 18,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 0,
#   'research_institute': 0},
#  '872f5bcceffffff': {'restaurant': 1,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 14,
#   'bench': 27,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  '872f5a368ffffff': {'restaurant': 75,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 5,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 5,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  '872f5aacdffffff': {'restaurant': 19,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 19,
#   'parking_space': 1,
#   'bank': 4,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5a36effffff': {'restaurant': 72,
#   'library': 2,
#   'atm': 8,
#   'vending_machine': 8,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 4,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5bd92ffffff': {'restaurant': 70,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 9,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 2,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  '872f5bd94ffffff': {'restaurant': 7,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 19,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5a300ffffff': {'restaurant': 55,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 0,
#   'bench': 1,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 6,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5aa98ffffff': {'restaurant': 23,
#   'library': 1,
#   'atm': 5,
#   'vending_machine': 0,
#   'bench': 11,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 6,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  '872f5a308ffffff': {'restaurant': 46,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 505,
#   'bench': 17,
#   'parking_space': 0,
#   'bank': 9,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  '872f5bcb3ffffff': {'restaurant': 14,
#   'library': 1,
#   'atm': 4,
#   'vending_machine': 2,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  '872f5a34bffffff': {'restaurant': 6,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  '872f5a31dffffff': {'restaurant': 13,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 3,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  '872f5aaecffffff': {'restaurant': 14,
#   'library': 0,
#   'atm': 4,
#   'vending_machine': 6,
#   'bench': 32,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 0,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  '872f5a304ffffff': {'restaurant': 44,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 6,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  '872f5aaeaffffff': {'restaurant': 75,
#   'library': 2,
#   'atm': 13,
#   'vending_machine': 44,
#   'bench': 34,
#   'parking_space': 2,
#   'bank': 9,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5aae8ffffff': {'restaurant': 60,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 50,
#   'bench': 23,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 5,
#   'place_of_worship': 14,
#   'research_institute': 0},
#  '872f5bcb2ffffff': {'restaurant': 25,
#   'library': 0,
#   'atm': 3,
#   'vending_machine': 26,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 0,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  '872f5bc18ffffff': {'restaurant': 11,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 8,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  '872f5aaebffffff': {'restaurant': 52,
#   'library': 1,
#   'atm': 4,
#   'vending_machine': 40,
#   'bench': 22,
#   'parking_space': 3,
#   'bank': 6,
#   'clinic': 1,
#   'place_of_worship': 27,
#   'research_institute': 0},
#  '872f5a341ffffff': {'restaurant': 94,
#   'library': 3,
#   'atm': 1,
#   'vending_machine': 2,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 9,
#   'clinic': 3,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5a35cffffff': {'restaurant': 26,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 2,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 5,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  '872f5b56affffff': {'restaurant': 1,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 0,
#   'research_institute': 0},
#  '872f5aac3ffffff': {'restaurant': 44,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 25,
#   'bench': 10,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 2,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  '872f5aa99ffffff': {'restaurant': 19,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 1,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  '872f5aa8bffffff': {'restaurant': 8,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5bcddffffff': {'restaurant': 8,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 78,
#   'bench': 29,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5a348ffffff': {'restaurant': 20,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 4,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 3,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  '872f5a36affffff': {'restaurant': 61,
#   'library': 1,
#   'atm': 4,
#   'vending_machine': 1,
#   'bench': 21,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 7,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5b509ffffff': {'restaurant': 20,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 7,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 5,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  '872f5a355ffffff': {'restaurant': 28,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 2,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5bc83ffffff': {'restaurant': 55,
#   'library': 1,
#   'atm': 3,
#   'vending_machine': 3,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 7,
#   'clinic': 12,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  '872f5bdb2ffffff': {'restaurant': 49,
#   'library': 1,
#   'atm': 6,
#   'vending_machine': 15,
#   'bench': 13,
#   'parking_space': 7,
#   'bank': 5,
#   'clinic': 4,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  '872f5aadaffffff': {'restaurant': 216,
#   'library': 3,
#   'atm': 8,
#   'vending_machine': 33,
#   'bench': 22,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  '872f5aa8affffff': {'restaurant': 30,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  '872f5bcb6ffffff': {'restaurant': 38,
#   'library': 3,
#   'atm': 4,
#   'vending_machine': 20,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 4,
#   'place_of_worship': 4,
#   'research_institute': 0}}

# %%
h3_cell_counts = copy.deepcopy(h3_cells)

for hex_id in h3_cells:
    for key in coefficents:
        h3_cells[hex_id][key] / max(1, totals[hex_id+key])
print('4')

def _housing(url):
    shit = get_lat_long(url)
    lat = shit[0]
    lng = shit[1]
    h3_cell_id = h3.geo_to_h3(lat, lng, resolution=7)
    _coefficents = {}
    ret = {
        'url': url,
        'location': shit,
        'h3_cell': h3_cell_id,  
        'coefficents': _coefficents
    }
    total = 0
    for key in coefficents: total += h3_cells[h3_cell_id][key]
    for key in coefficents: ret['coefficents'][key] = h3_cells[h3_cell_id][key] / total
    return ret 
print('5')

def key_function(apt, preferences_poi, idx):
    dist = 0
    for key in apt['coefficents']:
        dist += apt['coefficents'][key] - preferences_poi[key][idx]
    return dist
print('6')
_houses = [_housing(url) for url in all_houses]
for idx, person in enumerate(people_names):
    people_housing_list[person] = sorted(_houses, key=lambda apt: key_function(apt, preferences, idx))
print('7')
for person in people_housing_list:
    order = people_housing_list[person]
    #make sure each house is in walking distance 30 minutes or train 30 minutes from each other
#for ranked_list in sorted
#10 * 10 coefficents -> grid of checkboxes 
reports = []
for idx, person in enumerate(people_names):
    reasoning_explanation = ''
    house = people_housing_list[person][0]
    most = sorted(house['coefficents'].items(), key=lambda _: _[1])[-1]
    #max_key = max(house['coefficents'].values(), key=house['coefficents'].values().get)
    print(most)
    max_key = most
    num_studios = h3_cell_counts[house['h3_cell']][max_key[0]]
    reasoning_explanation += f'you selected {max_key[0]} as the most important and there are {num_studios} studios in that region :)'
    report = {
        'name': person,
        'house_suggestion':people_housing_list[person][0]['url'] ,
        'reasoning_explanation': reasoning_explanation,
    }
#     for hex_id in h3_cells:
#         for key in coefficents:
#             report[key] = f'you listed {key} as very important and there are  {h3_cell_counts[hex_id][key]} within a 4 kilometer radius'
    reports.append(report)
reports


#for each person -> strongest 2-3  preference get a custom sentence w/o generation
#
# Out:
# 4
# 5
# 6
# 7
# ('restaurant', 0.4490861618798956)
# ('vending_machine', 0.3105263157894737)
# ('restaurant', 0.3333333333333333)
# ('restaurant', 0.7520525451559934)
# ('bench', 0.44871794871794873)
# ('bench', 0.44871794871794873)
# ('restaurant', 0.4864864864864865)
# ('restaurant', 0.3333333333333333)
# ('restaurant', 0.3333333333333333)
# ('bench', 0.44871794871794873)
# [{'name': 'fred',
#   'house_suggestion': 'https://www.airbnb.com/rooms/1306664',
#   'reasoning_explanation': 'you selected restaurant as the most important and there are 344 studios in that region :)'},
#  {'name': 'bob',
#   'house_suggestion': 'https://www.airbnb.com/rooms/3572139',
#   'reasoning_explanation': 'you selected vending_machine as the most important and there are 59 studios in that region :)'},
#  {'name': 'sally',
#   'house_suggestion': 'https://www.airbnb.com/rooms/15568640',
#   'reasoning_explanation': 'you selected restaurant as the most important and there are 52 studios in that region :)'},
#  {'name': 'panda',
#   'house_suggestion': 'https://www.airbnb.com/rooms/2027932',
#   'reasoning_explanation': 'you selected restaurant as the most important and there are 458 studios in that region :)'},
#  {'name': 'velma',
#   'house_suggestion': 'https://www.airbnb.com/rooms/197677',
#   'reasoning_explanation': 'you selected bench as the most important and there are 35 studios in that region :)'},
#  {'name': 'gis',
#   'house_suggestion': 'https://www.airbnb.com/rooms/197677',
#   'reasoning_explanation': 'you selected bench as the most important and there are 35 studios in that region :)'},
#  {'name': 'mercator',
#   'house_suggestion': 'https://www.airbnb.com/rooms/4690684',
#   'reasoning_explanation': 'you selected restaurant as the most important and there are 18 studios in that region :)'},
#  {'name': 'machester',
#   'house_suggestion': 'https://www.airbnb.com/rooms/9575725',
#   'reasoning_explanation': 'you selected restaurant as the most important and there are 5 studios in that region :)'},
#  {'name': 'last',
#   'house_suggestion': 'https://www.airbnb.com/rooms/9575725',
#   'reasoning_explanation': 'you selected restaurant as the most important and there are 5 studios in that region :)'},
#  {'name': 'day',
#   'house_suggestion': 'https://www.airbnb.com/rooms/197677',
#   'reasoning_explanation': 'you selected bench as the most important and there are 35 studios in that region :)'}]

# %%
# Out:
# [('research_institute', 0.0),
#  ('library', 0.0013054830287206266),
#  ('parking_space', 0.0013054830287206266),
#  ('clinic', 0.01174934725848564),
#  ('bank', 0.016971279373368148),
#  ('atm', 0.033942558746736295),
#  ('place_of_worship', 0.04177545691906005),
#  ('bench', 0.1031331592689295),
#  ('vending_machine', 0.34073107049608353),
#  ('restaurant', 0.4490861618798956)]

# %%
[i for i in totals.values() if i == 0]
# Out:
# [0, 0, 0, 0]

# %%
people_housing_list['day']
# Out:
# [{'url': 'https://www.airbnb.com/rooms/16874184',
#   'location': [35.72295, 139.16195],
#   'h3_cell': '872f5b56affffff',
#   'restaurant': 1,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 0,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6194398',
#   'location': [35.59473, 139.40901000000002],
#   'h3_cell': '872f5bc1affffff',
#   'restaurant': 0,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3920124',
#   'location': [35.765390000000004, 139.44681],
#   'h3_cell': '872f5bc9affffff',
#   'restaurant': 5,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5876019',
#   'location': [35.765440000000005, 139.44477],
#   'h3_cell': '872f5bc9affffff',
#   'restaurant': 5,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/13566615',
#   'location': [35.751059999999995, 139.55189],
#   'h3_cell': '872f5a34bffffff',
#   'restaurant': 6,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/17530826',
#   'location': [35.67323, 139.85308999999998],
#   'h3_cell': '872f5aa8bffffff',
#   'restaurant': 8,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/9575725',
#   'location': [35.65767, 139.41636],
#   'h3_cell': '872f5bcabffffff',
#   'restaurant': 5,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/9995809',
#   'location': [35.65892, 139.4178],
#   'h3_cell': '872f5bcabffffff',
#   'restaurant': 5,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7322455',
#   'location': [35.66482, 139.40948999999998],
#   'h3_cell': '872f5bc8dffffff',
#   'restaurant': 10,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench':

#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/15994829',
#   'location': [35.74582, 139.86126000000002],
#   'h3_cell': '872f5a335ffffff',
#   'restaurant': 11,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/16193467',
#   'location': [35.63223, 139.6538],
#   'h3_cell': '872f5bd96ffffff',
#   'restaurant': 25,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/17945185',
#   'location': [35.72818, 139.57533],
#   'h3_cell': '872f5a348ffffff',
#   'restaurant': 20,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 4,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 3,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/17949579',
#   'location': [35.72636, 139.57535],
#   'h3_cell': '872f5a348ffffff',
#   'restaurant': 20,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 4,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 3,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/18082452',
#   'location': [35.72728, 139.57584],
#   'h3_cell': '872f5a348ffffff',
#   'restaurant': 20,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 4,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 3,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4690684',
#   'location': [35.75851, 139.47982],
#   'h3_cell': '872f5a26dffffff',
#   'restaurant': 18,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 11,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 4,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5719870',
#   'location': [35.71679, 139.85669],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5963368',
#   'location': [35.764359999999996, 139.6698],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6172827',
#   'location': [35.71306, 139.85558999999998],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6595315',
#   'location': [35.71432, 139.8557],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7038511',
#   'location': [35.764559999999996, 139.67015],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7038739',
#   'location': [35.76455, 139.66828999999998],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7170836',
#   'location': [35.72358, 139.85843],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7911710',
#   'location': [35.76123, 139.68315],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7940713',
#   'location': [35.763000000000005, 139.66878],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/10505175',
#   'location': [35.76313, 139.66853],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4222643',
#   'location': [35.6806, 139.81931],
#   'h3_cell': '872f5a325ffffff',
#   'restaurant': 18,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 5,
#   'bench': 0,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6785470',
#   'location': [35.72576, 139.50954],
#   'h3_cell': '872f5bc90ffffff',
#   'restaurant': 24,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/14971432',
#   'location': [35.68755, 139.83363],
#   'h3_cell': '872f5a325ffffff',
#   'restaurant': 18,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 5,
#   'bench': 0,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/17482160',
#   'location': [35.70511, 139.8814],
#   'h3_cell': '872f5aa99ffffff',
#   'restaurant': 19,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 1,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/8450948',
#   'location': [35.59061, 139.46899],
#   'h3_cell': '872f5bc10ffffff',
#   'restaurant': 18,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/18273940',
#   'location': [35.73937, 139.6734],
#   'h3_cell': '872f5a355ffffff',
#   'restaurant': 28,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 2,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/18897893',
#   'location': [35.5902, 139.4691],
#   'h3_cell': '872f5bc10ffffff',
#   'restaurant': 18,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 1,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/7057399',
#   'location': [35.70339, 139.84253],
#   'h3_cell': '872f5a320ffffff',
#   'restaurant': 21,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 1,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/

#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 27,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3021731',
#   'location': [35.72097, 139.69196000000002],
#   'h3_cell': '872f5a373ffffff',
#   'restaurant': 40,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 3,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3235958',
#   'location': [35.78156, 139.63308999999998],
#   'h3_cell': '872f5a35effffff',
#   'restaurant': 28,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 13,
#   'bench': 17,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 5,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3265059',
#   'location': [35.738620000000004, 139.8515],
#   'h3_cell': '872f5a331ffffff',
#   'restaurant': 56,
#   'library': 3,
#   'atm': 6,
#   'vending_machine': 1,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 8,
#   'place_of_worship': 22,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3339222',
#   'location': [35.78116, 139.63145],
#   'h3_cell': '872f5a35effffff',
#   'restaurant': 28,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 13,
#   'bench': 17,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 5,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3372902',
#   'location': [35.61728, 139.6679],
#   'h3_cell': '872f5aac9ffffff',
#   'restaurant': 88,
#   'library': 1,
#   'atm': 5,
#   'vending_machine': 1,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 11,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3409030',
#   'location': [35.69746, 139.70058],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3514008',
#   'location': [35.72672, 139.78201],
#   'h3_cell': '872f5a32affffff',
#   'restaurant': 127,
#   'library': 4,
#   'atm': 8,
#   'vending_machine': 52,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 10,
#   'clinic': 8,
#   'place_of_worship': 50,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3563698',
#   'location': [35.58911, 139.48023],
#   'h3_cell': '872f5bc16ffffff',
#   'restaurant': 17,
#   'library': 1,
#   'atm': 3,
#   'vending_machine': 26,
#   'bench': 6,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 4,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3572139',
#   'location': [35.72784, 139.73408],
#   'h3_cell': '872f5a376ffffff',
#   'restaurant': 57,
#   'library': 4,
#   'atm': 6,
#   'vending_machine': 59,
#   'bench': 42,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3606276',
#   'location': [35.67276, 139.65976],
#   'h3_cell': '872f5a360ffffff',
#   'restaurant': 132,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 3,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3623844',
#   'location': [35.68358, 139.85985],
#   'h3_cell': '872f5a324ffffff',
#   'restaurant': 12,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 1,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3689244',
#   'location': [35.67205, 139.67877],
#   'h3_cell': '872f5a360ffffff',
#   'restaurant': 132,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 3,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3744742',
#   'location': [35.76105, 139.716],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/3775528',
#   'location': [35.62942, 139.63076999999998],
#   'h3_cell': '872f5bd90ffffff',
#   'restaurant': 33,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 13,
#   'bench': 11,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 2,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3793206',
#   'location': [35.69847, 139.70432],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3793412',
#   'location': [35.698479999999996, 139.70432],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3814258',
#   'location': [35.70293, 139.60045],
#   'h3_cell': '872f5a34cffffff',
#   'restaurant': 101,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 10,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3838856',
#   'location': [35.68245, 139.69009],
#   'h3_cell': '872f5a366ffffff',
#   'restaurant': 74,
#   'library': 1,
#   'atm': 5,
#   'vending_machine': 26,
#   'bench': 43,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3845889',
#   'location': [35.706790000000005, 139.6551],
#   'h3_cell': '872f5a344ffffff',
#   'restaurant': 312,
#   'library': 2,
#   'atm': 9,
#   'vending_machine': 56,
#   'bench': 31,
#   'parking_space': 1,
#   'bank': 23,
#   'clinic': 5,
#   'place_of_worship': 31,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3846001',
#   'location': [35.70686, 139.65543],
#   'h3_cell': '872f5a344ffffff',
#   'restaurant': 312,
#   'library': 2,
#   'atm': 9,
#   'vending_machine': 56,
#   'bench': 31,
#   'parking_space': 1,
#   'bank': 23,
#   'clinic': 5,
#   'place_of_worship': 31,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3871442',
#   'location': [35.703990000000005, 139.59775],
#   'h3_cell': '872f5a34cffffff',
#   'restaurant': 101,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 10,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3886601',
#   'location': [35.64991, 139.72204],
#   'h3_cell': '872f5aaddffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 4,
#   'vending_machine': 7,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 3,
#   'place_of_worship': 29,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3920124',
#   'location': [35.765390000000004, 139.44681],
#   'h3_cell': '872f5bc9affffff',
#   'restaurant': 5,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3925416',
#   'location': [35.68577, 139.78368],
#   'h3_cell': '872f5aad3ffffff',
#   'restaurant': 141,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 11,
#   'bench': 37,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 4,
#   'place_of_worship': 13,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/3956263',
#   'location': [35.678129999999996, 139.67913000000001],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4026948',
#   'location': [35.60033, 139.73415],
#   'h3_cell': '872f5aac1ffffff',
#   'restaurant': 50,
#   'library': 0,
#   'atm': 6,
#   'vending_machine': 4,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4047596',
#   'location': [35.626329999999996, 139.7235],
#   'h3_cell': '872f5aaceffffff',
#   'restaurant': 106,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 9,
#   'bench': 30,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 3,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4050925',
#   'location': [35.71433, 139.79878],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4141228',
#   'location': [35.73417, 139.63328],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4222643',
#   'location': [35.6806, 139.81931],
#   'h3_cell': '872f5a325ffffff',
#   'restaurant': 18,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 5,
#   'bench': 0,
#   'parking_space': 1,
#   'bank': 2,
#   'clinic': 2,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4360718',
#   'location': [35.760940000000005, 139.71652],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/4388283',
#   'location': [35.70919, 139.48074],
#   'h3_cell': '872f5bc82ffffff',
#   'restaurant': 46,
#   'library': 4,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 7,
#   'place_of_worship': 3,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/4396219',
#   'location': [35.703990000000005, 139.59775],
#   'h3_cell': '872f5a34cffffff',
#   'restaurant': 101,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 10,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4396221',
#   'location': [35.703990000000005, 139.59775],
#   'h3_cell': '872f5a34cffffff',
#   'restaurant': 101,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 10,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4471946',
#   'location': [35.74576, 139.75222],
#   'h3_cell': '872f5a30cffffff',
#   'restaurant': 51,
#   'library': 4,
#   'atm': 1,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 2,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4495014',
#   'location': [35.761109999999995, 139.71576000000002],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/4540924',
#   'location': [35.68587, 139.39428],
#   'h3_cell': '872f5bc89ffffff',
#   'restaurant': 24,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 10,
#   'bench': 7,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 2,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4606903',
#   'location': [35.68002, 139.53689],
#   'h3_cell': '872f5bcb0ffffff',
#   'restaurant': 10,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4616579',
#   'location': [35.734140000000004, 139.63305],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4673248',
#   'location': [35.6818, 139.53855],
#   'h3_cell': '872f5bcb0ffffff',
#   'restaurant': 10,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4690684',
#   'location': [35.75851, 139.47982],
#   'h3_cell': '872f5a26dffffff',
#   'restaurant': 18,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 11,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 4,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4750169',
#   'location': [35.68441, 139.39461],
#   'h3_cell': '872f5bc89ffffff',
#   'restaurant': 24,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 10,
#   'bench': 7,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 2,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4813245',
#   'location': [35.73055, 139.68657],
#   'h3_cell': '872f5a373ffffff',
#   'restaurant': 40,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 3,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4817291',
#   'location': [35.72804, 139.79048],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4825779',
#   'location': [35.677479999999996, 139.68059],
#   'h3_cell': '872f5a366ffffff',
#   'restaurant': 74,
#   'library': 1,
#   'atm': 5,
#   'vending_machine': 26,
#   'bench': 43,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4827373',
#   'location': [35.6929, 139.67914],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4834215',
#   'location': [35.722390000000004, 139.76273],
#   'h3_cell': '872f5a32bffffff',
#   'restaurant': 98,
#   'library': 5,
#   'atm': 2,
#   'vending_machine': 26,
#   'bench': 148,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 6,
#   'place_of_worship': 60,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4849854',
#   'location': [35.63738, 139.2863],
#   'h3_cell': '872f5bcc1ffffff',
#   'restaurant': 28,
#   'library': 0,
#   'atm': 3,
#   'vending_machine': 30,
#   'bench': 1,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 1,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4888140',
#   'location': [35.76117, 139.71597],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/4909611',
#   'location': [35.73796, 139.85163],
#   'h3_cell': '872f5a331ffffff',
#   'restaurant': 56,
#   'library': 3,
#   'atm': 6,
#   'vending_machine': 1,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 8,
#   'place_of_worship': 22,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4917347',
#   'location': [35.73816, 139.85173999999998],
#   'h3_cell': '872f5a331ffffff',
#   'restaurant': 56,
#   'library': 3,
#   'atm': 6,
#   'vending_machine': 1,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 8,
#   'place_of_worship': 22,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4925503',
#   'location': [35.67923, 139.67571],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4925745',
#   'location': [35.72951, 139.79137],
#   'h3_cell': '872f5a305ffffff',
#   'restaurant': 69,
#   'library': 4,
#   'atm': 4,
#   'vending_machine': 26,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 7,
#   'clinic': 9,
#   'place_of_worship': 14,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4926317',
#   'location': [35.680679999999995, 139.6753],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4926426',
#   'location': [35.67933, 139.67511000000002],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4951604',
#   'location': [35.67129, 139.71021000000002],
#   'h3_cell': '872f5aadbffffff',
#   'restaurant': 151,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 37,
#   'bench': 69,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 0,
#   'place_of_worship': 23,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/4958750',
#   'location': [35.73673, 139.88586],
#   'h3_cell': '872f5a334ffffff',
#   'restaurant': 64,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5070495',
#   'location': [35.73496, 139.63132],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5080877',
#   'location': [35.68162, 139.81859],
#   'h3_cell': '872f5aad2ffffff',
#   'restaurant': 67,
#   'library': 2,
#   'atm': 5,
#   'vending_machine': 26,
#   'bench': 96,
#   'parking_space': 14,
#   'bank': 0,
#   'clinic': 3,
#   'place_of_worship': 34,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5128293',
#   'location': [35.69872, 139.70276],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5198467',
#   'location': [35.72129, 139.76323],
#   'h3_cell': '872f5a32bffffff',
#   'restaurant': 98,
#   'library': 5,
#   'atm': 2,
#   'vending_machine': 26,
#   'bench': 148,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 6,
#   'place_of_worship': 60,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5210118',
#   'location': [35.66339, 139.68741],
#   'h3_cell': '872f5a364ffffff',
#   'restaurant': 217,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 43,
#   'bench': 27,
#   'parking_space': 2,
#   'bank': 6,
#   'clinic': 8,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5217466',
#   'location': [35.73404, 139.63128],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5240174',
#   'location': [35.66339, 139.68741],
#   'h3_cell': '872f5a364ffffff',
#   'restaurant': 217,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 43,
#   'bench': 27,
#   'parking_space': 2,
#   'bank': 6,
#   'clinic': 8,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5262640',
#   'location': [35.73445, 139.63138999999998],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5262658',
#   'location': [35.73588, 139.63159],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5407938',
#   'location': [35.693459999999995, 139.70823000000001],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5410242',
#   'location': [35.70055, 139.60022],
#   'h3_cell': '872f5a34cffffff',
#   'restaurant': 101,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 14,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 10,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5414578',
#   'location': [35.70122, 139.70571],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5464305',
#   'location': [35.706559999999996, 139.63583],
#   'h3_cell': '872f5a345ffffff',
#   'restaurant': 183,
#   'library': 3,
#   'atm': 5,
#   'vending_machine': 3,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 1,
#   'place_of_worship': 17,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5516726',
#   'location': [35.72085, 139.64121],
#   'h3_cell': '872f5a340ffffff',
#   'restaurant': 59,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 2,
#   'bench': 1,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 0,
#   'place_of_worship': 5,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5564391',
#   'location': [35.73172, 139.66583],
#   'h3_cell': '872f5a346ffffff',
#   'restaurant': 48,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 5,
#   'bench': 20,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5583920',
#   'location': [35.70019, 139.70523],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5585604',
#   'location': [35.70041, 139.70621],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5633430',
#   'location': [35.7359, 139.63151000000002],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5641920',
#   'location': [35.7348, 139.63141000000002],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 7,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5643408',
#   'location': [35.69955, 139.70423],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5661072',
#   'location': [35.70035, 139.6967],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5673677',
#   'location': [35.664320000000004, 139.65839],
#   'h3_cell': '872f5a360ffffff',
#   'restaurant': 132,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 3,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5719870',
#   'location': [35.71679, 139.85669],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5726170',
#   'location': [35.70841, 139.56843],
#   'h3_cell': '872f5a34dffffff',
#   'restaurant': 124,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 22,
#   'bench': 10,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 8,
#   'place_of_worship': 10,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5738050',
#   'location': [35.569759999999995, 139.69158000000002],
#   'h3_cell': '872f5bdb6ffffff',
#   'restaurant': 13,
#   'library': 0,
#   'atm': 1,
#   'vending_machine': 2,
#   'bench': 9,
#   'parking_space': 6,
#   'bank': 5,
#   'clinic': 0,
#   'place_of_worship': 18,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5815307',
#   'location': [35.64757, 139.71993999999998],
#   'h3_cell': '872f5aaddffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 4,
#   'vending_machine': 7,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 3,
#   'place_of_worship': 29,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5815506',
#   'location': [35.71934, 139.76508],
#   'h3_cell': '872f5a328ffffff',
#   'restaurant': 800,
#   'library': 6,
#   'atm': 18,
#   'vending_machine': 777,
#   'bench': 207,
#   'parking_space': 0,
#   'bank': 31,
#   'clinic': 31,
#   'place_of_worship': 56,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5876019',
#   'location': [35.765440000000005, 139.44477],
#   'h3_cell': '872f5bc9affffff',
#   'restaurant': 5,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 1,
#   'clinic': 0,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5932309',
#   'location': [35.74408, 139.72525],
#   'h3_cell': '872f5a30dffffff',
#   'restaurant': 50,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 108,
#   'bench': 30,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 7,
#   'place_of_worship': 35,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5936568',
#   'location': [35.56134, 139.46284],
#   'h3_cell': '872f5bc15ffffff',
#   'restaurant': 15,
#   'library': 0,
#   'atm': 2,
#   'vending_machine': 2,
#   'bench': 6,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5940498',
#   'location': [35.76787, 139.86487],
#   'h3_cell': '872f5a333ffffff',
#   'restaurant': 53,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 6,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5949669',
#   'location': [35.68285, 139.81551000000002],
#   'h3_cell': '872f5aad2ffffff',
#   'restaurant': 67,
#   'library': 2,
#   'atm': 5,
#   'vending_machine': 26,
#   'bench': 96,
#   'parking_space': 14,
#   'bank': 0,
#   'clinic': 3,
#   'place_of_worship': 34,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5963368',
#   'location': [35.764359999999996, 139.6698],
#   'h3_cell': '872f5a350ffffff',
#   'restaurant': 15,
#   'library': 1,
#   'atm': 2,
#   'vending_machine': 4,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/5979941',
#   'location': [35.767759999999996, 139.86466000000001],
#   'h3_cell': '872f5a333ffffff',
#   'restaurant': 53,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 6,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6050643',
#   'location': [35.76676, 139.44505],
#   'h3_cell': '872f5a269ffffff',
#   'restaurant': 4,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 11,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6120428',
#   'location': [35.75913, 139.68681],
#   'h3_cell': '872f5a354ffffff',
#   'restaurant': 22,
#   'library': 1,
#   'atm': 0,
#   'vending_machine': 21,
#   'bench': 3,
#   'parking_space': 0,
#   'bank': 7,
#   'clinic': 3,
#   'place_of_worship': 6,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6122133',
#   'location': [35.72939, 139.28372],
#   'h3_cell': '872f5b529ffffff',
#   'restaurant': 23,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 4,
#   'place_of_worship': 2,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6128894',
#   'location': [35.757870000000004, 139.72151000000002],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/6142248',
#   'location': [35.640859999999996, 139.70202],
#   'h3_cell': '872f5aacaffffff',
#   'restaurant': 129,
#   'library': 2,
#   'atm': 8,
#   'vending_machine': 24,
#   'bench': 18,
#   'parking_space': 1,
#   'bank': 9,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6164909',
#   'location': [35.75788, 139.72151000000002],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/6166571',
#   'location': [35.75786, 139.72151000000002],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/6172827',
#   'location': [35.71306, 139.85558999999998],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6194398',
#   'location': [35.59473, 139.40901000000002],
#   'h3_cell': '872f5bc1affffff',
#   'restaurant': 0,
#   'library': 0,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 2,
#   'parking_space': 0,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 4,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6214018',
#   'location': [35.75786, 139.72151000000002],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/6308465',
#   'location': [35.64284, 139.70001000000002],
#   'h3_cell': '872f5aacaffffff',
#   'restaurant': 129,
#   'library': 2,
#   'atm': 8,
#   'vending_machine': 24,
#   'bench': 18,
#   'parking_space': 1,
#   'bank': 9,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6365363',
#   'location': [35.71865, 139.81069],
#   'h3_cell': '872f5a323ffffff',
#   'restaurant': 18,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 35,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6374299',
#   'location': [35.730059999999995, 139.73093],
#   'h3_cell': '872f5a376ffffff',
#   'restaurant': 57,
#   'library': 4,
#   'atm': 6,
#   'vending_machine': 59,
#   'bench': 42,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6380625',
#   'location': [35.67951, 139.64878000000002],
#   'h3_cell': '872f5a363ffffff',
#   'restaurant': 38,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 9,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 3,
#   'place_of_worship': 10,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6428968',
#   'location': [35.73773, 139.84798],
#   'h3_cell': '872f5a322ffffff',
#   'restaurant': 21,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6439108',
#   'location': [35.66106, 139.66859],
#   'h3_cell': '872f5a360ffffff',
#   'restaurant': 132,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 3,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6592213',
#   'location': [35.5872, 139.48277],
#   'h3_cell': '872f5bc16ffffff',
#   'restaurant': 17,
#   'library': 1,
#   'atm': 3,
#   'vending_machine': 26,
#   'bench': 6,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 4,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6595315',
#   'location': [35.71432, 139.8557],
#   'h3_cell': '872f5a326ffffff',
#   'restaurant': 18,
#   'library': 3,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 1,
#   'bank': 0,
#   'clinic': 0,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6613961',
#   'location': [35.757870000000004, 139.72153],
#   'h3_cell': '872f5a309ffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 7,
#   'vending_machine': 240,
#   'bench': 25,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/6635417',
#   'location': [35.70156, 139.76818],
#   'h3_cell': '872f5a328ffffff',
#   'restaurant': 800,
#   'library': 6,
#   'atm': 18,
#   'vending_machine': 777,
#   'bench': 207,
#   'parking_space': 0,
#   'bank': 31,
#   'clinic': 31,
#   'place_of_worship': 56,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6646878',
#   'location': [35.65191, 139.66968],
#   'h3_cell': '872f5a365ffffff',
#   'restaurant': 116,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 21,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 13,
#   'clinic': 0,
#   'place_of_worship': 17,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6648293',
#   'location': [35.61486, 139.726],
#   'h3_cell': '872f5aaceffffff',
#   'restaurant': 106,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 9,
#   'bench': 30,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 3,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6670367',
#   'location': [35.71285, 139.81568000000001],
#   'h3_cell': '872f5a323ffffff',
#   'restaurant': 18,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 1,
#   'bench': 35,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 1,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6719865',
#   'location': [35.720240000000004, 139.76606999999998],
#   'h3_cell': '872f5a328ffffff',
#   'restaurant': 800,
#   'library': 6,
#   'atm': 18,
#   'vending_machine': 777,
#   'bench': 207,
#   'parking_space': 0,
#   'bank': 31,
#   'clinic': 31,
#   'place_of_worship': 56,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6732871',
#   'location': [35.71079, 139.7956],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6738906',
#   'location': [35.711490000000005, 139.79425],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6749824',
#   'location': [35.7242, 139.77766],
#   'h3_cell': '872f5a32affffff',
#   'restaurant': 127,
#   'library': 4,
#   'atm': 8,
#   'vending_machine': 52,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 10,
#   'clinic': 8,
#   'place_of_worship': 50,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6750472',
#   'location': [35.7155, 139.79083],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6785470',
#   'location': [35.72576, 139.50954],
#   'h3_cell': '872f5bc90ffffff',
#   'restaurant': 24,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 2,
#   'clinic': 0,
#   'place_of_worship': 3,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/6800607',
#   'location': [35.73624, 139.63246999999998],
#   'h3_cell': '872f5a343ffffff',
#   'restaurant': 14,
#   'library': 0,
# ...
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20008156',
#   'location': [35.71904, 139.74956],
#   'h3_cell': '872f5a32bffffff',
#   'restaurant': 98,
#   'library': 5,
#   'atm': 2,
#   'vending_machine': 26,
#   'bench': 148,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 6,
#   'place_of_worship': 60,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20008361',
#   'location': [35.71946, 139.75167],
#   'h3_cell': '872f5a32bffffff',
#   'restaurant': 98,
#   'library': 5,
#   'atm': 2,
#   'vending_machine': 26,
#   'bench': 148,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 6,
#   'place_of_worship': 60,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20017756',
#   'location': [35.65805, 139.69681],
#   'h3_cell': '872f5a364ffffff',
#   'restaurant': 217,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 43,
#   'bench': 27,
#   'parking_space': 2,
#   'bank': 6,
#   'clinic': 8,
#   'place_of_worship': 12,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20018501',
#   'location': [35.63919, 139.63887],
#   'h3_cell': '872f5bd92ffffff',
#   'restaurant': 70,
#   'library': 2,
#   'atm': 3,
#   'vending_machine': 9,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 4,
#   'clinic': 2,
#   'place_of_worship': 9,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20020282',
#   'location': [35.687509999999996, 139.66794],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20020699',
#   'location': [35.688140000000004, 139.66964],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20026344',
#   'location': [35.70451, 139.78749],
#   'h3_cell': '872f5a32cffffff',
#   'restaurant': 310,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 414,
#   'bench': 80,
#   'parking_space': 0,
#   'bank': 15,
#   'clinic': 3,
#   'place_of_worship': 21,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20057275',
#   'location': [35.68769, 139.72767],
#   'h3_cell': '872f5aadaffffff',
#   'restaurant': 216,
#   'library': 3,
#   'atm': 8,
#   'vending_machine': 33,
#   'bench': 22,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20058088',
#   'location': [35.68568, 139.72886],
#   'h3_cell': '872f5aadaffffff',
#   'restaurant': 216,
#   'library': 3,
#   'atm': 8,
#   'vending_machine': 33,
#   'bench': 22,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20058287',
#   'location': [35.68584, 139.72925],
#   'h3_cell': '872f5aadaffffff',
#   'restaurant': 216,
#   'library': 3,
#   'atm': 8,
#   'vending_machine': 33,
#   'bench': 22,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20058496',
#   'location': [35.68777, 139.72768],
#   'h3_cell': '872f5aadaffffff',
#   'restaurant': 216,
#   'library': 3,
#   'atm': 8,
#   'vending_machine': 33,
#   'bench': 22,
#   'parking_space': 0,
#   'bank': 8,
#   'clinic': 5,
#   'place_of_worship': 7,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20060704',
#   'location': [35.691990000000004, 139.79605],
#   'h3_cell': '872f5a32cffffff',
#   'restaurant': 310,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 414,
#   'bench': 80,
#   'parking_space': 0,
#   'bank': 15,
#   'clinic': 3,
#   'place_of_worship': 21,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20071378',
#   'location': [35.73196, 139.72863999999998],
#   'h3_cell': '872f5a376ffffff',
#   'restaurant': 57,
#   'library': 4,
#   'atm': 6,
#   'vending_machine': 59,
#   'bench': 42,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20080757',
#   'location': [35.71157, 139.66732],
#   'h3_cell': '872f5a344ffffff',
#   'restaurant': 312,
#   'library': 2,
#   'atm': 9,
#   'vending_machine': 56,
#   'bench': 31,
#   'parking_space': 1,
#   'bank': 23,
#   'clinic': 5,
#   'place_of_worship': 31,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20081142',
#   'location': [35.71158, 139.75215],
#   'h3_cell': '872f5a329ffffff',
#   'restaurant': 344,
#   'library': 1,
#   'atm': 26,
#   'vending_machine': 261,
#   'bench': 79,
#   'parking_space': 1,
#   'bank': 13,
#   'clinic': 9,
#   'place_of_worship': 32,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20128230',
#   'location': [35.71371, 139.69852],
#   'h3_cell': '872f5a370ffffff',
#   'restaurant': 150,
#   'library': 2,
#   'atm': 12,
#   'vending_machine': 17,
#   'bench': 52,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 2,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20133389',
#   'location': [35.708690000000004, 139.63445],
#   'h3_cell': '872f5a345ffffff',
#   'restaurant': 183,
#   'library': 3,
#   'atm': 5,
#   'vending_machine': 3,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 1,
#   'place_of_worship': 17,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20139917',
#   'location': [35.7027, 139.79223000000002],
#   'h3_cell': '872f5a32cffffff',
#   'restaurant': 310,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 414,
#   'bench': 80,
#   'parking_space': 0,
#   'bank': 15,
#   'clinic': 3,
#   'place_of_worship': 21,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20154974',
#   'location': [35.77326, 139.73716000000002],
#   'h3_cell': '872f5a308ffffff',
#   'restaurant': 46,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 505,
#   'bench': 17,
#   'parking_space': 0,
#   'bank': 9,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20155149',
#   'location': [35.703109999999995, 139.70667],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20155240',
#   'location': [35.7751, 139.73838],
#   'h3_cell': '872f5a308ffffff',
#   'restaurant': 46,
#   'library': 2,
#   'atm': 1,
#   'vending_machine': 505,
#   'bench': 17,
#   'parking_space': 0,
#   'bank': 9,
#   'clinic': 11,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20162482',
#   'location': [35.64894, 139.74583],
#   'h3_cell': '872f5aadcffffff',
#   'restaurant': 218,
#   'library': 3,
#   'atm': 10,
#   'vending_machine': 79,
#   'bench': 97,
#   'parking_space': 0,
#   'bank': 13,
#   'clinic': 2,
#   'place_of_worship': 14,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20173783',
#   'location': [35.69835, 139.70088],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20175306',
#   'location': [35.7267, 139.78203],
#   'h3_cell': '872f5a32affffff',
#   'restaurant': 127,
#   'library': 4,
#   'atm': 8,
#   'vending_machine': 52,
#   'bench': 18,
#   'parking_space': 0,
#   'bank': 10,
#   'clinic': 8,
#   'place_of_worship': 50,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20175652',
#   'location': [35.70902, 139.81525],
#   'h3_cell': '872f5a321ffffff',
#   'restaurant': 132,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 69,
#   'bench': 28,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 2,
#   'place_of_worship': 24,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20176208',
#   'location': [35.70009, 139.47711999999999],
#   'h3_cell': '872f5bc82ffffff',
#   'restaurant': 46,
#   'library': 4,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 7,
#   'place_of_worship': 3,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/20182174',
#   'location': [35.734609999999996, 139.84801000000002],
#   'h3_cell': '872f5a322ffffff',
#   'restaurant': 21,
#   'library': 2,
#   'atm': 2,
#   'vending_machine': 0,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 3,
#   'clinic': 1,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20204891',
#   'location': [35.69185, 139.68352],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20219154',
#   'location': [35.657090000000004, 139.74446],
#   'h3_cell': '872f5aad8ffffff',
#   'restaurant': 458,
#   'library': 4,
#   'atm': 7,
#   'vending_machine': 48,
#   'bench': 38,
#   'parking_space': 0,
#   'bank': 12,
#   'clinic': 6,
#   'place_of_worship': 36,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20240130',
#   'location': [35.701240000000006, 139.70609],
#   'h3_cell': '872f5a375ffffff',
#   'restaurant': 618,
#   'library': 4,
#   'atm': 18,
#   'vending_machine': 44,
#   'bench': 26,
#   'parking_space': 1,
#   'bank': 29,
#   'clinic': 22,
#   'place_of_worship': 26,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20285316',
#   'location': [35.70608, 139.74165],
#   'h3_cell': '872f5a329ffffff',
#   'restaurant': 344,
#   'library': 1,
#   'atm': 26,
#   'vending_machine': 261,
#   'bench': 79,
#   'parking_space': 1,
#   'bank': 13,
#   'clinic': 9,
#   'place_of_worship': 32,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20285412',
#   'location': [35.705940000000005, 139.74156000000002],
#   'h3_cell': '872f5a329ffffff',
#   'restaurant': 344,
#   'library': 1,
#   'atm': 26,
#   'vending_machine': 261,
#   'bench': 79,
#   'parking_space': 1,
#   'bank': 13,
#   'clinic': 9,
#   'place_of_worship': 32,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20288298',
#   'location': [35.717690000000005, 139.78472],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20289881',
#   'location': [35.69027, 139.68331],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20290031',
#   'location': [35.71894, 139.78471000000002],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20292150',
#   'location': [35.71821, 139.78443000000001],
#   'h3_cell': '872f5a32effffff',
#   'restaurant': 415,
#   'library': 2,
#   'atm': 0,
#   'vending_machine': 201,
#   'bench': 47,
#   'parking_space': 2,
#   'bank': 16,
#   'clinic': 1,
#   'place_of_worship': 96,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20299581',
#   'location': [35.69188, 139.68374],
#   'h3_cell': '872f5a362ffffff',
#   'restaurant': 102,
#   'library': 3,
#   'atm': 3,
#   'vending_machine': 13,
#   'bench': 9,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 0,
#   'place_of_worship': 8,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20309506',
#   'location': [35.7042, 139.70703999999998],
#   'h3_cell': '872f5a370ffffff',
#   'restaurant': 150,
#   'library': 2,
#   'atm': 12,
#   'vending_machine': 17,
#   'bench': 52,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 2,
#   'place_of_worship': 11,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20312645',
#   'location': [35.71162, 139.8165],
#   'h3_cell': '872f5a321ffffff',
#   'restaurant': 132,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 69,
#   'bench': 28,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 2,
#   'place_of_worship': 24,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20313397',
#   'location': [35.71197, 139.81248],
#   'h3_cell': '872f5a321ffffff',
#   'restaurant': 132,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 69,
#   'bench': 28,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 2,
#   'place_of_worship': 24,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20313696',
#   'location': [35.71158, 139.81646],
#   'h3_cell': '872f5a321ffffff',
#   'restaurant': 132,
#   'library': 0,
#   'atm': 5,
#   'vending_machine': 69,
#   'bench': 28,
#   'parking_space': 0,
#   'bank': 14,
#   'clinic': 2,
#   'place_of_worship': 24,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20432881',
#   'location': [35.71029, 139.48091000000002],
#   'h3_cell': '872f5bc82ffffff',
#   'restaurant': 46,
#   'library': 4,
#   'atm': 0,
#   'vending_machine': 0,
#   'bench': 4,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 7,
#   'place_of_worship': 3,
#   'research_institute': 1},
#  {'url': 'https://www.airbnb.com/rooms/20458950',
#   'location': [35.707840000000004, 139.64664],
#   'h3_cell': '872f5a344ffffff',
#   'restaurant': 312,
#   'library': 2,
#   'atm': 9,
#   'vending_machine': 56,
#   'bench': 31,
#   'parking_space': 1,
#   'bank': 23,
#   'clinic': 5,
#   'place_of_worship': 31,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20487787',
#   'location': [35.73677, 139.75614],
#   'h3_cell': '872f5a32bffffff',
#   'restaurant': 98,
#   'library': 5,
#   'atm': 2,
#   'vending_machine': 26,
#   'bench': 148,
#   'parking_space': 0,
#   'bank': 11,
#   'clinic': 6,
#   'place_of_worship': 60,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20527555',
#   'location': [35.76838, 139.8661],
#   'h3_cell': '872f5a333ffffff',
#   'restaurant': 53,
#   'library': 1,
#   'atm': 1,
#   'vending_machine': 6,
#   'bench': 0,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 3,
#   'place_of_worship': 16,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20528100',
#   'location': [35.696290000000005, 139.78121000000002],
#   'h3_cell': '872f5a32cffffff',
#   'restaurant': 310,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 414,
#   'bench': 80,
#   'parking_space': 0,
#   'bank': 15,
#   'clinic': 3,
#   'place_of_worship': 21,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20574418',
#   'location': [35.64054, 139.74013],
#   'h3_cell': '872f5aaddffffff',
#   'restaurant': 108,
#   'library': 3,
#   'atm': 4,
#   'vending_machine': 7,
#   'bench': 12,
#   'parking_space': 0,
#   'bank': 5,
#   'clinic': 3,
#   'place_of_worship': 29,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20574453',
#   'location': [35.61412, 139.7407],
#   'h3_cell': '872f5aac1ffffff',
#   'restaurant': 50,
#   'library': 0,
#   'atm': 6,
#   'vending_machine': 4,
#   'bench': 14,
#   'parking_space': 0,
#   'bank': 6,
#   'clinic': 2,
#   'place_of_worship': 15,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20575191',
#   'location': [35.73214, 139.70592],
#   'h3_cell': '872f5a372ffffff',
#   'restaurant': 195,
#   'library': 2,
#   'atm': 4,
#   'vending_machine': 7,
#   'bench': 5,
#   'parking_space': 0,
#   'bank': 28,
#   'clinic': 3,
#   'place_of_worship': 19,
#   'research_institute': 0},
#  {'url': 'https://www.airbnb.com/rooms/20607902',
#   'location': [35.69437, 139.79681000000002],
#   'h3_cell': '872f5a32cffffff',
#   'restaurant': 310,
#   'library': 2,
#   'atm': 6,
#   'vending_machine': 414,
#   'bench': 80,
#   'parking_space': 0,
#   'bank': 15,
#   'clinic': 3,
#   'place_of_worship': 21,
#   'research_institute': 0}]

# %%
preferences
# Out:
# {'restaurant': [0.0064718547249795755,
#   0.07384895985771633,
#   0.9901815974827721,
#   0.0765439605183772,
#   0.7385378645713035,
#   0.5371596261127178,
#   0.9172035631996321,
#   0.2175844142556117,
#   0.9143645474789924,
#   0.022112045908133537],
#  'library': [0.7537102841979849,
#   0.5960779525670337,
#   0.14681991991952204,
#   0.4461010453106101,
#   0.22510108536960138,
#   0.24091242690444814,
#   0.9974057325555087,
#   0.08341617474529517,
#   0.6300899825969589,
#   0.13097209248169228],
#  'atm': [0.541673492004574,
#   0.41005076744202185,
#   0.40484721345094066,
#   0.2882185172640782,
#   0.8985666212215919,
#   0.3091351795708428,
#   0.45377109982220853,
#   0.639477781780047,
#   0.3364858372015155,
#   0.07010280733798102],
ff': {'restaurant': 0, 'library': 0, 'atm': 0},
#  '872f5aa8affffff': {'restaurant': 0, 'library': 0, 'atm': 0},
#  '872f5bcb6ffffff': {'restaurant': 0, 'library': 0, 'atm': 0}}

# %%
num_houses

# %%
import os

os

os.listdir('./data')
# Out:
# ['75.818982_26.915458_places.json',
#  'downloaded_file_7.pdf',
#  'downloaded_file_14.pdf',
#  'database.txt',
#  'downloaded_file_15.pdf',
#  'downloaded_file_6.pdf',
#  'airbnb.json',
#  '101.648104_3.162947_places.json',
#  '75.784422_26.8726_places.json',
#  'downloaded_file_4.pdf',
#  'downloaded_file_17.pdf',
#  'downloaded_file_16.pdf',
#  'downloaded_file_5.pdf',
#  'encodings.json',
#  '.DS_Store',
#  'downloaded_file_12.pdf',
#  'downloaded_file_1.pdf',
#  'airbnb',
#  'downloaded_file_0.pdf',
#  '101.693684_3.139395_places.json',
#  'downloaded_file_13.pdf',
#  'airbnb_map.json',
#  'Hanoi--Vietnam_apt.json',
#  'downloaded_file_11.pdf',
#  'downloaded_file_2.pdf',
#  'Dubrovnik--Croatia_apt.json',
#  'downloaded_file_3.pdf',
#  'downloaded_file_10.pdf',
#  'big.txt',
#  'archive (4).textClipping',
#  'Brisbane--Australia_apt.json',
#  'george.txt',
#  'archive (4).zip',
#  'classifications.json',
#  'Taipei--Taiwan_apt.json',
#  'complaint.csv',
#  'nyc_airbnb.csv',
#  'California_Houses (2).csv',
#  '101.723056_3.044258_places.json',
#  'sf-noise-regions.csv',
#  '75.775256_26.897392_places.json',
#  'stream-comments.json',
#  '75.822858_26.915904_places.json',
#  'twitch.json',
#  'sf_airbnb.csv',
#  'Hong Kong--China_apt.json',
#  'somefile.pdf',
#  'Cusco--Peru_apt.json',
#  'Ethereum_tweets.csv',
#  '75.856433_26.881864_places.json',
#  'Dakar--Senegal_apt.json',
#  'Cairo--Egypt_apt.json',
#  '75.78857_26.919951_places.json',
#  '75.793949_26.877699_places.json',
#  'package-lock.json',
#  'package.json',
#  'Bangkok--Thailand_apt.json',
#  '75.8427605_26.919543_places.json',
#  '371548168_10231725809506196_4991688290360420786_n.jpeg',
#  '370178622_848098466977592_2971496631804265319_n.jpeg',
#  '_apt.json',
#  'downloaded_file_21.pdf',
#  'downloaded_file_20.pdf',
#  'Kuala Lumpur--Malaysia_apt.json',
#  '2015_Street_Tree_Census_-_Tree_Data.csv',
#  'rome_apt.json',
#  'Kyoto--Japan_apt.json',
#  'cario-- egypt.json',
#  'jaipur-- india_apt.json',
#  'save-twitch.json',
#  '311_Cases.csv',
#  'downloaded_file_22.pdf',
#  '371040428_661172512744902_4204384451716555273_n.jpeg',
#  'Beijing--China_apt.json',
#  'downloaded_file_23.pdf',
#  '75.804092_26.815534_places.json',
#  'Accra--Ghana_apt.json',
#  'downloaded_file_8.pdf',
#  'jaipur--india_apt.json',
#  'downloaded_file_9.pdf',
#  '371330141_10159152899662443_3642421300759488530_n.jpeg',
#  'Dubai--UAE_apt.json',
#  'AB_NYC_2019.csv',
#  'downloaded_file_24.pdf',
#  '101.6942371_3.1516964_places.json',
#  'downloaded_file_18.pdf',
#  'downloaded_file_19.pdf',
#  'all_pg.txt',
#  'counties-albers-10m.json']

# %%
# perform migrations -> 0 data
# 7 million airbnbs
# for each city in airbnb ?
#     get geocoordinates of borders of city + 2 miles?
#        teseelate that into boxes?
#                        


#airbnb, yelp, etc

# %%
from PIL import Image
import requests
from io import BytesIO
longitude =-95.731003
latitude = 29.746700
zoom =16.25
tilt = 0
rotation = 0

res = requests.get(f'https://api.mapbox.com/styles/v1/mapbox/satellite-streets-v11/static/{longitude},{latitude},{zoom},{tilt}, {rotation}/600x600?access_token=pk.eyJ1IjoiYXdhaGFiIiwiYSI6ImNrdjc3NW11aTJncmIzMXExcXRiNDNxZWYifQ.tqFU7uVd6mbhHtjYsjtvlg')


image = Image.open(BytesIO(res.content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600>

# %%
async def _():
    pass

import inspect


inspect.iscoroutinefunction(_)


def __():
    pass

inspect.iscoroutinefunction(__)
# Out:
# False

# %%
import glob

coords = glob.glob('*_geoCoordinates.json')

import json

json.load(open(coords[0]))
# Out:
# ['126.965727:37.59496', '126.9943448:37.5702942', '126.99215:37.59552']

# %%
# #given a geolocation -> output like 5 metrics 
# #hipsterness -> mentions of hipster per square mile 
# #


# #reverse - frequency of words in twitter for each city in the top 100

# # installation
# !pip install easyocr

# import easyocr

# reader = easyocr.Reader(['en'])
# extract_info = reader.readtext(img_path1)

# for el in extract_info:
#    print(el)


#characterize neighborhoods as hipster, density of _ foods, 
#for every building in negihborhood -> get classification
#mueseum, history, culture, quiet, family, loud, nightlife, parks, architecture

# safetey
#transportation

#proximity to waterfront
#sum up complaints in each area -> find complaints above norm not just density of complaint

#word cloud for reviews of google places api

#curb appeal
#https://metropolismoving.com/blog/neighborhoods-in-manhattan-explained/

#https://developer.twitter.com/en/docs/twitter-api/enterprise/rules-and-filtering/enterprise-operators#listofoperators
#https://developer.twitter.com/en/docs/twitter-api/v1/geo/places-near-location/api-reference/get-geo-search

twit_url = 'https://api.twitter.com/1.1/geo/search.json'
res = requests.post(twit_url, json={
  "lat": -0.8957793,
  "long": 119.8679974,
})

#find all bars, restauarnts and shit near an airbnb - automatically sort them
#find all blogs about place -> find words of interest


#create data sets but especially geospatial

latitude =  -0.8957793
longitude = 119.8679974

# %%
l=list(cache)
l
# Out:
# [(-4.05568501525488, 41.2948556295683),
#  (119.8679974, -0.8957793),
#  (73.594322, 29.95872),
#  (-0.5312195, 53.172297),
#  (-54.154887, -34.626067),
#  (-79.450667, 43.950347),
#  (8.8263532, 45.817549),
#  (-0.193263, 51.501466),
#  (-98.483963, 29.612465),
#  (-77.029429, 38.925672),
#  (-0.120666, 51.503266),
#  (15.32299, 48.102374),
#  (-3.86509, 56.619321),
#  None,
#  (-3.60824203189663, 52.3287887217459),
#  (35.2, 31.88333),
#  (151.206353, -33.877945),
#  (-80.868475, 35.08156),
#  (7.893079, 45.285328),
#  (0.05532, 51.532963),
#  (-71.124496, 42.255654),
#  (103.165793, 31.438424),
#  (-0.232347, 51.759906)]

# %%
# Out:
# {'type': 'Feature', 'geometry': {'coordinates': [-0.239985, 51.761168], 'type': 'Point'}, 'properties': {'name': 'Sports Direct', 'mapbox_id': 'CkIKQDNhNTFkMzdmMzUwZDI2NGViZmMwNzYwY2RlYjM3ODc2ODIyMzYyODk3ZmYwYzgwYzAwY2ZjMmQ5YWNlOWUwYjg=', 'feature_type': 'poi', 'address': '"17 The Galleria', 'full_address': '"17 The Galleria, Hatfield, AL10 0XS, United Kingdom', 'place_formatted': 'Hatfield, AL10 0XS, United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'postcode': {'name': 'AL10 0XS'}, 'place': {'name': 'Hatfield'}, 'address': {'name': '"17 The Galleria', 'address_number': '"17', 'street_name': 'The Galleria'}, 'street': {'name': 'the galleria comet way"'}}, 'coordinates': {'latitude': 51.761168, 'longitude': -0.239985, 'routable_points': [{'name': 'default', 'latitude': 51.761687139110975, 'longitude': -0.23975779057476845}]}, 'maki': 'marker', 'poi_category': ['sports shop', 'shopping'], 'poi_category_ids': ['sports_shop', 'shopping'], 'brand': ['Sports Direct'], 'brand_id': ['sports_direct'], 'external_ids': {'safegraph': 'zzy-23y@4hq-8yz-52k', 'foursquare': '4c8b42fc6418a14378c3e7ce'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.240304, 51.760664], 'type': 'Point'}, 'properties': {'name': 'The Works', 'mapbox_id': 'CkIKQDEwNDcwMWZmMTI0NTRlNDkyNjk0ZjQzNjkwY2M4MDBkNGZkMTg0YmIzZDVjOGY2NmIzY2ZlNDZjOGQ4NzRhMTY=', 'feature_type': 'poi', 'address': 'Comet Way', 'full_address': 'Comet Way, Hatfield, AL10 0XX, United Kingdom', 'place_formatted': 'Hatfield, AL10 0XX, United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'postcode': {'name': 'AL10 0XX'}, 'place': {'name': 'Hatfield'}, 'address': {'name': 'Comet Way', 'address_number': 'Comet', 'street_name': 'Way'}, 'street': {'name': 'comet way'}}, 'coordinates': {'latitude': 51.760664, 'longitude': -0.240304, 'routable_points': [{'name': 'default', 'latitude': 51.761663423425574, 'longitude': -0.24075668827914357}]}, 'maki': 'marker', 'poi_category': ['bookstore', 'shopping', 'discount store'], 'poi_category_ids': ['book_store', 'shopping', 'discount_store'], 'brand': ['The Works'], 'brand_id': ['the_works'], 'external_ids': {'foursquare': '4f2b1dccaf24d05b4be75667'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.240363, 51.76101], 'type': 'Point'}, 'properties': {'name': 'Holland & Barrett', 'mapbox_id': 'CkIKQDUzNDBlYTZjNGEyYWJiMDNhNDkyODIyYmJlYjBhNjdiOWI1ZDY4ZjNkMjc0Y2I4MmViYWRlZThhZGE5MjIyOGQ=', 'feature_type': 'poi', 'address': 'Unit 100', 'full_address': 'Unit 100, Hatfield, AL10 0XR, United Kingdom', 'place_formatted': 'Hatfield, AL10 0XR, United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'postcode': {'name': 'AL10 0XR'}, 'place': {'name': 'Hatfield'}, 'address': {'name': 'Unit 100', 'address_number': 'Unit', 'street_name': '100'}, 'street': {'name': '100'}}, 'coordinates': {'latitude': 51.76101, 'longitude': -0.240363, 'routable_points': [{'name': 'default', 'latitude': 51.76044523981428, 'longitude': -0.24005947915153197}]}, 'maki': 'marker', 'poi_category': ['health food store', 'shopping'], 'poi_category_ids': ['health_food_store', 'shopping'], 'brand': ['Holland & Barrett'], 'brand_id': ['holland__barrett'], 'external_ids': {'safegraph': 'zzy-244@4hq-8yz-52k', 'foursquare': '4e5b732418388cd5cbbc8cae'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0
Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'place': {'name': 'Hatfield'}}, 'coordinates': {'latitude': 51.7607952, 'longitude': -0.24135, 'routable_points': [{'name': 'default', 'latitude': 51.760997944085375, 'longitude': -0.24152549528030168}]}, 'maki': 'marker', 'poi_category': ['mobile phone store', 'shopping'], 'poi_category_ids': ['phone_store', 'shopping'], 'brand': ['O2'], 'brand_id': ['o2'], 'external_ids': {}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.2415795, 51.7607063], 'type': 'Point'}, 'properties': {'name': 'M&S Outlet', 'mapbox_id': 'CkIKQDM0MWIwZGI4YWZjYWE0Yzc1MWU4NjAyNzliMzc1NDllNzlkOGFjYTNmY2I3NWM1YWExMTE1M2NmNGMyMjU0MjQ=', 'feature_type': 'poi', 'address': 'Hatfield', 'full_address': 'Hatfield, United Kingdom', 'place_formatted': 'United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'place': {'name': 'Hatfield'}}, 'coordinates': {'latitude': 51.7607063, 'longitude': -0.2415795, 'routable_points': [{'name': 'default', 'latitude': 51.76084630041709, 'longitude': -0.24170068436103315}]}, 'maki': 'marker', 'poi_category': ['department store', 'shopping'], 'poi_category_ids': ['department_store', 'shopping'], 'brand': ['M&S Outlet'], 'brand_id': ['ms_outlet'], 'external_ids': {'safegraph': 'zzy-222@4hq-8yz-575'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.2416659, 51.7607161], 'type': 'Point'}, 'properties': {'name': 'TK Maxx', 'mapbox_id': 'CkIKQDYwYzA0MDkzOTM3ZWI1YWNkM2ZkOWIwM2U3MDViNDQxNTFjMjM2NzU5YmNkMjA3ODg2MWM4MWNlZGQxNjQwNDA=', 'feature_type': 'poi', 'address': 'Hatfield', 'full_address': 'Hatfield, AL10 0XR, United Kingdom', 'place_formatted': 'AL10 0XR, United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'postcode': {'name': 'AL10 0XR'}, 'place': {'name': 'Hatfield'}, 'street': {'name': 'Comet Way'}}, 'coordinates': {'latitude': 51.7607161, 'longitude': -0.2416659, 'routable_points': [{'name': 'default', 'latitude': 51.76082972741288, 'longitude': -0.24171983062282845}]}, 'maki': 'marker', 'poi_category': ['clothes store', 'shopping', 'department store'], 'poi_category_ids': ['clothing_store', 'shopping', 'department_store'], 'brand': ['TK Maxx'], 'brand_id': ['tk_maxx'], 'external_ids': {'foursquare': '4c503e1a371520a1b0a4fbc0'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.2407918, 51.7630643], 'type': 'Point'}, 'properties': {'name': 'ALDI', 'mapbox_id': 'CkIKQDkxYzEzNjQ2N2Y5NWJhYmUwMWIzOTIxY2IyYzhkYjExMjRlY2ViOTA4OGIwMjAzNTk5ZmQwN2M3MDZkZjdiZGY=', 'feature_type': 'poi', 'address': 'Hatfield', 'full_address': 'Hatfield, AL10 9RQ, United Kingdom', 'place_formatted': 'AL10 9RQ, United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'postcode': {'name': 'AL10 9RQ'}, 'place': {'name': 'Hatfield'}, 'street': {'name': 'Parkhouse Court'}}, 'coordinates': {'latitude': 51.7630643, 'longitude': -0.2407918, 'routable_points': [{'name': 'default', 'latitude': 51.762639, 'longitude': -0.240773}]}, 'maki': 'marker', 'poi_category': ['grocery', 'shopping'], 'poi_category_ids': ['grocery', 'shopping'], 'brand': ['ALDI', 'Aldi', 'Aldi Nord', 'Aldi Süd', 'ALDI Nord', 'ALDI Süd'], 'brand_id': ['aldi'], 'external_ids': {'safegraph': '242-222@4hq-8yz-5fz', 'foursquare': '4c94f48294a0236a55679112'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.243385, 51.753502], 'type': 'Point'}, 'properties': {'name': 'Art Shop', 'mapbox_id': 'CkIKQGQ0YWM3MTEyODAyNjM0NzkzNzc0OGYzZTgwMjhlNjNkM2M2ZWI1OGJjMDI0M2UxNWFjM2NlMjU3MGQ4MDM2OWM=', 'feature_type': 'poi', 'address': 'Hatfield', 'full_address': 'Hatfield, United Kingdom', 'place_formatted': 'United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'place': {'name': 'Hatfield'}, 'neighborhood': {'name': 'Roehyde'}}, 'coordinates': {'latitude': 51.753502, 'longitude': -0.243385, 'routable_points': [{'name': 'default', 'latitude': 51.75347869342159, 'longitude': -0.2430994944145639}]}, 'maki': 'marker', 'poi_category': ['bookstore', 'shopping', 'university building', 'university book store'], 'poi_category_ids': ['book_store', 'shopping', 'university_building', 'university_book_store'], 'external_ids': {'foursquare': '4c08d9b8a1b32d7fd79a96f0;4ea671cfe300a8628e8c8730;560d0275498ebe5036c8ac01'}, 'metadata': {}}}
# {'type': 'Feature', 'geometry': {'coordinates': [-0.23504153692676985, 51.77026033851829], 'type': 'Point'}, 'properties': {'name': 'Porsche Centre Hatfield', 'mapbox_id': 'CkIKQGU2ZTU5Yjc5OGFlMGYxZWY1ODZhOWU3ZTNmM2RhMDM1ZGQyNDk2M2NlM2NmOTkzMGNjZjlkZDU4NDdkYWFlOGI=', 'feature_type': 'poi', 'address': 'Hatfield', 'full_address': 'Hatfield, AL10 9UA, United Kingdom', 'place_formatted': 'AL10 9UA, United Kingdom', 'context': {'country': {'name': 'United Kingdom', 'country_code': 'GB', 'country_code_alpha_3': 'GBR'}, 'postcode': {'name': 'AL10 9UA'}, 'place': {'name': 'Hatfield'}}, 'coordinates': {'latitude': 51.77026033851829, 'longitude': -0.23504153692676985, 'routable_points': [{'name': 'default', 'latitude': 51.770051862999125, 'longitude': -0.2351095929846781}]}, 'maki': 'marker', 'poi_category': ['car dealership', 'shopping'], 'poi_category_ids': ['car_dealership', 'shopping'], 'brand': ['Porsche', 'Porsche Dealer'], 'brand_id': ['porsche', 'volkswagen'], 'external_ids': {'safegraph': '222-222@4hq-8yz-v75', 'foursquare': '4c934f782bf7b60c7aca690a'}, 'metadata': {'website': 'http://www.porsche.co.uk/hatfield'}}}

# %%
coords = [-71.126085, 42.25230]
import requests
longitude = coords[0]
latitude = coords[1]
latitude, longitude = 139.766828, 35.668613

contours_minutes = 2
isochrone_url = f'https://api.mapbox.com/isochrone/v1/mapbox/driving-traffic/{latitude}%2C{longitude}?contours_minutes={contours_minutes}&polygons=true&denoise=0&generalize=0&access_token=pk.eyJ1IjoiYXdhaGFiIiwiYSI6ImNrdjc3NW11aTJncmIzMXExcXRiNDNxZWYifQ.tqFU7uVd6mbhHtjYsjtvlg'
geojson_data = requests.get(isochrone_url).json()

# %%
#print(coffee_shops, 'coffee_shops')
#print('geojson_data', geojson_data)
data = []
from shapely.geometry import shape, Point

for shop in coffee_shops: 
    if 'lat' not in shop or 'lon' not in shop: 
        #print(shop)
        continue
    point_to_check = Point(shop['lon'], shop['lat'])
    for feature in geojson_data['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point_to_check):
            data.append(shop)
len(data)
# Out:
# 27

# %%
coffee_shops = fetch_coffee_shops(longitude, latitude)
coffee_shops
# Out:
# [{'type': 'node',
#   'id': 585164417,
#   'lat': 35.6695915,
#   'lon': 139.7653106,
#   'tags': {'addr:full': '東京都中央区銀座5-10-6',
#    'addr:housename': '御幸ビル1F',
#    'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'branch': '銀座みゆき通り店',
#    'brand': 'カフェ・ベローチェ',
#    'brand:en': 'CAFFÈ VELOCE',
#    'brand:ja': 'カフェ・ベローチェ',
#    'brand:wikidata': 'Q11294597',
#    'brand:wikipedia': 'ja:カフェ・ベローチェ',
#    'cuisine': 'coffee_shop',
#    'level': '0',
#    'name': 'カフェ・ベローチェ',
#    'name:en': 'CAFFÈ VELOCE',
#    'name:ja': 'カフェ・ベローチェ',
#    'name:ja_rm': 'Kafe Berōche',
#    'opening_hours': 'Mo-Su 07:00-23:00',
#    'operator': 'シャノアール',
#    'phone': '+81 3-3289-3233',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://chatnoir-company.com/chatnoir/html/brand/brand_veloce.html'}},
#  {'type': 'node',
#   'id': 1195197103,
#   'lat': 35.6727334,
#   'lon': 139.7673145,
#   'tags': {'addr:full': '東京都中央区銀座2-7-11',
#    'addr:postcode': '104-0061',
#    'alt_name:en': 'Saint Marc Café',
#    'amenity': 'cafe',
#    'branch': '銀座マロニエ通り店',
#    'brand': 'サンマルクカフェ',
#    'brand:en': 'ST.MARC CAFÉ',
#    'brand:ja': 'サンマルクカフェ',
#    'brand:wikidata': 'Q11305989',
#    'brand:wikipedia': 'ja:サンマルクホールディングス',
#    'cuisine': 'coffee_shop',
#    'name': 'サンマルクカフェ',
#    'name:en': 'ST.MARC CAFÉ',
#    'name:ja': 'サンマルクカフェ',
#    'name:ja_rm': 'Sanmaruku Kafe',
#    'opening_hours': 'Mo-Fr 07:00-22:30; Sa,Su,PH 07:30-22:30',
#    'operator': 'サンマルクカフェ',
#    'phone': '+81 3-3535-0309',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.saint-marc-hd.com/cafe/'}},
#  {'type': 'node',
#   'id': 1195197230,
#   'lat': 35.6727804,
#   'lon': 139.767244,
#   'tags': {'addr:full': '東京都中央区銀座2-7-11',
#    'addr:housename': '銀座ブラジルビル',
#    'amenity': 'cafe',
#    'branch': '銀座マロニエ通り店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:it': 'Doutor',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'opening_hours': 'Mo-Sa 07:30-22:00; Su,PH 08:00-22:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'phone': '+81 3-3567-9003',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 1326424579,
#   'lat': 35.6687077,
#   'lon': 139.7656222,
#   'tags': {'addr:full': '東京都中央区銀座6-14-5',
#    'addr:housename': '銀座ホウライビル1F',
#    'amenity': 'cafe',
#    'branch': '銀座六丁目昭和通り店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'check_date': '2023-01-20',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'level': '0',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:es': "café Tully's",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarizu Kohi',
#    'opening_hours': 'Mo-Fr 07:30-21:00; Sa 08:00-20:00; Su,PH 09:00-19:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-5148-8660',
#    'smoking': 'yes',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wikidata': 'Q11316408',
#    'wikipedia': 'ja:タリーズコーヒージャパン'}},
#  {'type': 'node',
#   'id': 1327304988,
#   'lat': 35.6716935,
#   'lon': 139.7665908,
#   'tags': {'addr:full': '東京都中央区銀座3-7-14',
#    'addr:housename': 'ESKビル1F',
#    'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'branch': '銀座松屋通り店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'level': '0',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutah-bakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Th 07:00-22:30; Fr,Sa 07:00-23:00; Su,PH 07:00-22:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'source': 'Bing 2010; (URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 1327304991,
#   'lat': 35.6702592,
#   'lon': 139.7650197,
#   'tags': {'amenity': 'cafe', 'name': 'トリコロール本店', 'name:en': 'Tricolore'}},
#  {'type': 'node',
#   'id': 1327332377,
#   'lat': 35.6754844,
#   'lon': 139.7695215,
#   'tags': {'addr:full': '東京都中央区京橋3-6-12',
#    'amenity': 'cafe',
#    'branch': '京橋中央通り店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'internet_access:fee': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'opening_hours': 'Mo-Fr 06:45-21:00; Sa 08:00-19:30; Su,PH 08:00-19:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'outdoor_seating': 'no',
#    'phone': '03-5250-7780',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 1385607925,
#   'lat': 35.6661722,
#   'lon': 139.7579385,
#   'tags': {'addr:postcode': '110-8549',
#    'amenity': 'cafe',
#    'branch': '新橋烏森口',
#    'brand': 'カフェ・ド・クリエ',
#    'brand:en': 'Cafe de CRIE',
#    'brand:ja': 'カフェ・ド・クリエ',
#    'brand:wikidata': 'Q17219077',
#    'contact:phone': '+81-3-55371861',
#    'cuisine': 'coffee_shop',
#    'level': '0',
#    'name': 'カフェ・ド・クリエ',
#    'name:en': 'Cafe de CRIE',
#    'name:ja': 'カフェ・ド・クリエ',
#    'name:ja_rm': 'Kafe Do Kurie',
#    'opening_hours': 'Mo-Fr 06:30-22:30; Sa,Su,PH 07:00-19:00',
#    'operator': 'ポッカ・クリエイト',
#    'source': '(URL)',
#    'takeaway': 'yes',
#    'website': 'https://www.pokkacreate.co.jp/',
#    'wifi': 'free'}},
#  {'type': 'node',
#   'id': 1656807475,
#   'lat': 35.667334,
#   'lon': 139.757236,
#   'tags': {'amenity': 'cafe',
#    'brand': 'Pronto',
#    'brand:wikidata': 'Q11336224',
#    'brand:wikipedia': 'ja:プロントコーポレーション',
#    'cuisine': 'coffee_shop',
#    'name': 'Pronto',
#    'name:en': 'PRONTO',
#    'name:ja': 'プロント',
#    'name:ja_rm': 'Puronto',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 1656807582,
#   'lat': 35.6673494,
#   'lon': 139.7571847,
#   'tags': {'amenity': 'cafe', 'level': '1', 'name': '驛舎珈琲店'}},
#  {'type': 'node',
#   'id': 1892891698,
#   'lat': 35.6765852,
#   'lon': 139.7695113,
#   'tags': {'addr:full': '東京都中央区京橋2-4-12',
#    'addr:housename': '京橋第一生命ビルディング1F',
#    'addr:postcode': '104-0031',
#    'amenity': 'cafe',
#    'branch': '京橋駅前店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'level': '0',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutah-bakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Sa 07:00-22:00; Su,PH 09:00-22:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/',
#    'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 1894393313,
#   'lat': 35.6722427,
#   'lon': 139.7676164,
#   'tags': {'addr:full': '東京都中央区銀座3-7-3',
#    'addr:housename': '銀座オーミビル1F',
#    'addr:housenumber': '銀座オーミビル1F',
#    'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'branch': '銀座マロニエ通り店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'level': '0',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutah-bakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Su 07:00-22:30',
#    'operator': 'スターバックスコーヒージャパン',
#    'source': 'Bing 2010; (URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 1894458887,
#   'lat': 35.6712526,
#   'lon': 139.7603141,
#   'tags': {'addr:full': '東京都中央区銀座7-2-22',
#    'addr:housename': '銀座同和ビル',
#    'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'branch': '銀座コリドー通り店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutah-bakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Fr 07:30-22:30; Sa 08:00-22:30; Su,PH 08:00-22:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-3575-0938',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 1894469039,
#   'lat': 35.6679087,
#   'lon': 139.7673177,
#   'tags': {'addr:full': '東京都中央区銀座5-15-8',
#    'addr:housename': '時事通信ビル',
#    'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'branch': '東銀座店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutah-bakkusu',
#    'opening_hours': 'Mo-Fr 07:00-21:00; Sa,Su,PH 08:00-20:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-3544-6240',
#    'source': 'Bing 2010;(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/',
#    'wifi': 'yes'}},
#  {'type': 'node',
#   'id': 1898471645,
#   'lat': 35.6776514,
#   'lon': 139.7708621,
#   'tags': {'addr:postcode': '104-0031',
#    'amenity': 'cafe',
#    'branch': '京橋丁目店',
#    'brand': '上島珈琲店',
#    'brand:wikidata': 'Q1185060',
#    'brand:wikipedia': 'ja:UCC上島珈琲',
#    'cuisine': 'coffee_shop',
#    'name': '上島珈琲店',
#    'name:en': 'Ueshima Coffee Ten',
#    'name:ja': '上島珈琲店',
#    'name:ja_rm': 'Ueshima Kohi Ten',
#    'operator': 'ユーシーシーフードサービスシステムズ',
#    'source': '(URL)',
#    'website': 'http://www.ueshima-coffee-ten.jp/',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 1917926558,
#   'lat': 35.6669331,
#   'lon': 139.7661697,
#   'tags': {'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'branch': '銀座7丁目',
#    'brand': 'カフェ・ド・クリエ',
#    'brand:en': 'Cafe de CRIE',
#    'brand:ja': 'カフェ・ド・クリエ',
#    'brand:wikidata': 'Q17219077',
#    'brand:wikipedia': 'ja:ポッカクリエイト',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'internet_access:fee': 'no',
#    'level': '0',
#    'name': 'カフェ・ド・クリエ',
#    'name:en': 'Cafe de CRIE',
#    'name:ja': 'カフェ・ド・クリエ',
#    'name:ja_rm': 'Kafe Do Kurie',
#    'opening_hours': 'wd 07:00-21:00; Sa,Su,PH 08:30-18:00',
#    'operator': 'ポッカ・クリエイト',
#    'phone': '+81-3-35421891',
#    'source': '(URL)',
#    'takeaway': 'yes',
#    'website': 'https://www.pokkacreate.co.jp/'}},
#  {'type': 'node',
#   'id': 1921449893,
#   'lat': 35.6657199,
#   'lon': 139.7681799,
#   'tags': {'addr:postcode': '104-0045',
#    'amenity': 'cafe',
#    'branch': '国立がん研究センター中央病院',
#    'brand': 'カフェ・ド・クリエ',
#    'brand:en': 'Cafe de CRIE',
#    'brand:ja': 'カフェ・ド・クリエ',
#    'brand:wikidata': 'Q17219077',
#    'brand:wikipedia': 'ja:ポッカクリエイト',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'カフェ・ド・クリエ',
#    'name:en': 'Cafe de CRIE',
#    'name:ja': 'カフェ・ド・クリエ',
#    'name:ja_rm': 'Kafe Do Kurie',
#    'opening_hours': 'Mo-Fr 07:00-20:00; Sa,Su,PH 08:00-19:00',
#    'operator': 'ポッカ・クリエイト',
#    'phone': '+81-3-35477550',
#    'smoking': 'no',
#    'takeaway': 'yes',
#    'website': 'https://www.pokkacreate.co.jp/'}},
#  {'type': 'node',
#   'id': 1926554530,
#   'lat': 35.667173,
#   'lon': 139.776781,
#   'tags': {'amenity': 'cafe',
#    'branch': '聖路加ガーデン店',
#    'brand': 'エクセルシオール カフェ',
#    'brand:en': 'EXCELSIOR CAFFÉ',
#    'brand:ja': 'エクセルシオール カフェ',
#    'brand:wikidata': 'Q11289828',
#    'brand:wikipedia': 'ja:エクセルシオール カフェ',
#    'cuisine': 'coffee_shop',
#    'name': 'エクセルシオール カフェ',
#    'name:en': 'EXCELSIOR CAFFE',
#    'name:ja': 'エクセルシオール カフェ',
#    'name:ja_rm': 'Ekuserusiohru Kafe',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa,Su,PH 08:00-20:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '+81-3-55502323',
#    'source': '(URL)',
#    'takeaway': 'yes',
#    'website': 'http://www.doutor.co.jp/exc/'}},
#  {'type': 'node',
#   'id': 1992017277,
#   'lat': 35.6749567,
#   'lon': 139.7636138,
#   'tags': {'amenity': 'cafe',
#    'brand': 'Pronto',
#    'brand:wikidata': 'Q11336224',
#    'brand:wikipedia': 'ja:プロントコーポレーション',
#    'cuisine': 'coffee_shop',
#    'layer': '1',
#    'level': '1',
#    'name': 'Pronto',
#    'name:en': 'PRONTO',
#    'name:it': 'Pronto',
#    'name:ja': 'プロント',
#    'name:ja_rm': 'Puronto',
#    'source': 'image',
#    'takeaway': 'yes',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 2017978529,
#   'lat': 35.6681654,
#   'lon': 139.7599602,
#   'tags': {'amenity': 'cafe', 'name': 'CAFÉ BALCONY', 'source': 'image;Bing'}},
#  {'type': 'node',
#   'id': 2018929303,
#   'lat': 35.6711218,
#   'lon': 139.7627649,
#   'tags': {'amenity': 'cafe',
#    'name': '風月堂',
#    'name:en': 'Fugetsudo',
#    'name:ja': '風月堂',
#    'name:ja_kana': 'ふうげつどう',
#    'name:ja_rm': 'Fugetsudo',
#    'source': 'image;Bing'}},
#  {'type': 'node',
#   'id': 2019045867,
#   'lat': 35.6692053,
#   'lon': 139.7610656,
#   'tags': {'amenity': 'cafe',
#    'brand': 'Pronto',
#    'brand:wikidata': 'Q11336224',
#    'brand:wikipedia': 'ja:プロントコーポレーション',
#    'cuisine': 'coffee_shop',
#    'name': 'Pronto',
#    'name:en': 'PRONTO',
#    'name:ja': 'プロント',
#    'name:ja_rm': 'Puronto',
#    'source': 'image;Bing',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 2019045868,
#   'lat': 35.670696,
#   'lon': 139.7610416,
#   'tags': {'amenity': 'cafe',
#    'name': 'R25 café',
#    'source': 'image;Bing',
#    'wikidata': 'Q11240392',
#    'wikipedia': 'ja:R25cafe'}},
#  {'type': 'node',
#   'id': 2019197418,
#   'lat': 35.6681112,
#   'lon': 139.7619956,
#   'tags': {'addr:street': '일본 〒104-0061 Tōkyō-to, 中央区銀座８−９−１６ 1F 長崎センタービル Cafe Paulista Gi',
#    'amenity': 'cafe',
#    'name': 'カフェ パウリスタ',
#    'name:en': 'CAFÉ PAULISTA',
#    'name:it': 'Paulista',
#    'name:ko': '파우리스타',
#    'wikidata': 'Q17228156',
#    'wikipedia': 'ja:カフェーパウリスタ'}},
#  {'type': 'node',
#   'id': 2135544279,
#   'lat': 35.6734291,
#   'lon': 139.7608512,
#   'tags': {'addr:full': '東京都千代田区有楽町1-3-7',
#    'amenity': 'cafe',
#    'branch': '有楽町日比谷口店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'check_date': '2023-09-01',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:it': 'Doutor',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'opening_hours': 'Mo-Fr 07:00-21:00; Sa,Su,PH 08:00-20:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'phone': '+81 3-3504-1821',
#    'smoking': 'separated',
#    'source': 'survey; (URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 2291366306,
#   'lat': 35.6723539,
#   'lon': 139.7600241,
#   'tags': {'amenity': 'cafe',
#    'name:en': 'MUJI flagship branch',
#    'source': 'image,2013-05;Bing'}},
#  {'type': 'node',
#   'id': 2291366348,
#   'lat': 35.673711,
#   'lon': 139.7610091,
#   'tags': {'amenity': 'cafe',
#    'layer': '-1',
#    'level': '-1',
#    'name': '珈琲茶館 集',
#    'source': 'image,2013-05;Bing'}},
#  {'type': 'node',
#   'id': 2291366349,
#   'lat': 35.6735696,
#   'lon': 139.7609583,
#   'tags': {'amenity': 'cafe',
#    'check_date': '2023-09-01',
#    'level': '0',
#    'name': '珈琲館 紅鹿舎',
#    'name:en': 'KO:HI:KAN',
#    'source': 'image,2013-05;Bing'}},
#  {'type': 'node',
#   'id': 2324069353,
#   'lat': 35.673704,
#   'lon': 139.761042,
#   'tags': {'amenity': 'cafe',
#    'check_date': '2023-09-01',
#    'level': '-1',
#    'name': '集'}},
#  {'type': 'node',
#   'id': 2429720248,
#   'lat': 35.671701,
#   'lon': 139.7647168,
#   'tags': {'amenity': 'cafe',
#    'name': 'WAKO ANNEX',
#    'source': 'image,2013-08,Bing'}},
#  {'type': 'node',
#   'id': 2430629060,
#   'lat': 35.6712181,
#   'lon': 139.7646792,
#   'tags': {'amenity': 'cafe',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:it': 'Doutor',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'phone': '+81 3-5537-8959',
#    'source': 'image,2013-08,Bing',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 2569152099,
#   'lat': 35.6756929,
#   'lon': 139.7617079,
#   'tags': {'addr:full': '東京都千代田区有楽町1-12-1',
#    'addr:housename': '新有楽町ビルB1F',
#    'amenity': 'cafe',
#    'branch': '新有楽町ビル店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'level': '-1',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_kana': 'どとーるこーひーしょっぷ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa 08:00-21:00; Su,PH 10:30-20:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '03-3240-8845',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 2778784658,
#   'lat': 35.6669696,
#   'lon': 139.7602728,
#   'tags': {'addr:full': '東京都港区新橋1-8-4',
#    'addr:housename': '丸忠ビル1F',
#    'amenity': 'cafe',
#    'branch': '新橋銀座口店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'check_date': '2023-01-20',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'level': '0',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'note': '1階が禁煙席、2階が禁煙席と喫煙席。',
#    'opening_hours': 'Mo-Fr 07:00-21:30; Sa 08:00-20:00; Su,PH 10:00-18:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'outdoor_seating': 'no',
#    'phone': '+81 3 3571 6562',
#    'smoking': 'separated',
#    'source': 'knowledge; (URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/',
#    'wheelchair': 'no',
#    'wifi': 'yes'}},
#  {'type': 'node',
#   'id': 2800311018,
#   'lat': 35.6703457,
#   'lon': 139.7616151,
#   'tags': {'addr:city': '中央区',
#    'addr:housenumber': '7-5-4',
#    'addr:postcode': '104-0061',
#    'addr:street': '銀座',
#    'amenity': 'cafe',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'yes',
#    'name': 'the SNACK',
#    'opening_hours': 'Mo-Fr 09:00-23:00; Sa 09:00-19:00',
#    'phone': '+81 03 5537 5862',
#    'smoking': 'outside',
#    'source': 'Survey',
#    'website': 'https://the-snack.jp/',
#    'wheelchair': 'no'}},
#  {'type': 'node',
#   'id': 2800570536,
#   'lat': 35.6699838,
#   'lon': 139.7603005,
#   'tags': {'amenity': 'cafe',
#    'name': '和蘭豆',
#    'name:en': 'Ranzu',
#    'source': 'image,2014-04;Bing;GSI/KIBAN'}},
#  {'type': 'node',
#   'id': 2882674739,
#   'lat': 35.6741754,
#   'lon': 139.7671463,
#   'tags': {'addr:full': '東京都中央区銀座2-5-2',
#    'amenity': 'cafe',
#    'branch': '銀座2丁目店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'level': '0;1;2;3',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'opening_hours': 'Mo-Fr 07:00-21:00; Sa,Su,PH 08:00-21:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'phone': '+81 3-5159-0360',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 2883448833,
#   'lat': 35.6728271,
#   'lon': 139.7696271,
#   'tags': {'amenity': 'cafe',
#    'name': 'Pour Cafe',
#    'name:it': 'Pour',
#    'source': 'image,2014-05;Bing;GSI/KIBAN 2500,NARO'}},
#  {'type': 'node',
#   'id': 2883448834,
#   'lat': 35.6734199,
#   'lon': 139.768551,
#   'tags': {'addr:full': '東京都中央区銀座1-9-12',
#    'amenity': 'cafe',
#    'branch': '銀座柳通り店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotoru Kohi Shoppu',
#    'opening_hours': 'Mo-Fr 07:00-21:00; Sa 07:30-20:00; Su,PH 07:30-19:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '03-3535-6638',
#    'smoking': 'separated',
#    'source': 'image,2014-05;Bing;GSI/KIBAN 2500,NARO',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 2901059906,
#   'lat': 35.6695947,
#   'lon': 139.7674312,
#   'tags': {'amenity': 'cafe',
#    'brand': 'Pronto',
#    'brand:wikidata': 'Q11336224',
#    'brand:wikipedia': 'ja:プロントコーポレーション',
#    'cuisine': 'coffee_shop',
#    'name': 'Pronto',
#    'name:en': 'PRONTO',
#    'name:ja': 'プロント',
#    'name:ja_rm': 'Puronto',
#    'source': 'image,2014-06;Bing;GSI/KIBAN 2500',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 3289232778,
#   'lat': 35.6762769,
#   'lon': 139.7635241,
#   'tags': {'addr:block_number': '5',
#    'addr:city': '千代田区',
#    'addr:flats': '東京国際フォーラム',
#    'addr:full': '東京都千代田区丸の内3丁目5-1 東京国際フォーラム1F',
#    'addr:housenumber': '1',
#    'addr:neighbourhood': '三丁目',
#    'addr:province': '東京都',
#    'addr:quarter': '丸の内',
#    'amenity': 'cafe',
#    'name': '神戸屋ダイニング',
#    'name:en': 'Kobeya Dining',
#    'opening_hours': 'Mo-Fr 07:30-21:00; Sa,Su 09:00-20:00',
#    'phone': '03-5220-1107',
#    'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 3371408375,
#   'lat': 35.669701,
#   'lon': 139.7654687,
#   'tags': {'amenity': 'cafe',
#    'cuisine': 'coffee_shop',
#    'name': '宮越屋珈琲',
#    'smoking': 'yes',
#    'source': 'survey'}},
#  {'type': 'node',
#   'id': 3608248439,
#   'lat': 35.6779135,
#   'lon': 139.7624703,
#   'tags': {'addr:full': '東京都千代田区丸の内3-3-1',
#    'addr:housename': '丸の内新東京ビル',
#    'addr:postcode': '100-0005',
#    'amenity': 'cafe',
#    'branch': '丸の内新東京ビル店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:es': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'name:zh': '星巴克',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Fr 07:00-22:30; Sa 08:00-21:00; Su,PH 10:00-20:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-3216-3552',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3608303393,
#   'lat': 35.6750146,
#   'lon': 139.7617717,
#   'tags': {'addr:full': '東京都千代田区有楽町1-10-1',
#    'addr:housename': '有楽町ビル1F',
#    'addr:postcode': '100-0006',
#    'amenity': 'cafe',
#    'branch': '有楽町ビル1階店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'level': '0',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa 09:00-22:00; Su,PH 09:00-21:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-6250-1021',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3608320493,
#   'lat': 35.6748021,
#   'lon': 139.7620952,
#   'tags': {'addr:full': '東京都千代田区有楽町1-10-1',
#    'addr:housename': '有楽町ビルB1F',
#    'addr:postcode': '100-0006',
#    'amenity': 'cafe',
#    'branch': '有楽町ビル地下1階店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'level': '-1',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Fr 06:00-22:00; Sa 09:00-21:00; Su,PH 09:00-20:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-5288-7075',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3608333109,
#   'lat': 35.6733331,
#   'lon': 139.760038,
#   'tags': {'addr:full': '東京都千代田区有楽町1-2-2',
#    'addr:housename': '日比谷シャンテ',
#    'addr:postcode': '100-0006',
#    'amenity': 'cafe',
#    'branch': '日比谷シャンテ店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Su 07:00-22:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-5510-7081',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/',
#    'wheelchair': 'no'}},
#  {'type': 'node',
#   'id': 3608353015,
#   'lat': 35.6743376,
#   'lon': 139.7636645,
#   'tags': {'addr:full': '東京都千代田区有楽町2-7-1',
#    'addr:housename': '有楽町マルイ',
#    'addr:postcode': '100-0006',
#    'amenity': 'cafe',
#    'branch': 'TSUTAYA 有楽町マルイ店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Sa 11:00-21:00; Su,PH 10:30-20:30',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '+81 3-6738-3888',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3608362328,
#   'lat': 35.6753161,
#   'lon': 139.7640645,
#   'tags': {'addr:full': '東京都千代田区有楽町2-9',
#    'addr:postcode': '100-0006',
#    'amenity': 'cafe',
#    'branch': 'JR有楽町駅京橋口店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Su 07:00-22:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-6870-6070',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/',
#    'wheelchair': 'no'}},
#  {'type': 'node',
#   'id': 3610053493,
#   'lat': 35.6667943,
#   'lon': 139.7596273,
#   'tags': {'addr:full': '東京都港区新橋2-19-3',
#    'addr:housename': 'カシケイビル1F',
#    'addr:postcode': '105-0004',
#    'amenity': 'cafe',
#    'branch': '新橋駅前店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'level': '0',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'opening_hours': 'Mo-Th 06:30-22:00; Fr 06:30-22:30; Sa 07:00-22:30; Su,PH 08:00-21:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-3573-6815',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/',
#    'wifi': 'yes'}},
#  {'type': 'node',
#   'id': 3610101775,
#   'lat': 35.6654683,
#   'lon': 139.7596584,
#   'tags': {'addr:full': '東京都港区東新橋1-1-8',
#    'addr:postcode': '105-0021',
#    'amenity': 'cafe',
#    'branch': 'ゆりかもめ新橋駅店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'level': '1',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Su 07:00-22:30',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-3574-8860',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3610164026,
#   'lat': 35.6642828,
#   'lon': 139.7618358,
#   'tags': {'addr:full': '東京都港区東新橋1-8-2',
#    'addr:housename': 'カレッタ汐留',
#    'addr:postcode': '105-7090',
#    'amenity': 'cafe',
#    'branch': 'カレッタ汐留店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa,Su,PH 09:00-21:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-5537-2471',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3610168553,
#   'lat': 35.6655379,
#   'lon': 139.7609614,
#   'tags': {'addr:full': '東京都港区東新橋1-5-2',
#    'addr:housename': '汐留シティセンター',
#    'addr:postcode': '105-7101',
#    'amenity': 'cafe',
#    'branch': '汐留シティセンター店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa 10:00-19:00; Su,PH 10:00-18:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-5537-2780',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/',
#    'wifi': 'yes'}},
#  {'type': 'node',
#   'id': 3610206606,
#   'lat': 35.6630359,
#   'lon': 139.7607914,
#   'tags': {'addr:full': '東京都港区東新橋1-9-1',
#    'addr:housename': '東京汐留ビルディング',
#    'addr:postcode': '105-7302',
#    'amenity': 'cafe',
#    'branch': 'ぺディ汐留店',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'drive_through': 'no',
#    'internet_access': 'wlan',
#    'level': '-2',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'name:ja_rm': 'Sutābakkusu',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa,Su,PH 08:00-20:00',
#    'operator': 'スターバックスコーヒージャパン',
#    'phone': '03-6274-5021',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/'}},
#  {'type': 'node',
#   'id': 3624471006,
#   'lat': 35.665433,
#   'lon': 139.7614174,
#   'tags': {'addr:full': '東京都港区東新橋1-5-2',
#    'addr:housename': '汐留シティセンターB2F',
#    'amenity': 'cafe',
#    'branch': '汐留シティセンター店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'cuisine': 'coffee_shop',
#    'level': '-2',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa 10:00-19:00; Su,PH 10:00-18:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-6280-6534',
#    'smoking': 'no',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wifi': 'no'}},
#  {'type': 'node',
#   'id': 3624486064,
#   'lat': 35.6619174,
#   'lon': 139.7599288,
#   'tags': {'addr:full': '東京都港区東新橋1-9-2',
#    'addr:housename': '汐留住友ビル2F',
#    'amenity': 'cafe',
#    'branch': '汐留住友ビル店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:wikidata': 'Q3541983',
#    'cuisine': 'coffee_shop',
#    'level': '1',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa,Su,PH 08:00-20:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-6228-5884',
#    'smoking': 'yes',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wifi': 'yes'}},
#  {'type': 'node',
#   'id': 3625181998,
#   'lat': 35.6647808,
#   'lon': 139.7601178,
#   'tags': {'addr:full': '東京都港区東新橋1-5-44',
#    'addr:housename': '日本テレビタワーB2F',
#    'amenity': 'cafe',
#    'branch': '日テレプラザ店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:wikidata': 'Q3541983',
#    'cuisine': 'coffee_shop',
#    'level': '-2',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Su 07:30-22:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-5537-6053',
#    'smoking': 'yes',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wifi': 'yes'}},
#  {'type': 'node',
#   'id': 3626074451,
#   'lat': 35.6777815,
#   'lon': 139.7670236,
#   'tags': {'addr:full': '東京都千代田区丸の内1-11-1',
#    'addr:housename': 'パシフィックセンチュリープレイス丸の内B1F',
#    'amenity': 'cafe',
#    'branch': 'PCP丸の内店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'level': '-1',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Fr 07:30-22:00; Sa 09:00-19:00; Su,PH 09:00-18:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-5208-8423',
#    'smoking': 'no',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wikidata': 'Q11316408',
#    'wikipedia': 'ja:タリーズコーヒージャパン'}},
#  {'type': 'node',
#   'id': 3626519833,
#   'lat': 35.6710075,
#   'lon': 139.7660435,
#   'tags': {'addr:full': '東京都中央区銀座4-6-16',
#    'addr:housename': '三越銀座店1F',
#    'addr:housenumber': '三越銀座店1F',
#    'amenity': 'cafe',
#    'branch': 'デンマーク・ザ・ロイヤルカフェ銀座三越店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'level': '0',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:it': "Tully's",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Su 10:30-22:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '+81 3-3561-7018',
#    'smoking': 'no',
#    'source': '(URL) 2015',
#    'takeaway': 'no',
#    'website': 'http://www.tullys.co.jp/',
#    'wikidata': 'Q11316408',
#    'wikipedia': 'ja:タリーズコーヒージャパン'}},
#  {'type': 'node',
#   'id': 3626534377,
#   'lat': 35.6739184,
#   'lon': 139.765179,
#   'tags': {'addr:full': '東京都中央区銀座3-2-1',
#    'addr:housename': 'プランタン銀座B2F',
#    'amenity': 'cafe',
#    'branch': 'プランタン銀座店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'cuisine': 'coffee_shop',
#    'level': '-2',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Sa 11:00-21:00; Su,PH 11:00-20:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '+81 3-6228-7218',
#    'smoking': 'no',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wifi': 'no',
#    'wikidata': 'Q11316408',
#    'wikipedia': 'ja:タリーズコーヒージャパン'}},
#  {'type': 'node',
#   'id': 3626551224,
#   'lat': 35.6692944,
#   'lon': 139.7678992,
#   'tags': {'addr:full': '東京都中央区銀座4-12-15',
#    'addr:housename': 'GINZAKABUKIZA B2F',
#    'amenity': 'cafe',
#    'branch': '歌舞伎座店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'level': '-2',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Fr 07:30-22:00; Sa,Su,PH 08:00-22:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-3547-3370',
#    'smoking': 'yes',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/'}},
#  {'type': 'node',
#   'id': 3626959746,
#   'lat': 35.6714862,
#   'lon': 139.7657568,
#   'tags': {'addr:full': '東京都中央区銀座4-6-16',
#    'addr:housename': '銀座三越ル・プレイス内3F',
#    'addr:housenumber': '銀座三越ル・プレイス内3F',
#    'amenity': 'cafe',
#    'branch': '銀座三越コミュ店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'level': '2',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:it': "Tully's",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Su 10:30-20:00',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '+81 3-5159-0655',
#    'smoking': 'no',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 3627058358,
#   'lat': 35.6693441,
#   'lon': 139.7718366,
#   'tags': {'addr:full': '東京都中央区築地1-9-2',
#    'addr:housename': '伊勢常ビル1F',
#    'amenity': 'cafe',
#    'branch': '築地一丁目店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'brand:wikipedia': "en:Tully's Coffee",
#    'contact:phone': '+81 3-5148-2991',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'level': '0',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Fr 07:30-21:00; Sa,Su,PH 08:00-19:00',
#    'operator': 'タリーズコーヒージャパン',
#    'smoking': 'yes',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wikidata': 'Q11316408',
#    'wikipedia': 'ja:タリーズコーヒージャパン'}},
#  {'type': 'node',
#   'id': 3627089712,
#   'lat': 35.6642849,
#   'lon': 139.7669614,
#   'tags': {'addr:full': '東京都中央区築地5-3-2',
#    'addr:housename': '朝日新聞東京本社ビル2F',
#    'amenity': 'cafe',
#    'branch': '朝日新聞東京本社ビル店',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:ja': 'タリーズコーヒー',
#    'brand:wikidata': 'Q3541983',
#    'cuisine': 'coffee_shop',
#    'level': '1',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee",
#    'name:ja': 'タリーズコーヒー',
#    'name:ja_rm': 'Tarīzu Kohī',
#    'opening_hours': 'Mo-Fr 08:00-21:00; Sa 09:00-18:00; Su,PH off',
#    'operator': 'タリーズコーヒージャパン',
#    'phone': '03-3524-1155',
#    'smoking': 'no',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.tullys.co.jp/',
#    'wifi': 'no',
#    'wikidata': 'Q11316408',
#    'wikipedia': 'ja:タリーズコーヒージャパン'}},
#  {'type': 'node',
#   'id': 3632323144,
#   'lat': 35.6755871,
#   'lon': 139.7642191,
#   'tags': {'addr:full': '東京都千代田区丸の内3-6-11',
#    'amenity': 'cafe',
#    'branch': '有楽町駅前店',
#    'brand': 'ドトール',
#    'brand:en': 'DOUTOR',
#    'brand:ja': 'ドトール',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:it': 'Doutor',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Sa 07:00-22:00; Su,PH 08:00-21:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'phone': '03-3214-6882',
#    'short_name': 'DCS',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/',
#    'wheelchair': 'no'}},
#  {'type': 'node',
#   'id': 3633690713,
#   'lat': 35.674688,
#   'lon': 139.7614481,
#   'tags': {'addr:full': '東京都千代田区有楽町1-7-1',
#    'amenity': 'cafe',
#    'branch': '有楽町電気ビル店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:it': 'Doutor',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Fr 07:00-21:00; Sa 08:00-19:00; Su,PH 10:00-19:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '03-3217-2521',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/',
#    'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 3633740842,
#   'lat': 35.6712551,
#   'lon': 139.7607548,
#   'tags': {'addr:full': '東京都中央区銀座6-3-12',
#    'addr:housename': '数寄屋ビル1F',
#    'amenity': 'cafe',
#    'branch': '数寄屋橋店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'level': '0',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Fr 07:30-21:30; Sa 11:00-19:00; Su,PH 11:00-18:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'phone': '+81 3-3573-1789',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 3633816443,
#   'lat': 35.6699107,
#   'lon': 139.7687336,
#   'tags': {'addr:full': '東京都中央区銀座4-11-6',
#    'addr:housename': '銀座島倉ビル',
#    'amenity': 'cafe',
#    'branch': '銀座4丁目店',
#    'brand': 'ドトール',
#    'brand:en': 'DOUTOR',
#    'brand:ja': 'ドトール',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Fr 06:45-21:30; Sa 07:00-20:00; Su,PH 07:30-20:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '03-3543-8922',
#    'short_name': 'DCS',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 3633920568,
#   'lat': 35.6680103,
#   'lon': 139.7736411,
#   'tags': {'addr:full': '東京都中央区築地3-7-1',
#    'addr:housename': '築地吉本ビル',
#    'amenity': 'cafe',
#    'branch': '築地聖路加通り店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Fr 06:45-22:00; Sa 07:30-20:00; Su,PH 08:00-19:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '03-3544-1352',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 3634833417,
#   'lat': 35.6689212,
#   'lon': 139.7650152,
#   'tags': {'addr:full': '東京都中央区銀座6-13-6',
#    'amenity': 'cafe',
#    'branch': '銀座6丁目店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'check_date': '2023-01-20',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:es': 'Doutor',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Su 07:00-21:00; Sa 07:00-20:00; Su,PH 08:00-19:00',
#    'operator': 'ドトールコーヒー',
#    'phone': '03-5565-0913',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 3634856994,
#   'lat': 35.6704753,
#   'lon': 139.7749138,
#   'tags': {'addr:full': '東京都中央区新富2-14-6',
#    'addr:housename': 'ONZE1852',
#    'amenity': 'cafe',
#    'branch': '新富町店',
#    'brand': 'ドトールコーヒーショップ',
#    'brand:en': 'Doutor',
#    'brand:ja': 'ドトールコーヒーショップ',
#    'brand:wikidata': 'Q11322732',
#    'brand:wikipedia': 'ja:ドトールコーヒーショップ',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': 'ドトールコーヒーショップ',
#    'name:en': 'Doutor Coffee Shop',
#    'name:ja': 'ドトールコーヒーショップ',
#    'name:ja_rm': 'Dotōru Kōhī Shoppu',
#    'opening_hours': 'Mo-Fr 07:00-21:00; Sa 08:00-17:00',
#    'operator': 'ドトールコーヒー',
#    'operator:wikidata': 'Q11322732',
#    'operator:wikipedia': 'ja:ドトールコーヒーショップ',
#    'phone': '03-3206-6911',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://www.doutor.co.jp/dcs/'}},
#  {'type': 'node',
#   'id': 3658925991,
#   'lat': 35.6777903,
#   'lon': 139.7630482,
#   'tags': {'addr:full': '東京都千代田区丸の内3-3-1',
#    'addr:housename': '新東京ビル',
#    'addr:postcode': '100-0005',
#    'alt_name:en': 'Saint Marc Café',
#    'amenity': 'cafe',
#    'branch': '丸の内新東京ビル店',
#    'brand': 'サンマルクカフェ',
#    'brand:en': 'ST.MARC CAFÉ',
#    'brand:ja': 'サンマルクカフェ',
#    'brand:wikidata': 'Q11305989',
#    'brand:wikipedia': 'ja:サンマルクホールディングス',
#    'cuisine': 'coffee_shop',
#    'name': 'サンマルクカフェ',
#    'name:en': 'ST.MARC CAFÉ',
#    'name:it': 'St-Marc',
#    'name:ja': 'サンマルクカフェ',
#    'name:ja_rm': 'Sanmaruku Kafe',
#    'opening_hours': 'Mo-Su 07:00-22:00',
#    'operator': 'サンマルクカフェ',
#    'phone': '03-5224-3309',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'http://www.saint-marc-hd.com/cafe/',
#    'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 3661044966,
#   'lat': 35.6748036,
#   'lon': 139.7618878,
#   'tags': {'addr:full': '東京都千代田区有楽町1-10-1',
#    'addr:housename': '有楽町ビルB1F',
#    'addr:housenumber': '有楽町ビルB1F',
#    'addr:postcode': '100-0006',
#    'alt_name:en': 'Saint Marc Café',
#    'amenity': 'cafe',
#    'branch': '東京都有楽町ビル店',
#    'brand': 'サンマルクカフェ',
#    'brand:en': 'ST.MARC CAFÉ',
#    'brand:ja': 'サンマルクカフェ',
#    'brand:wikidata': 'Q11305989',
#    'brand:wikipedia': 'ja:サンマルクホールディングス',
#    'cuisine': 'coffee_shop',
#    'level': '-1',
#    'name': 'サンマルクカフェ',
#    'name:en': 'ST.MARC CAFÉ',
#    'name:it': 'St-Marc',
#    'name:ja': 'サンマルクカフェ',
#    'name:ja_rm': 'Sanmaruku Kafe',
#    'operator': 'サンマルクカフェ',
#    'phone': '03-6266-9309',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
# ...
#    'operator': 'シャノアール',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://chatnoir-company.com/chatnoir/html/brand/brand_veloce.html'}},
#  {'type': 'node',
#   'id': 3677143837,
#   'lat': 35.6681127,
#   'lon': 139.7729637,
#   'tags': {'addr:full': '東京都中央区築地3-9-10',
#    'addr:housename': '築地ビル1F',
#    'addr:postcode': '104-0045',
#    'amenity': 'cafe',
#    'branch': '築地店',
#    'brand': 'カフェ・ベローチェ',
#    'brand:en': 'CAFFÈ VELOCE',
#    'brand:ja': 'カフェ・ベローチェ',
#    'brand:wikidata': 'Q11294597',
#    'brand:wikipedia': 'ja:カフェ・ベローチェ',
#    'cuisine': 'coffee_shop',
#    'level': '0',
#    'name': 'カフェ・ベローチェ',
#    'name:en': 'CAFFÈ VELOCE',
#    'name:ja': 'カフェ・ベローチェ',
#    'name:ja_rm': 'Kafe Berōche',
#    'opening_hours': 'Mo-Fr 06:45-22:00; Sa,Su,PH 07:00-22:00',
#    'operator': 'シャノアール',
#    'phone': '03-3546-1101',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://chatnoir-company.com/chatnoir/html/brand/brand_veloce.html',
#    'wheelchair': 'no'}},
#  {'type': 'node',
#   'id': 3681655635,
#   'lat': 35.6779335,
#   'lon': 139.7754417,
#   'tags': {'addr:full': '東京都中央区八丁堀1-2-8',
#    'addr:housename': 'タビックスビル1F',
#    'addr:postcode': '104-0032',
#    'amenity': 'cafe',
#    'branch': '八丁堀一丁目店',
#    'brand': 'カフェ・ベローチェ',
#    'brand:en': 'CAFFÈ VELOCE',
#    'brand:ja': 'カフェ・ベローチェ',
#    'brand:wikidata': 'Q11294597',
#    'brand:wikipedia': 'ja:カフェ・ベローチェ',
#    'cuisine': 'coffee_shop',
#    'level': '0',
#    'name': 'カフェ・ベローチェ',
#    'name:en': 'CAFFÈ VELOCE',
#    'name:ja': 'カフェ・ベローチェ',
#    'name:ja_rm': 'Kafe Berōche',
#    'opening_hours': 'Mo-Sa 07:00-22:00; Su,PH 07:00-21:00',
#    'operator': 'シャノアール',
#    'phone': '03-5541-0074',
#    'smoking': 'separated',
#    'source': '(URL) 2015',
#    'takeaway': 'yes',
#    'website': 'https://chatnoir-company.com/chatnoir/html/brand/brand_veloce.html'}},
#  {'type': 'node',
#   'id': 3806355357,
#   'lat': 35.672285,
#   'lon': 139.768511,
#   'tags': {'amenity': 'cafe',
#    'name': 'ミタスカフェ',
#    'name:en': 'Mitas Cafe',
#    'name:es': 'Mitas Cafe',
#    'name:it': 'Mitas'}},
#  {'type': 'node',
#   'id': 4271130089,
#   'lat': 35.6760885,
#   'lon': 139.7759195,
#   'tags': {'addr:housenumber': '2-19-11',
#    'addr:postcode': '104-0032',
#    'addr:street': 'Hatchobori 2-19-11',
#    'amenity': 'cafe',
#    'name': 'Roar Coffee',
#    'opening_hours': 'Mo-Fr 08:00-23:00',
#    'website': 'www.roar-coffee.com'}},
#  {'type': 'node',
#   'id': 4286785291,
#   'lat': 35.6713262,
#   'lon': 139.7637212,
#   'tags': {'addr:housenumber': '5-5-6',
#    'addr:street': '西五番街通り',
#    'amenity': 'cafe',
#    'cuisine': 'tea',
#    'name': 'Cha Ginza',
#    'phone': '+81 3 3571 1211'}},
#  {'type': 'node',
#   'id': 4317800492,
#   'lat': 35.675862,
#   'lon': 139.7666515,
#   'tags': {'amenity': 'cafe'}},
#  {'type': 'node',
#   'id': 4367486089,
#   'lat': 35.6679258,
#   'lon': 139.7622872,
#   'tags': {'amenity': 'cafe',
#    'cuisine': 'coffee_shop',
#    'name': "Cafe de l'ambre",
#    'name:ja': 'カフェ・ド・ランブル',
#    'opening_hours': 'Mo-Sa 12:00-22:00; Su 12:00-19:00',
#    'website': 'http://www.cafedelambre.com/'}},
#  {'type': 'node',
#   'id': 4450068890,
#   'lat': 35.6767958,
#   'lon': 139.7689319,
#   'tags': {'addr:block_number': '4',
#    'addr:housenumber': '16',
#    'addr:neighbourhood': '2',
#    'addr:province': '東京都',
#    'addr:quarter': '京橋',
#    'addr:suburb': '中央区',
#    'amenity': 'cafe',
#    'name': 'Meiji 100% Chocolate Cafe',
#    'name:ja': 'Meiji 100% Chocolate Cafe',
#    'phone': '+81-3-3273-3184'}},
#  {'type': 'node',
#   'id': 4513561289,
#   'lat': 35.6680482,
#   'lon': 139.7719852,
#   'tags': {'amenity': 'cafe', 'name:en': 'Turret Coffee'}},
#  {'type': 'node',
#   'id': 4554922589,
#   'lat': 35.6736545,
#   'lon': 139.7625388,
#   'tags': {'amenity': 'cafe', 'name:en': 'The Monocle Cafe'}},
#  {'type': 'node',
#   'id': 4566270089,
#   'lat': 35.6769902,
#   'lon': 139.761642,
#   'tags': {'amenity': 'cafe',
#    'name': 'Ippodo tea store',
#    'name:it': 'Ippodo Tea Store',
#    'name:ja': 'Ippodo tea store'}},
#  {'type': 'node',
#   'id': 4757003424,
#   'lat': 35.6748809,
#   'lon': 139.7657577,
#   'tags': {'amenity': 'cafe', 'name': '十一房咖啡店', 'name:ja': '十一房咖啡店'}},
#  {'type': 'node',
#   'id': 4794783929,
#   'lat': 35.6684723,
#   'lon': 139.7679498,
#   'tags': {'amenity': 'cafe', 'name': 'ルノアール', 'source': 'survey'}},
#  {'type': 'node',
#   'id': 4823022550,
#   'lat': 35.6694275,
#   'lon': 139.7643067,
#   'tags': {'amenity': 'cafe',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'wlan',
#    'internet_access:fee': 'no',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:it': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'smoking': 'no',
#    'takeaway': 'yes',
#    'website': 'https://www.starbucks.co.jp/store/search/detail.php?id=1374'}},
#  {'type': 'node',
#   'id': 4879750722,
#   'lat': 35.6749462,
#   'lon': 139.7668592,
#   'tags': {'addr:housenumber': 'B1F',
#    'addr:postcode': '104-0061',
#    'amenity': 'cafe',
#    'name:en': 'Cafe Fredy',
#    'opening_hours': 'Mo-Su 11:00-20:30',
#    'phone': '+81335642077'}},
#  {'type': 'node',
#   'id': 4943535221,
#   'lat': 35.6710055,
#   'lon': 139.7618754,
#   'tags': {'amenity': 'cafe',
#    'name': 'オスロコーヒー',
#    'name:en': 'Oslo coffee',
#    'name:es': 'Oslo coffee',
#    'name:ja': 'オスロコーヒー'}},
#  {'type': 'node',
#   'id': 5015687236,
#   'lat': 35.6655358,
#   'lon': 139.7591114,
#   'tags': {'amenity': 'cafe',
#    'brand:wikidata': 'Q11649991',
#    'name': 'ルノアール',
#    'name:en': 'Renoir',
#    'name:es': 'Renoir'}},
#  {'type': 'node',
#   'id': 5015688531,
#   'lat': 35.665956,
#   'lon': 139.7594966,
#   'tags': {'amenity': 'cafe',
#    'name': 'ポンヌフ',
#    'name:en': 'Pont Neuf',
#    'name:es': 'Pont Neuf',
#    'name:ja_rm': "Pon'nufu"}},
#  {'type': 'node',
#   'id': 5015695340,
#   'lat': 35.6625186,
#   'lon': 139.7604031,
#   'tags': {'amenity': 'cafe',
#    'brand': 'タリーズコーヒー',
#    'brand:en': "Tully's Coffee",
#    'brand:wikidata': 'Q3541983',
#    'name': 'タリーズコーヒー',
#    'name:en': "Tully's Coffee"}},
#  {'type': 'node',
#   'id': 5015902069,
#   'lat': 35.6657547,
#   'lon': 139.759244,
#   'tags': {'amenity': 'cafe', 'name': 'スターバックスコーヒー'}},
#  {'type': 'node',
#   'id': 5053829029,
#   'lat': 35.6742964,
#   'lon': 139.7677894,
#   'tags': {'addr:street': '2nd floor, Pola Ginza building, 1-7-7 Ginza, Chuo-ku, Tokyo',
#    'amenity': 'cafe',
#    'name': 'HIGASHIYA GINZA',
#    'name:ja': 'HIGASHIYA GINZA'}},
#  {'type': 'node',
#   'id': 5104603735,
#   'lat': 35.6655545,
#   'lon': 139.7589801,
#   'tags': {'amenity': 'cafe',
#    'cuisine': 'sandwich',
#    'name': '新橋珈琲店 S.P.I.D Group',
#    'opening_hours': 'Mo-Sa 07:00-23:00; Su, PH 08:00-21:00',
#    'smoking': 'isolated',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 5175419523,
#   'lat': 35.668327,
#   'lon': 139.7615735,
#   'tags': {'amenity': 'cafe',
#    'name:en': 'Fantasy Dining Alice in a Labyrinth'}},
#  {'type': 'node',
#   'id': 5208155421,
#   'lat': 35.6762888,
#   'lon': 139.7619345,
#   'tags': {'amenity': 'cafe',
#    'name': 'サダハルアオキ',
#    'opening_hours': 'Mo-Su 11:00-19:15'}},
#  {'type': 'node',
#   'id': 5208155423,
#   'lat': 35.6711917,
#   'lon': 139.7638039,
#   'tags': {'amenity': 'cafe',
#    'name': '銀座ぶどうの木',
#    'name:ja_rm': 'Ginzabudōnoki',
#    'opening_hours': 'Mo-Su 11:00-18:15'}},
#  {'type': 'node',
#   'id': 5237380316,
#   'lat': 35.6732289,
#   'lon': 139.7706896,
#   'tags': {'amenity': 'cafe', 'name': '舘田珈琲'}},
#  {'type': 'node',
#   'id': 5237380342,
#   'lat': 35.6749012,
#   'lon': 139.7767769,
#   'tags': {'amenity': 'cafe', 'name': 'コロラド', 'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 5237380356,
#   'lat': 35.6747634,
#   'lon': 139.7746787,
#   'tags': {'amenity': 'cafe', 'name': 'Vino daily stand'}},
#  {'type': 'node',
#   'id': 5237390676,
#   'lat': 35.6718769,
#   'lon': 139.7694746,
#   'tags': {'amenity': 'cafe', 'name': 'SWAN CAFE'}},
#  {'type': 'node',
#   'id': 5706772774,
#   'lat': 35.6687375,
#   'lon': 139.7642416,
#   'tags': {'amenity': 'cafe',
#    'brand': 'ルノアール',
#    'brand:en': 'Renoir',
#    'brand:ja': 'ルノアール',
#    'brand:wikidata': 'Q11649991',
#    'brand:wikipedia': 'ja:銀座ルノアール',
#    'check_date': '2023-01-20',
#    'cuisine': 'coffee_shop',
#    'level': '0',
#    'name': 'ルノアール',
#    'name:en': 'Renoir',
#    'name:es': 'Renoir',
#    'name:ja': 'ルノアール',
#    'official_name': '喫茶室ルノアール',
#    'official_name:en': 'Ginza Renoir',
#    'official_name:ja': '喫茶室ルノアール',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 5781511095,
#   'lat': 35.6752588,
#   'lon': 139.7622774,
#   'tags': {'amenity': 'cafe', 'level': '0', 'name': 'Oriental Hotel'}},
#  {'type': 'node',
#   'id': 5837405070,
#   'lat': 35.67653,
#   'lon': 139.7701465,
#   'tags': {'amenity': 'cafe',
#    'brand': '俺のBakery&Cafe',
#    'cuisine': 'bakery',
#    'level': '0',
#    'name': '俺のベーカリー&カフェ',
#    'name:ja': '俺のベーカリー&カフェ',
#    'source': 'survey'}},
#  {'type': 'node',
#   'id': 5884880793,
#   'lat': 35.6695932,
#   'lon': 139.7642308,
#   'tags': {'amenity': 'cafe', 'name:en': 'Elle Cafe'}},
#  {'type': 'node',
#   'id': 6296041591,
#   'lat': 35.6698367,
#   'lon': 139.7688054,
#   'tags': {'amenity': 'cafe',
#    'cuisine': 'sandwich',
#    'name': 'アメリカン',
#    'opening_hours': 'Mo-Fr 08:00-10:30, 12:00-15:00',
#    'phone': '0335420922'}},
#  {'type': 'node',
#   'id': 6314683086,
#   'lat': 35.6663403,
#   'lon': 139.7595648,
#   'tags': {'addr:housenumber': '港区新橋2-20-15 1F',
#    'amenity': 'cafe',
#    'cuisine': 'pasta;curry',
#    'name': 'カフェテラス ポンヌフ',
#    'name:en': 'PONT NEUF',
#    'opening_hours': 'Mo-Fr 11:15-16:00, 17:30-20:00; Sa 11:15-15:00',
#    'phone': '0335725346'}},
#  {'type': 'node',
#   'id': 6324598389,
#   'lat': 35.6655306,
#   'lon': 139.7699267,
#   'tags': {'amenity': 'cafe',
#    'cuisine': 'coffee_shop',
#    'name': '喫茶マコ',
#    'outdoor_seating': 'no'}},
#  {'type': 'node',
#   'id': 6324598392,
#   'lat': 35.6655306,
#   'lon': 139.7699267,
#   'tags': {'addr:block_number': '中富ビル2F',
#    'addr:city': '中央区',
#    'addr:neighbourhood': '4丁目',
#    'addr:postcode': '104-0045',
#    'addr:province': '東京都',
#    'addr:quarter': '築地',
#    'amenity': 'cafe',
#    'cuisine': 'coffee_shop;japanese',
#    'name': '喫茶マコ',
#    'outdoor_seating': 'no'}},
#  {'type': 'node',
#   'id': 6434188585,
#   'lat': 35.6689708,
#   'lon': 139.7619927,
#   'tags': {'amenity': 'cafe', 'name:en': 'Toriba Coffee'}},
#  {'type': 'node',
#   'id': 6467509503,
#   'lat': 35.6761207,
#   'lon': 139.7704486,
#   'tags': {'amenity': 'cafe',
#    'name': 'Bless Coffee',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 6479149086,
#   'lat': 35.672443,
#   'lon': 139.7626886,
#   'tags': {'amenity': 'cafe', 'name:en': 'Tully’s coffee B1F'}},
#  {'type': 'node',
#   'id': 6839143886,
#   'lat': 35.6651585,
#   'lon': 139.7710742,
#   'tags': {'amenity': 'cafe', 'name:en': 'Matcha Stand Maruni'}},
#  {'type': 'node',
#   'id': 6894432102,
#   'lat': 35.6742873,
#   'lon': 139.759429,
#   'tags': {'amenity': 'cafe',
#    'name': 'al bicerin',
#    'source': 'survey',
#    'takeaway': 'only'}},
#  {'type': 'node',
#   'id': 6898440925,
#   'lat': 35.6740885,
#   'lon': 139.7596818,
#   'tags': {'amenity': 'cafe',
#    'brand': 'スターバックス',
#    'brand:en': 'Starbucks',
#    'brand:ja': 'スターバックス',
#    'brand:wikidata': 'Q37158',
#    'brand:wikipedia': 'ja:スターバックス',
#    'cuisine': 'coffee_shop',
#    'layer': '-1',
#    'name': 'スターバックス',
#    'name:en': 'Starbucks',
#    'name:ja': 'スターバックス',
#    'official_name': 'スターバックスコーヒー',
#    'official_name:en': 'Starbucks Coffee',
#    'official_name:ja': 'スターバックスコーヒー',
#    'source': 'survey',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 6898440926,
#   'lat': 35.6741571,
#   'lon': 139.7595698,
#   'tags': {'amenity': 'cafe',
#    'layer': '-1',
#    'name': "Pâtisserie & Café DEL'IMMO",
#    'source': 'survey'}},
#  {'type': 'node',
#   'id': 6898515511,
#   'lat': 35.6740722,
#   'lon': 139.7595035,
#   'tags': {'amenity': 'cafe',
#    'name': 'DEAN & DELUCA',
#    'opening_hours': 'Mo-Fr 07:00-22:00; Sa,Su,PH 08:00-21:00',
#    'outdoor_seating': 'yes',
#    'source': 'survey'}},
#  {'type': 'node',
#   'id': 6900192227,
#   'lat': 35.6737083,
#   'lon': 139.7595263,
#   'tags': {'amenity': 'cafe',
#    'name': 'buvette',
#    'outdoor_seating': 'yes',
#    'source': 'survey',
#    'wheelchair': 'limited'}},
#  {'type': 'node',
#   'id': 7159841506,
#   'lat': 35.6725797,
#   'lon': 139.7581987,
#   'tags': {'amenity': 'cafe',
#    'name': 'ランデブーラウンジ',
#    'name:en': 'THE RANDEZ -VOUZ LOUNGE',
#    'wheelchair': 'yes'}},
#  {'type': 'node',
#   'id': 7237906203,
#   'lat': 35.6629972,
#   'lon': 139.7606913,
#   'tags': {'amenity': 'cafe',
#    'brand': 'エクセルシオール カフェ',
#    'brand:en': 'EXCELSIOR CAFFÉ',
#    'brand:ja': 'エクセルシオール カフェ',
#    'brand:wikidata': 'Q11289828',
#    'brand:wikipedia': 'ja:エクセルシオール カフェ',
#    'cuisine': 'coffee_shop',
#    'level': '1',
#    'name': 'エクセルシオール カフェ',
#    'name:ja': 'エクセルシオール カフェ',
#    'takeaway': 'yes'}},
#  {'type': 'node',
#   'id': 7440039131,
#   'lat': 35.6723365,
#   'lon': 139.7648059,
#   'tags': {'amenity': 'cafe', 'name': 'ploom shop 銀座店'}},
#  {'type': 'node',
#   'id': 7638823592,
#   'lat': 35.6680525,
#   'lon': 139.7635371,
#   'tags': {'amenity': 'cafe', 'name': 'チーパズカフェ', 'name:en': 'Cheepa’s Cafe'}},
#  {'type': 'node',
#   'id': 8088339156,
#   'lat': 35.6680279,
#   'lon': 139.7693813,
#   'tags': {'amenity': 'cafe',
#    'branch': '東銀座店',
#    'cuisine': 'fast_food;international',
#    'diet:vegan': 'only',
#    'name': 'KOMEDA is □',
#    'name:ja_rm': 'コメダイズ'}},
#  {'type': 'node',
#   'id': 9195099569,
#   'lat': 35.6649544,
#   'lon': 139.7725408,
#   'tags': {'amenity': 'cafe', 'name': 'ネスク'}},
#  {'type': 'node',
#   'id': 10080852921,
#   'lat': 35.665543,
#   'lon': 139.7579905,
#   'tags': {'amenity': 'cafe', 'check_date': '2022-10-07'}},
#  {'type': 'node',
#   'id': 10294527009,
#   'lat': 35.6739126,
#   'lon': 139.7761659,
#   'tags': {'amenity': 'cafe', 'name:en': 'CAFE'}},
#  {'type': 'node',
#   'id': 10570223956,
#   'lat': 35.6678029,
#   'lon': 139.7645135,
#   'tags': {'amenity': 'cafe',
#    'check_date': '2023-01-20',
#    'level': '3',
#    'name': 'Tea ginza'}},
#  {'type': 'node',
#   'id': 10936950893,
#   'lat': 35.6711851,
#   'lon': 139.7635328,
#   'tags': {'amenity': 'cafe',
#    'branch': '銀座本店',
#    'level': '1;2',
#    'name': 'ピエールマルコリーニ',
#    'name:en': 'Pierre Marcolini'}},
#  {'type': 'node',
#   'id': 10937003714,
#   'lat': 35.675581,
#   'lon': 139.7665872,
#   'tags': {'addr:street': '1 Chome-1-2-1 Ginza, 中央区 Chūō-ku, Tōkyō-to 104-0061, 일본',
#    'amenity': 'cafe',
#    'level': '0',
#    'name': 'ラ・カンティーヌ セントル',
#    'name:en': 'La Cantine Centre',
#    'name:ko': '센트레 더 베이커리',
#    'opening_hours': 'Mo-Su 10:00-19:00',
#    'phone': '+81 3 3562 3106',
#    'shop': 'bakery'}},
#  {'type': 'node',
#   'id': 11133745006,
#   'lat': 35.6721438,
#   'lon': 139.7624837,
#   'tags': {'amenity': 'cafe',
#    'name:en': 'Truedan',
#    'name:fr': 'Truedan',
#    'opening_hours': 'Mo-Su 11:00-22:00'}},
#  {'type': 'node',
#   'id': 11160869217,
#   'lat': 35.6739558,
#   'lon': 139.760592,
#   'tags': {'amenity': 'cafe',
#    'check_date': '2023-09-01',
#    'level': '0',
#    'name': 'GESHARY COFFEE'}},
#  {'type': 'way',
#   'id': 87456655,
#   'nodes': [1016977169,
#    5434799744,
#    5434799743,
#    5434799742,
#    5434799741,
#    1016977801,
#    5434799740,
#    1016977652,
#    5434799739,
#    5434789811,
#    1016976371,
#    1016975964,
#    1016977527,
#    1016977087,
#    1016976566,
#    1016976136,
#    1016977723,
#    1016976981,
#    1016976462,
#    1016976057,
#    1016977610,
#    1016977169],
#   'tags': {'amenity': 'cafe',
#    'building': 'yes',
#    'building:levels': '1',
#    'cuisine': 'tea',
#    'name': '中島の御茶屋',
#    'name:en': 'Nakajima-no-Ochaya',
#    'opening_hours': 'Mo-Su 09:00-16:45',
#    'source:geometry': 'Bing',
#    'wheelchair': 'no'}},
#  {'type': 'way',
#   'id': 151481856,
#   'nodes': [1642975734,
#    1642975684,
#    1642975682,
#    1642975686,
#    1642975691,
#    1642975697,
#    1642975707,
#    1642975714,
#    1642975725,
#    1642975734],
#   'tags': {'amenity': 'cafe',
#    'building': 'yes',
#    'check_date': '2023-01-20',
#    'cuisine': 'coffee_shop',
#    'internet_access': 'no',
#    'name': '宮越屋珈琲店',
#    'outdoor_seating': 'no',
#    'smoking': 'yes',
#    'source': 'Bing, 2007, Survey',
#    'takeaway': 'yes',
#    'wheelchair': 'no'}}]

# %%
polygon.contain()

# %%
polygon = shape(geojson_data['features'][0]['geometry'])
polygon
# Out:
# <POLYGON ((139.767 35.671, 139.767 35.671, 139.766 35.671, 139.766 35.671, 1...>

# %%
geojson_data['features'][0]['geometry']
# Out:
# {'coordinates': [[[139.766828, 35.670636],
#    [139.766799, 35.670642],
#    [139.765857, 35.670642],
#    [139.765828, 35.67065],
#    [139.765794, 35.670647],
#    [139.765761, 35.670613],
#    [139.765758, 35.670543],
#    [139.765815, 35.669626],
#    [139.765815, 35.669613],
#    [139.765815, 35.6696],
#    [139.76566, 35.668781],
#    [139.765659, 35.668613],
#    [139.765641, 35.668426],
#    [139.765828, 35.668148],
#    [139.766025, 35.66781],
#    [139.766513, 35.667928],
#    [139.766828, 35.667841],
#    [139.767293, 35.668148],
#    [139.767568, 35.668613],
#    [139.767623, 35.668818],
#    [139.767828, 35.668951],
#    [139.768192, 35.669249],
#    [139.76829, 35.669613],
#    [139.768151, 35.669936],
#    [139.767828, 35.670445],
#    [139.767676, 35.670461],
#    [139.767018, 35.670613],
#    [139.766858, 35.670643],
#    [139.766828, 35.670636]]],
#  'type': 'Polygon'}

# %%
coords_1 = [52.2296756, 21.0122287]
coords_2 = str(coords_1[0]) + ':' + str(coords_1[1])
coords_3 = coords_2.split(':')
coords_4 = [float(coords_3[0]), float(coords_3[1])]
coords_4
# Out:
# [52.2296756, 21.0122287]

# %%
import geopy.distance

coords_2 = (52.406374, 16.9251681)

 

def geoDistance(one, two):
    return geopy.distance.geodesic(one, two).km


#for each airbnb -> key by distance to closest shopping place
#all all shopping types to select box -> which lets you pick what you care about
#bookstore, bike store, clothes -> give each a coefficent from -1 to 1 ?

# %%
all_json[0]
# Out:
# {'type': 'Feature',
#  'geometry': {'coordinates': [-4.108979, 41.235559], 'type': 'Point'},
#  'properties': {'name': 'Campo Segoviano 2 S. Coop',
#   'mapbox_id': 'CkIKQDc0ZmVhYWUwYjM2NjI4YmQ3YWE0NjE5MjE5M2ViNDUwNzNjYWI1Y2FhYjFjYjQyZGMzODI4MmE0Y2Q5ZDZhMzQ=',
#   'feature_type': 'poi',
#   'address': 'Carretera Lastras de Cuellar',
#   'full_address': 'Carretera Lastras de Cuellar, 40340 Aguilafuente, Spain',
#   'place_formatted': '40340 Aguilafuente, Spain',
#   'context': {'country': {'name': 'Spain',
#     'country_code': 'ES',
#     'country_code_alpha_3': 'ESP'},
#    'postcode': {'name': '40340'},
#    'place': {'name': 'Aguilafuente'},
#    'address': {'name': 'Carretera Lastras de Cuellar',
#     'address_number': 'Carretera',
#     'street_name': 'Lastras de Cuellar'},
#    'street': {'name': 'carretera lastras de cuellar'}},
#   'coordinates': {'latitude': 41.235559,
#    'longitude': -4.108979,
#    'routable_points': [{'name': 'default',
#      'latitude': 41.23539801385105,
#      'longitude': -4.109065002326695}]},
#   'maki': 'marker',
#   'poi_category': ['garden center', 'shopping'],
#   'poi_category_ids': ['garden_store', 'shopping'],
#   'external_ids': {'foursquare': '5e74b3a77e4be20008969812'},
#   'metadata': {}}}

# %%
import requests
address = '1600 Amphitheatre Parkway, Mountain View, CA'
address = 'SUNDAR NAGAR sneer ae'
# Replace YOUR_ACCESS_TOKEN with your Mapbox access token
#geoCode('HYDE PARK NN 5208')
#avoid this https://www.wsj.com/lifestyle/travel/vacation-hotels-flights-online-booking-fees-29262506
#traveling in a poopy way is an unseen problem

# %%
import glob
import json 
image_urls = glob.glob('./*.json')
import pytesseract
##put city as name of file

def parseUrl(url):
    import re
    url = "https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40"
    match = re.search(r'/rooms/(\d+)', url)
    return match.group(1)

#apt has 6 images -> get coordinates -> search in mb -> get distance from APT to closest one
# def givenListOfImagesInJson(src='0.json'):
#     imgs = json.load(open(src))
#     for _ in image_urls:
#         gm = json.load(open(_))
#         coordinates = [saveImage(_) for _ in gm]
from PIL import Image

# Open an image file
image = Image.open('_.png')

# Display the image
#image.show()

#!pip install easyocr

import easyocr


# fp='gm_395995.json'
# images=json.load(open(fp))
# #imageToCoords(images)

# response = requests.get(images[0])
# response.content
# with open('_.png', 'wb') as f:
#         f.write(response.content)
# pytesseract.image_to_string('_.png', lang='eng')
# Out:
# ''

# %%
#_ =[json.load(open(_)) for _ in glob.glob('./gm*.json')]
import json
import requests
import easyocr
def imageToCoords(url_list, location='jaipur,india'):
    cache = set()

    for _ in url_list[:5]:
        if len(_) < 10: continue
        response = requests.get(_)
        if response.status_code == 200:
            with open(_[-50:-1], 'wb') as f:
                f.write(response.content)

        ocr = ocrImage(_[-50:-1])
        if not ocr: continue
        coords = geoCode(ocr)
        print(coords)
        if not coords: continue
        cache.add(str(coords[0]) + ':' + str(coords[1]))
    return list(cache)

def key_function (_):
    return _[1]

def ocrImage(fp):
    reader = easyocr.Reader(['en'])
    extract_info = reader.readtext(fp)
    #print(extract_info)
    from time import time
    sorted(extract_info, key=key_function)
    #if 0 not in extract_info: return print('wtf', extract_info)
    #print(extract_info)
    if (not extract_info): return False
    return extract_info[0][1]   

def geoCode(address = "1600 Amphitheatre Parkway, Mountain View, CA"):
    accessToken = "pk.eyJ1IjoiYXdhaGFiIiwiYSI6ImNrdjc3NW11aTJncmIzMXExcXRiNDNxZWYifQ.tqFU7uVd6mbhHtjYsjtvlg"  # Replace with your actual access token

    geocodeUrl = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{address}%2C%20singapore.json?access_token={accessToken}"

    response = requests.get(geocodeUrl)
    data = response.json()

    if 'features' in data and len(data['features']) > 0:
        location = data['features'][0]['geometry']['coordinates']
        #print(f"Longitude: {location[0]}, Latitude: {location[1]}")
        return location

geocords = [imageToCoords(_) for _ in _] 
#each _ is an appartment -> 
#have to ocr 6 iamges or find a better ocr function

#ocr('_.png')
_ = json.load(open('gm_54155787.json'))
imageToCoords(_)
# Out:
# [103.9884945, 1.35601825]
# [103.832237, 1.309447]
# [103.869241, 1.412418]
# [103.9884945, 1.35601825]
# ['103.869241:1.412418', '103.832237:1.309447', '103.9884945:1.35601825']

# %%
geoCoordinates = [[75.775256, 26.897392],
[75.818982, 26.915458],
[75.822858, 26.915904],
[75.632758, 26.697753],
[6.9561, 50.944057],
[75.787137, 26.933939],
[75.804092, 26.815534],
[75.822858, 26.915904],
[75.78857, 26.919951],
[75.818982, 26.915458],
[75.775256, 26.897392],
[75.818982, 26.915458],
[75.632758, 26.697753],
[75.822858, 26.915904],
[6.9561, 50.944057],
[75.818982, 26.915458],
[6.9561, 50.944057],
[75.739386, 26.936794],
[75.804092, 26.815534],
[30.203709, 59.987311],
[75.784422, 26.8726],
[75.203905, 26.464273],]


def getPlacesOfInterest(aptGeoLocation):
#     print(aptGeoLocation)
#     aptGeoLocation = aptGeoLocation.split(':')
#     aptGeoLocation =  [float(aptGeoLocation[0]), float(aptGeoLocation[1])]
    all_json = []
    latitude = aptGeoLocation[0]
    longitude = aptGeoLocation[1]
    url = f""" https://api.mapbox.com/search/searchbox/v1/category/shopping?access_token=pk.eyJ1Ijoic2VhcmNoLW1hY2hpbmUtdXNlci0xIiwiYSI6ImNrNnJ6bDdzdzA5cnAza3F4aTVwcWxqdWEifQ.RFF7CVFKrUsZVrJsFzhRvQ&language=en&limit=20&proximity={longitude}%2C%20{latitude}"""
    _ = requests.get(url).json()
    print(_)
    for place in _['features']:
        #print(place)
        all_json.append(place)
    poi = []
    for place in all_json:
        coords = place['geometry']['coordinates']
        categories = place['properties']['poi_category']
        poi.append([coords, categories])
        #print(place)
    sorted(poi, key=lambda _: geoDistance(_[0], aptGeoLocation))
    return geoDistance(poi[0][0], aptGeoLocation)


distance = [getPlacesOfInterest(geoCoordinate) for geoCoordinate in geoCoordinates]

# %%
?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694806265_F%2BQPxtSmCtqU8Ddj&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 116
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 116.json
# https://www.airbnb.com/rooms/53601522?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694806265_F%2BQPxtSmCtqU8Ddj&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 117
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 117.json
# https://www.airbnb.com/rooms/53601522?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694806265_F%2BQPxtSmCtqU8Ddj&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 118
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 118.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 119
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 119.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 120
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 120.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 121
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 121.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 122
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 122.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 123
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 123.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 124
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 124.json
# https://www.airbnb.com/rooms/21363658?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-10-15&check_out=2023-10-20&source_impression_id=p3_1694806265_9ywrM3JxkoiBHIp%2F&previous_page_section_name=1000&federated_search_id=c9de1c68-04a4-4dce-8f81-60648418af40 125
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# saving to 125.json
# CompletedProcess(args=['node', 'airbnb_get_img_url.js', 'jaipur--india_apt.json'], returncode=0)

# %%
import requests
import json

def fetch_cafes(minlat, minlon, maxlat, maxlon):
    overpass_url = "http://overpass-api.de/api/interpreter"
    overpass_query = f"""
    [out:json];
    (
        node["amenity"="cafe"]({minlat},{minlon},{maxlat},{maxlon});
        way["amenity"="cafe"]({minlat},{minlon},{maxlat},{maxlon});
        relation["amenity"="cafe"]({minlat},{minlon},{maxlat},{maxlon});
    );
    out body;
    >;
    out skel qt;
    """
    response = requests.get(overpass_url, params={'data': overpass_query})
    data = response.json()
    return data

# Example usage:
minlat, minlon, maxlat, maxlon = 40.7128, -74.0060, 40.7138, -73.0050  # Example coordinates for New York City
cafes = fetch_cafes(minlat, minlon, maxlat, maxlon)
print(json.dumps(cafes, indent=4))
# Out:
# {
#     "version": 0.6,
#     "generator": "Overpass API 0.7.61.5 4133829e",
#     "osm3s": {
#         "timestamp_osm_base": "2023-09-16T22:25:55Z",
#         "copyright": "The data included in this document is from www.openstreetmap.org. The data is made available under ODbL."
#     },
#     "elements": [
#         {
#             "type": "node",
#             "id": 2422377040,
#             "lat": 40.7131024,
#             "lon": -73.9623534,
#             "tags": {
#                 "addr:city": "Brooklyn",
#                 "addr:housenumber": "328",
#                 "addr:postcode": "11211",
#                 "addr:street": "Bedford Avenue",
#                 "amenity": "cafe",
#                 "check_date": "2023-04-22",
#                 "internet_access": "no",
#                 "name": "Oslo Coffee Roasters",
#                 "website": "https://oslocoffee.com/"
#             }
#         },
#         {
#             "type": "node",
#             "id": 3199078271,
#             "lat": 40.7129493,
#             "lon": -73.9555025,
#             "tags": {
#                 "addr:city": "Brooklyn",
#                 "addr:housenumber": "66",
#                 "addr:postcode": "11211",
#                 "addr:state": "NY",
#                 "addr:street": "Hope Street",
#                 "amenity": "cafe",
#                 "atm": "no",
#                 "cuisine": "coffee_shop",
#                 "internet_access": "wlan",
#                 "name": "66 Hope Cafe",
#                 "opening_hours": "Mo 08:00-18:00;Sa 09:00-18:00;Su 09:00-18:00",
#                 "smoking": "no",
#                 "toilets": "yes",
#                 "toilets:access": "permissive",
#                 "wheelchair": "no"
#             }
#         },
#         {
#             "type": "node",
#             "id": 3805991016,
#             "lat": 40.7137679,
#             "lon": -73.9461019,
#             "tags": {
#                 "addr:city": "Brooklyn",
#                 "addr:housenumber": "289",
#                 "addr:postcode": "11211",
#                 "addr:state": "NY",
#                 "addr:street": "Manhattan Avenue",
#                 "amenity": "cafe",
#                 "cuisine": "pastry",
#                 "internet_access": "no",
#                 "name": "Fortunato Brothers",
#                 "note": "Minimum $10 for credit card use",
#                 "opening_hours": "08:00-23:00",
#                 "phone": "(718) 387-2281",
#                 "website": "fortunatobrothers.com"
#             }
#         },
#         {
#             "type": "node",
#             "id": 4312082389,
#             "lat": 40.7137511,
#             "lon": -73.9985135,
#             "tags": {
#                 "amenity": "cafe",
#                 "cuisine": "ice_cream",
#                 "name": "10 Below Ice Cream"
#             }
#         },
#         {
#             "type": "node",
#             "id": 4312750372,
#             "lat": 40.7136847,
#             "lon": -73.9657829,
#             "tags": {
#                 "addr:city": "Brooklyn",
#                 "addr:housenumber": "45",
#                 "addr:postcode": "11211",
#                 "addr:state": "NY",
#                 "addr:street": "South 3rd Street",
#                 "amenity": "cafe",
#                 "cuisine": "coffee_shop",
#                 "internet_access": "wlan",
#                 "name": "Freehold"
#             }
#         },
#         {
#             "type": "node",
#             "id": 5616253137,
#             "lat": 40.7129063,
#             "lon": -73.9902499,
#             "tags": {
#                 "addr:housenumber": "26",
#                 "addr:street": "Rutgers Street",
#                 "amenity": "cafe",
#                 "name": "Mee Cafe"
#             }
#         },
#         {
#             "type": "node",
#             "id": 6073872634,
#             "lat": 40.7131587,
#             "lon": -73.9087002,
#             "tags": {
#                 "addr:housenumber": "55-03",
#                 "addr:street": "Metropolitan Avenue",
#                 "amenity": "cafe",
#                 "drink:coffee": "yes",
#                 "name": "Sebastian's Cafe"
#             }
#         },
#         {
#             "type": "node",
#             "id": 6260059211,
#             "lat": 40.7136566,
#             "lon": -73.9974429,
#             "tags": {
#                 "addr:housenumber": "2",
#                 "addr:postcode": "10038",
#                 "addr:street": "East Broadway",
#                 "amenity": "cafe",
#                 "branch": "Chatham Square",
#                 "name": "ViVi Bubble Tea",
#                 "opening_hours": "Mo-Th, Su 10:00-21:00; Fr, Sa 10:00-21:30",
#                 "payment:credit_cards": "no",
#                 "phone": "+1 212-966-5793",
#                 "website": "http://www.vivibubbletea.com/location_content.php?l=4"
#             }
#         },
#         {
#             "type": "node",
#             "id": 8109403685,
#             "lat": 40.7137246,
#             "lon": -73.9494826,
#             "tags": {
#                 "addr:city": "Brooklyn",
#                 "addr:housenumber": "561",
#                 "addr:postcode": "11211",
#                 "addr:state": "NY",
#                 "addr:street": "Lorimer Street",
#                 "amenity": "cafe",
#                 "cuisine": "coffee;pastry",
#                 "name": "Poetica Coffee"
#             }
#         },
#         {
#             "type": "node",
#             "id": 8109403686,
#             "lat": 40.7135773,
#             "lon": -73.949434,
#             "tags": {
#                 "addr:city": "Brooklyn",
#                 "addr:housenumber": "557",
#                 "addr:postcode": "11211",
#                 "addr:state": "NY",
#                 "addr:street": "Lorimer Street",
#                 "amenity": "cafe",
#                 "cuisine": "yerba_mate;coffee;pastry",
#                 "diet:dairy_free": "yes",
#                 "diet:gluten_free": "yes",
#                 "diet:vegan": "yes",
#                 "diet:vegetarian": "yes",
#                 "name": "Porte\u00f1as",
#                 "website": "https://portenas.nyc"
#             }
#         },
#         {
#             "type": "node",
#             "id": 9348996443,
#             "lat": 40.7131507,
#             "lon": -73.8731553,
#             "tags": {
#                 "amenity": "cafe",
#                 "name": "Caffe Latte"
#             }
#         },
#         {
#             "type": "way",
#             "id": 331910343,
#             "nodes": [
#                 3390089542,
#                 3390089553,
#                 3390089546,
#                 3390089545,
#                 3390089543,
#                 3390089549,
#                 3390089552,
#                 3390089547,
#                 3390089544,
#                 3390089551,
#                 3390089548,
#                 3390089550,
#                 3390089542
#             ],
#             "tags": {
#                 "amenity": "cafe",
#                 "building": "yes"
#             }
#         },
#         {
#             "type": "node",
#             "id": 3390089542,
#             "lat": 40.71296,
#             "lon": -73.6000468
#         },
#         {
#             "type": "node",
#             "id": 3390089543,
#             "lat": 40.7128295,
#             "lon": -73.6000775
#         },
#         {
#             "type": "node",
#             "id": 3390089544,
#             "lat": 40.7129112,
#             "lon": -73.6001495
#         },
#         {
#             "type": "node",
#             "id": 3390089545,
#             "lat": 40.7128402,
#             "lon": -73.6000415
#         },
#         {
#             "type": "node",
#             "id": 3390089546,
#             "lat": 40.7129202,
#             "lon": -73.5999952
#         },
#         {
#             "type": "node",
#             "id": 3390089547,
#             "lat": 40.7129004,
#             "lon": -73.6001173
#         },
#         {
#             "type": "node",
#             "id": 3390089548,
#             "lat": 40.7129218,
#             "lon": -73.6001025
#         },
#         {
#             "type": "node",
#             "id": 3390089549,
#             "lat": 40.7128436,
#             "lon": -73.600119
#         },
#         {
#             "type": "node",
#             "id": 3390089550,
#             "lat": 40.7129515,
#             "lon": -73.6000852
#         },
#         {
#             "type": "node",
#             "id": 3390089551,
#             "lat": 40.7129333,
#             "lon": -73.6001366
#         },
#         {
#             "type": "node",
#             "id": 3390089552,
#             "lat": 40.7128723,
#             "lon": -73.6001338
#         },
#         {
#             "type": "node",
#             "id": 3390089553,
#             "lat": 40.7129478,
#             "lon": -73.6000106
#         }
#     ]
# }

# %%
getCityList().keys()
# Out:
# dict_keys(['Europe', 'North America', 'Asia', 'South America', 'Africa', 'Australia and Oceania', 'Others/Islands', 'Lesser-known Gems', 'For Nature Lovers'])

# %%
#2 cities
#moscow 

def getCityList():
    return {
  "Europe": [
    "Paris, France",
    "Rome, Italy",
    "Barcelona, Spain",
    "Amsterdam, Netherlands",
    "London, United Kingdom",
    "Prague, Czech Republic",
    "Vienna, Austria",
    "Budapest, Hungary",
    "Berlin, Germany",
    "Athens, Greece",
    "Venice, Italy",
    "Lisbon, Portugal",
    "Copenhagen, Denmark",
    "Stockholm, Sweden",
    "Edinburgh, Scotland",
    "Dublin, Ireland",
    "Reykjavik, Iceland",
    "Madrid, Spain",
    "Oslo, Norway",
    "Zurich, Switzerland"
  ],
  "North America": [
    "New York City, USA",
    "San Francisco, USA",
    "Vancouver, Canada",
    "New Orleans, USA",
    "Los Angeles, USA",
    "Chicago, USA",
    "Toronto, Canada",
    "Mexico City, Mexico",
    "Montreal, Canada",
    "Boston, USA",
    "Miami, USA",
    "Austin, USA",
    "Quebec City, Canada",
    "Seattle, USA",
    "Nashville, USA"
  ],
  "Asia": [
    "Tokyo, Japan",
    "Kyoto, Japan",
    "Bangkok, Thailand",
    "Hong Kong, China",
    "Singapore, Singapore",
    "Seoul, South Korea",
    "Beijing, China",
    "Dubai, UAE",
    "Taipei, Taiwan",
    "Istanbul, Turkey",
    "Hanoi, Vietnam",
    "Jerusalem, Israel",
    "Mumbai, India",
    "Kuala Lumpur, Malaysia",
    "Jaipur, India"
  ],
  "South America": [
    "Rio de Janeiro, Brazil",
    "Buenos Aires, Argentina",
    "Cartagena, Colombia",
    "Lima, Peru",
    "Santiago, Chile",
    "Cusco, Peru",
    "Medellín, Colombia",
    "Quito, Ecuador",
    "Montevideo, Uruguay",
    "Bogota, Colombia"
  ],
  "Africa": [
    "Cape Town, South Africa",
    "Marrakech, Morocco",
    "Cairo, Egypt",
    "Dakar, Senegal",
    "Zanzibar City, Tanzania",
    "Accra, Ghana",
    "Addis Ababa, Ethiopia",
    "Victoria Falls, Zimbabwe/Zambia",
    "Nairobi, Kenya",
    "Tunis, Tunisia"
  ],
  "Australia and Oceania": [
    "Sydney, Australia",
    "Melbourne, Australia",
    "Auckland, New Zealand",
    "Wellington, New Zealand",
    "Brisbane, Australia"
  ],
  "Others/Islands": [
    "Honolulu, Hawaii, USA",
    "Bali, Indonesia",
    "Santorini, Greece",
    "Maldives (Male)",
    "Phuket, Thailand",
    "Ibiza, Spain",
    "Seychelles (Victoria)",
    "Havana, Cuba",
    "Punta Cana, Dominican Republic",
    "Dubrovnik, Croatia"
  ],
  "Lesser-known Gems": [
    "Ljubljana, Slovenia",
    "Tallinn, Estonia",
    "Riga, Latvia",
    "Sarajevo, Bosnia and Herzegovina",
    "Vilnius, Lithuania",
    "Tbilisi, Georgia",
    "Yerevan, Armenia",
    "Baku, Azerbaijan",
    "Belgrade, Serbia",
    "Skopje, North Macedonia"
  ],
  "For Nature Lovers": [
    "Banff, Canada",
    "Queenstown, New Zealand",
    "Reykjavik (as a gateway to Icelandic nature)",
    "Ushuaia, Argentina (Gateway to Antarctica)",
    "Kathmandu, Nepal (Gateway to the Himalayas)"
  ]
}


locations = getCityList()

    
    


import json
import asyncio
from pyppeteer import launch


async def delay(seconds):
    await asyncio.sleep(seconds)

links = []
headless = True

async def get_img_url(apt_listing, idx):
    print(apt_listing, idx)
    browser = await launch(headless=headless)
    page = await browser.newPage()
    await page.setViewport({'width': 1920, 'height': 1080})
    await page.goto(apt_listing)

    await page.waitForSelector('section')

    await page.evaluate('''() => {
        window.scrollBy(0, 100000);
    }''')

    await delay(3)

    await page.evaluate('''() => {
        //window.scrollBy(0, 100000);
        //document.querySelectorAll('.hnwb2pb.dir.dir-ltr')[3]?.scrollIntoView()
        //document?.querySelector('.cj0q2ib.sne7mb7.rp6dtyx.c1y4i074.dir.dir-ltr').click()
    }''')

    await delay(1)

    selector = '.gm-style img'
    img_urls = await page.querySelectorAllEval(selector, 'img => img.map(i => i.src).filter(src => src.indexOf("maps.googleapis.com") !== -1)')

    print('saving to ' + f'{idx}.json')
    with open(f'{idx}.json', 'w') as f:
        json.dump(img_urls, f)

    #print(img_urls)
    #await browser.close()
    return img_urls

async def get_apt(url, location):
    browser = await launch(headless=headless)
    page = await browser.newPage()

    await page.goto(url)
    qs = '.cy5jw6o.dir.dir-ltr a'

    try:
        await page.waitForSelector(qs)
    except:
      return []

    # Placeholder for your logic to extract tweets, adapt as needed
    tweets = await page.querySelectorAllEval(qs, '''tweets => {
        return tweets.map(tweet => ({
            link: tweet.href
        }));
    }''')

    #print(tweets)
    #link += tweets

    await browser.close()
    with open(f'{location}_apt.json', 'w') as f:
        json.dump(tweets, f)
    return tweets

#if __name__ == "__main__":
#fn = input("Enter function to execute (get_apt/get_img_url): ")
#if fn == 'get_apt':
#    asyncio.get_event_loop().run_until_complete(get_apt())
#elif fn == 'get_img_url':
    #apt_listing = input("Enter the apartment listing URL: ")
apt_listing = 'https://www.airbnb.com/rooms/586166376600248074?adults=1&category_tag=Tag%3A8522&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1457367815&search_mode=flex_destinations_search&check_in=2023-09-14&check_out=2023-09-19&source_impression_id=p3_1694719767_8kxnr2mVDAfpYdMo&previous_page_section_name=1000&federated_search_id=62cba934-7640-4911-b5c5-cb37f6420f19'
#asyncio.get_event_loop().run_until_complete(get_img_url(apt_listing))

#for city in list of cities
#search airbnb
#cache listing_url in json
#for listing_url -> get geo-coordinate

#check availability weekly -> 7 million = 
#86,400 seconds => 1 computer 

import asyncio
#loop = asyncio.get_event_loop()
#loop.create_task(get_img_url(apt_listing))
def getAllApt_(location):
    return ['hello world']

#make server async -> 10 ?? 
#use nodejs subprocess -> 2 min 
async def getAllAptForLocation(location):
    location = location.replace(',','--')
    url = f'https://www.airbnb.com/s/{location}/homes' 
    task = asyncio.create_task(get_apt(url, location)) #get 18 apt urls 
    return await task

async def main(location):
    # run my_coroutine as a task
    task = getAllAptForLocation(location)

    url = await task
    #return print('task done', len(url))
    for idx, url in enumerate(url):
        task = asyncio.create_task(get_img_url(url['link'], location))
        #task = asyncio.create_task(get_img_url(apt_listing))
        await task

# run main() in the current event loop
# for location in locations['Asia']:
#     print('lets go to ' + location)
#     await main(location)

# %%
#get every property on airbnb
#get every house in the world
#get every appartment in the world
#re-index every 24 hours

#make it simple to "suitability-analysis" each one with 10-20 columns or whatever is available in that city
#make an "admin UI" that is viewable by all so everyone can see all the different data for geospatial 




#also do timeseries
#also do tabular data

#geospatial ETA - 1 week
url
# Out:
# ['https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11707!3i6832!4i256!2m3!1e0!2sm!3i662403161!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=31812',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11708!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=130417',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11708!3i6833!4i256!2m3!1e0!2sm!3i662403161!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=20371',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11708!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=46912',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11705!3i6833!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=105547',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11706!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=105733',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11705!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=22042',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11706!3i6833!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=10601',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11707!3i6833!4i256!2m3!1e0!2sm!3i662403161!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=115317',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11707!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=10787',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11709!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=35471',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11706!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=58167',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11709!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=83037',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11709!3i6833!4i256!2m3!1e0!2sm!3i662403161!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=56496',
#  'https://maps.googleapis.com/maps/vt?pb=!1m5!1m4!1i14!2i11705!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m17!2sen!3sUS!5e18!12m4!1e68!2m2!1sset!2sRoadmap!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!...!4e0!23i1379903!23i1376099&key=AIzaSyCrpUPhpbPzRI4hYC7xE02WKsrxQv0HClI&token=69608']

# %%
#Image(url=i).
import requests



#pytesseract.image_to_string()
#Image(filename='./local_image.jpg')

# %%
import os

#import os
os.listdir()

#print('local_image.jpg' in os.listdir())

#'local_image.jpg' in os.listdir()
# Out:
# ['downloaded_file_7.pdf',
#  'downloaded_file_14.pdf',
#  'client.js',
#  'downloaded_file_15.pdf',
#  'downloaded_file_6.pdf',
#  '20.json',
#  '16.json',
#  'downloaded_file_4.pdf',
#  'downloaded_file_17.pdf',
#  'downloaded_file_16.pdf',
#  'downloaded_file_5.pdf',
#  '14!2i11705!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m',
#  '6.json',
#  '7.json',
#  'index.html',
#  '.DS_Store',
#  'downloaded_file_12.pdf',
#  'downloaded_file_1.pdf',
#  '14!2i11709!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m',
#  '14!2i11707!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m',
#  'downloaded_file_0.pdf',
#  'downloaded_file_13.pdf',
#  '17.json',
#  '14!2i11709!3i6833!4i256!2m3!1e0!2sm!3i662403161!3m',
#  '14!2i11707!3i6833!4i256!2m3!1e0!2sm!3i662403161!3m',
#  'airbnb_map.json',
#  '14!2i11708!3i6833!4i256!2m3!1e0!2sm!3i662403161!3m',
#  'downloaded_file_11.pdf',
#  '21.json',
#  'downloaded_file_2.pdf',
#  '#client.js#',
#  '14!2i11708!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m',
#  'downloaded_file_3.pdf',
#  'downloaded_file_10.pdf',
#  '14!2i11706!3i6831!4i256!2m3!1e0!2sm!3i662403173!3m',
#  'Untitled.ipynb',
#  '10.json',
#  '14!2i11709!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m',
#  'shit.txt',
#  '0.json',
#  'California_Houses (2).csv',
#  '26.json',
#  'node_modules',
#  '14!2i11706!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m',
#  '14!2i11708!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m',
#  'Pokemon_Dota_Arxiv.ipynb',
#  '30.json',
#  '31.json',
#  'local_image.jpg',
#  'vite-project',
#  '27.json',
#  'geospatial.ipynb',
#  '1.json',
#  '__pycache__',
#  'somefile.pdf',
#  '11.json',
#  '14!2i11705!3i6832!4i256!2m3!1e0!2sm!3i662403173!3m',
#  '2.json',
#  'puppet-twitter',
#  '28.json',
#  'netlify',
#  'yoursite.png',
#  '12.json',
#  '32.json',
#  'yarn.lock',
#  '24.json',
#  '374563271_777451084391208_1943605163788673804_n.jpeg',
#  '.gitignore',
#  'package-lock.json',
#  '14!2i11707!3i6832!4i256!2m3!1e0!2sm!3i662403161!3m',
#  'package.json',
#  '25.json',
#  '33.json',
#  '13.json',
#  'client.css',
#  '29.json',
#  '3.json',
#  '34.json',
#  '.ipynb_checkpoints',
#  '8.json',
#  '22.json',
#  'downloaded_file_21.pdf',
#  'downloaded_file_20.pdf',
#  '18.json',
#  '14!2i11705!3i6833!4i256!2m3!1e0!2sm!3i662403173!3m',
#  '4.json',
#  '.git',
#  'main.py',
#  'downloaded_file_22.pdf',
#  'downloaded_file_23.pdf',
#  'RPC',
#  '14.json',
#  'data',
#  'poll.json',
#  '15.json',
#  'downloaded_file_8.pdf',
#  'downloaded_file_9.pdf',
#  'jupyter',
#  '5.json',
#  '14!2i11706!3i6833!4i256!2m3!1e0!2sm!3i662403173!3m',
#  '19.json',
#  'downloaded_file_24.pdf',
#  'downloaded_file_18.pdf',
#  '23.json',
#  'downloaded_file_19.pdf',
#  'all_pg.txt',
#  '9.json']

# %%
#! pip install pytesseract
import pytesseract
#pytesseract.image_to_string(, lang='eng')
print(pytesseract.image_to_string(Image.open('_.png'), lang='eng'))

# %%
Image.open('_.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256>

# %%
import json
import requests
import pytesseract
url = json.load(open('./airbnb_map.json'))



for i in url:
    #from IPython.display import display, Image
    saveImage(i)
    # Display an image from a URL
    #display(Image(url=i))
# Out:
# (hosp? seep 3

# %%
#! pip install pyppeteer
#https://github.com/pyppeteer/pyppeteer
import subprocess

location = 'jaipur--india'
args = [
    "node",
    "getAptInCity.js",
    location
]

# Execute the command
# try:
#result = subprocess.run(command, check=True)
# except subprocess.CalledProcessError as e:
#     print(f"The command failed with error: {e}")
completed_process = subprocess.run(args
                                   #, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True
                                   )
# Out:
#   Puppeteer old Headless deprecation warning:
#     In the near future `headless: true` will default to the new Headless mode
#     for Chrome instead of the old Headless implementation. For more
#     information, please see https://developer.chrome.com/articles/new-headless/.
#     Consider opting in early by passing `headless: "new"` to `puppeteer.launch()`
#     If you encounter any bugs, please report them to https://github.com/puppeteer/puppeteer/issues/new/choose.
# writing jaipur--india_apt.json

# %%
args = [
    "node",
    "RPC/fetchAirbnb.js",
    "get_img_url",
    "https://www.airbnb.com/rooms/46167540?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694700080_UjFiBEV3n8iEBFMu&previous_page_section_name=1000&federated_search_id=c852781b-8f44-4187-a236-0aeb4c288fa8"
]

# Execute the command
# try:
#result = subprocess.run(command, check=True)
# except subprocess.CalledProcessError as e:
#     print(f"The command failed with error: {e}")
completed_process = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True)
stdout = completed_process.stdout.decode()
stderr = completed_process.stderr.decode()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[31], line 15
#       3 args = [
#       4     "node",
#       5     "RPC/fetchAirbnb.js",
#       6     "get_img_url",
#       7     "https://www.airbnb.com/rooms/46167540?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694700080_UjFiBEV3n8iEBFMu&previous_page_section_name=1000&federated_search_id=c852781b-8f44-4187-a236-0aeb4c288fa8"
#       8 ]
#      10 # Execute the command
#      11 # try:
#      12 #result = subprocess.run(command, check=True)
#      13 # except subprocess.CalledProcessError as e:
#      14 #     print(f"The command failed with error: {e}")
# ---> 15 completed_process = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True)
#      16 stdout = completed_process.stdout.decode()
#      17 stderr = completed_process.stderr.decode()
#
# File ~/opt/anaconda3/lib/python3.9/subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526     retcode = process.poll()
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['node', 'RPC/fetchAirbnb.js', 'get_img_url', 'https://www.airbnb.com/rooms/46167540?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694700080_UjFiBEV3n8iEBFMu&previous_page_section_name=1000&federated_search_id=c852781b-8f44-4187-a236-0aeb4c288fa8']' returned non-zero exit status 1.

# %%
args = [
    "node",
    "RPC/fetchAirbnb.js",
    "get_img_url",
    "https://www.airbnb.com/rooms/46167540?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694700080_UjFiBEV3n8iEBFMu&previous_page_section_name=1000&federated_search_id=c852781b-8f44-4187-a236-0aeb4c288fa8"
]

output = subprocess.check_output(args)

result = output
result
# Out:
# b''

# %%
import subprocess


url = "node RPC/fetchAirbnb.js  get_img_url 'https://www.airbnb.com/rooms/46167540?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2023-09-17&check_out=2023-09-22&source_impression_id=p3_1694700080_UjFiBEV3n8iEBFMu&previous_page_section_name=1000&federated_search_id=c852781b-8f44-4187-a236-0aeb4c288fa8'"
subprocess.call(url.split(' '))
# Out:
# 0

# %%
from PIL import Image

import pytesseract

# If you don't have tesseract executable in your PATH, include the following:
pytesseract.pytesseract.tesseract_cmd = r'<full_path_to_your_tesseract_executable>'
# Example tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'

# Simple image to string
print(pytesseract.image_to_string(Image.open('test.png')))

# In order to bypass the image conversions of pytesseract, just use relative or absolute image path
# NOTE: In this case you should provide tesseract supported images or tesseract will return error
print(pytesseract.image_to_string('test.png'))

# List of available languages
print(pytesseract.get_languages(config=''))

# French text image to string
print(pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra'))
# Batch processing with a single file containing the list of multiple image file paths
print(pytesseract.image_to_string('images.txt'))

# Timeout/terminate the tesseract job after a period of time
try:
    print(pytesseract.image_to_string('test.jpg', timeout=2)) # Timeout after 2 seconds
    print(pytesseract.image_to_string('test.jpg', timeout=0.5)) # Timeout after half a second
except RuntimeError as timeout_error:
    # Tesseract processing is terminated
    pass

# Get bounding box estimates
print(pytesseract.image_to_boxes(Image.open('test.png')))

# Get verbose data including boxes, confidences, line and page numbers
print(pytesseract.image_to_data(Image.open('test.png')))

# Get information about orientation and script detection
print(pytesseract.image_to_osd(Image.open('test.png')))

# Get HOCR output
hocr = pytesseract.image_to_pdf_or_hocr('test.png', extension='hocr')

# Get ALTO XML output
xml = pytesseract.image_to_alto_xml('test.png')
#Support for OpenCV image/NumPy array objects

# import cv2

# img_cv = cv2.imread(r'/<path_to_image>/digits.png')

# # By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
# # we need to convert from BGR to RGB format/mode:
# img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
# print(pytesseract.image_to_string(img_rgb))
# # OR
# img_rgb = Image.frombytes('RGB', img_cv.shape[:2], img_cv, 'raw', 'BGR', 0, 0)
# print(pytesseract.image_to_string(img_rgb))

# %%
trees_map()
# Out:
# [['latitude', 'longitude'],
#  ['40.72309177', '-73.84421522'],
#  ['40.79411067', '-73.81867946'],
#  ['40.71758074', '-73.9366077'],
#  ['40.71353749', '-73.93445616'],
#  ['40.66677776', '-73.97597938'],
#  ['40.77004563', '-73.98494997'],
#  ['40.77020969', '-73.98533807'],
#  ['40.76272385', '-73.98729652'],
#  ['40.59657931', '-74.07625483'],
#  ['40.58635725', '-73.96974394'],
#  ['40.78242823', '-73.91117077'],
#  ['40.78173511', '-73.91201957'],
#  ['40.55710259', '-74.16267038'],
#  ['40.69473314', '-73.96821054'],
#  ['40.6643174', '-73.92113023'],
#  ['40.69331418', '-73.96760066'],
#  ['40.59378755', '-73.9915968'],
#  ['40.64878769', '-73.96452447'],
#  ['40.73764622', '-73.86529992'],
#  ['40.69149917', '-73.97258754'],
#  ['40.66123875', '-73.98588944'],
#  ['40.77217148', '-73.96045571'],
#  ['40.7820872', '-73.98096428'],
#  ['40.56882124', '-74.1385634'],
#  ['40.67483919', '-73.97218377'],
#  ['40.59493629', '-73.98917143'],
#  ['40.70653352', '-73.82499155'],
#  ['40.61190461', '-73.97042748'],
#  ['40.72180744', '-73.98982976'],
#  ['40.70804012', '-73.91549691'],
#  ['40.66882647', '-73.98670282'],
#  ['40.84794708', '-73.89338226'],
#  ['40.77039613', '-73.9816267'],
#  ['40.77022715', '-73.98121826'],
#  ['40.5881073', '-74.08667827'],
#  ['40.77008698', '-73.98504779'],
#  ['40.77018061', '-73.98526929'],
#  ['40.77499266', '-73.92203675'],
#  ['40.56882517', '-74.13906215'],
#  ['40.85091786', '-73.90356058'],
#  ['40.57807406', '-74.11474624'],
#  ['40.78258674', '-73.97484011'],
#  ['40.5752053', '-73.9524669'],
#  ['40.7337165', '-73.97705764'],
#  ['40.61366258', '-73.97453014'],
#  ['40.70404652', '-73.82768034'],
#  ['40.72663958', '-73.99936836'],
#  ['40.78233983', '-73.91127902'],
#  ['40.69528068', '-73.96637972'],
#  ['40.7821811', '-73.97238977'],
#  ['40.59393169', '-73.9938007'],
#  ['40.58584952', '-74.14804001'],
#  ['40.61293798', '-73.97671635'],
#  ['40.71490997', '-73.82720922'],
#  ['40.61003477', '-73.94863403'],
#  ['40.60991608', '-73.94861133'],
#  ['40.74068684', '-73.80826026'],
#  ['40.87192665', '-73.88234856'],
#  ['40.53211313', '-74.1561806'],
#  ['40.85677447', '-73.89097861'],
#  ['40.78993607', '-73.97721169'],
#  ['40.56103243', '-74.10653494'],
#  ['40.53936939', '-74.19255287'],
#  ['40.59683648', '-73.77245394'],
#  ['40.85791814', '-73.89340631'],
#  ['40.739991', '-73.86526993'],
#  ['40.66362636', '-73.75365462'],
#  ['40.72186915', '-73.86525671'],
#  ['40.703218', '-73.73473543'],
#  ['40.67591256', '-73.96350468'],
#  ['40.715253', '-73.85049293'],
#  ['40.56744833', '-74.13410014'],
#  ['40.77079674', '-73.89080443'],
#  ['40.75195241', '-73.82895529'],
#  ['40.71219318', '-73.82549632'],
#  ['40.78080395', '-73.97613836'],
#  ['40.71175384', '-73.82794408'],
#  ['40.80907709', '-73.96312072'],
#  ['40.5602591', '-74.16264761'],
#  ['40.61799206', '-73.99518627'],
#  ['40.68162051', '-74.00147075'],
#  ['40.65015942', '-73.95571955'],
#  ['40.67524604', '-73.97323052'],
#  ['40.90339978', '-73.84936673'],
#  ['40.764166', '-73.87162804'],
#  ['40.61891585', '-73.99026972'],
#  ['40.77688357', '-73.97980287'],
#  ['40.77277225', '-73.9553271'],
#  ['40.76996266', '-73.98475372'],
#  ['40.76206839', '-73.92575935'],
#  ['40.73943979', '-73.98436755'],
#  ['40.69062557', '-73.86702522'],
#  ['40.58401171', '-73.81814429'],
#  ['40.66831143', '-73.98089638'],
#  ['40.67498646', '-73.9720122'],
#  ['40.73570804', '-73.98261517'],
#  ['40.71266167', '-73.83049495'],
#  ['40.85392218', '-73.9013742'],
#  ['40.64072805', '-73.97579406'],
#  ['40.67179945', '-73.97521359'],
#  ['40.73275126', '-73.78793925'],
#  ['40.75395021', '-73.83485946'],
#  ['40.77033272', '-73.98369364'],
#  ['40.68584614', '-73.99547033'],
#  ['40.68581011', '-73.99536155'],
#  ['40.76955939', '-73.95993924'],
#  ['40.72173136', '-73.98958224'],
#  ['40.78010688', '-73.98322688'],
#  ['40.7681009', '-73.89434096'],
#  ['40.76280482', '-73.78633372'],
#  ['40.60430523', '-73.93644715'],
#  ['40.66826409', '-73.98079837'],
#  ['40.67201868', '-73.97503084'],
#  ['40.71171868', '-73.85446422'],
#  ['40.76332189', '-73.96121439'],
#  ['40.78061205', '-73.98564087'],
#  ['40.57619607', '-73.85018599'],
#  ['40.74996589', '-73.88713449'],
#  ['40.72549844', '-73.94980363'],
#  ['40.70574154', '-73.91784901'],
#  ['40.68844787', '-73.86658672'],
#  ['40.68591967', '-73.97626031'],
#  ['40.72856769', '-73.95177312'],
#  ['40.59666002', '-74.16220431'],
#  ['40.76980427', '-73.82714606'],
#  ['40.7631618', '-73.92810436'],
#  ['40.77000454', '-73.98485279'],
#  ['40.57887248', '-73.94378432'],
#  ['40.77038983', '-73.98213047'],
#  ['40.59784149', '-74.16242863'],
#  ['40.72262725', '-73.94879371'],
#  ['40.67099868', '-73.97620526'],
#  ['40.55906117', '-74.10603753'],
#  ['40.86998754', '-73.90162551'],
#  ['40.63056031', '-73.9241548'],
#  ['40.76436461', '-73.95955458'],
#  ['40.74780138', '-73.97857966'],
#  ['40.6244214', '-73.96036845'],
#  ['40.85705393', '-73.88745706'],
#  ['40.60961592', '-73.96487682'],
#  ['40.76996828', '-73.98212294'],
#  ['40.59837239', '-74.16253586'],
#  ['40.69543462', '-73.96835285'],
#  ['40.69528272', '-73.96832203'],
#  ['40.67530269', '-73.9733763'],
#  ['40.76307992', '-73.96064456'],
#  ['40.76963905', '-73.96012717'],
#  ['40.68606021', '-73.97628864'],
#  ['40.78017187', '-73.9833793'],
#  ['40.72311463', '-73.9903307'],
#  ['40.76299829', '-73.96045231'],
#  ['40.76313613', '-73.96077693'],
#  ['40.67490334', '-73.97505728'],
#  ['40.76960162', '-73.96003888'],
#  ['40.75757044', '-73.98285452'],
#  ['40.72206573', '-73.99110017'],
#  ['40.76964206', '-73.98370686'],
#  ['40.55918278', '-74.10593025'],
#  ['40.58211738', '-73.82864619'],
#  ['40.77046435', '-73.98179161'],
#  ['40.58306474', '-73.82538142'],
#  ['40.69153074', '-73.96062867'],
#  ['40.77248279', '-73.90907286'],
#  ['40.74486653', '-73.98598251'],
#  ['40.76916627', '-73.95901189'],
#  ['40.76432442', '-73.95945923'],
#  ['40.72286388', '-73.94759301'],
#  ['40.66972377', '-73.97268165'],
#  ['40.75235028', '-73.97971637'],
#  ['40.60963578', '-73.94855771'],
#  ['40.73815531', '-73.98054734'],
#  ['40.77005069', '-73.98079175'],
#  ['40.67672539', '-73.97265212'],
#  ['40.64872085', '-73.96469573'],
#  ['40.71308988', '-73.93895706'],
#  ['40.77055862', '-73.9861635'],
#  ['40.66116853', '-73.98577305'],
#  ['40.70233782', '-73.91521777'],
#  ['40.71269558', '-73.99769319'],
#  ['40.76961476', '-73.98364215'],
#  ['40.62037645', '-73.95847826'],
#  ['40.6635718', '-73.99457015'],
#  ['40.58221487', '-73.82831042'],
#  ['40.60955151', '-73.94574108'],
#  ['40.67586569', '-73.97279'],
#  ['40.70099719', '-73.89270307'],
#  ['40.69124695', '-73.96056701'],
#  ['40.79880049', '-73.96897589'],
#  ['40.70871281', '-73.91480707'],
#  ['40.72627143', '-73.94728673'],
#  ['40.71007644', '-74.01226648'],
#  ['40.69577266', '-73.97068954'],
#  ['40.67249783', '-73.97235367'],
#  ['40.67688868', '-73.97371851'],
#  ['40.80278452', '-73.95251716'],
#  ['40.60949889', '-73.94853152'],
#  ['40.73824263', '-73.98048352'],
#  ['40.67561105', '-73.97213743'],
#  ['40.67551014', '-73.97187885'],
#  ['40.58344881', '-73.82405773'],
#  ['40.58350299', '-73.82387099'],
#  ['40.71763375', '-73.93663139'],
#  ['40.75182477', '-73.88841976'],
#  ['40.72566319', '-73.94694312'],
#  ['40.85153001', '-73.89377521'],
#  ['40.85811921', '-73.9021878'],
#  ['40.74222798', '-73.92783662'],
#  ['40.63461036', '-73.99982555'],
#  ['40.77199195', '-73.95165745'],
#  ['40.61095304', '-73.7701119'],
#  ['40.55832021', '-74.16176844'],
#  ['40.84983561', '-73.90281035'],
#  ['40.69414597', '-73.75058098'],
#  ['40.78343726', '-73.91459447'],
#  ['40.78183619', '-73.91206578'],
#  ['40.58453676', '-73.93097316'],
#  ['40.61544133', '-74.16442172'],
#  ['40.80690345', '-73.95739877'],
#  ['40.76932328', '-73.8906477'],
#  ['40.85070575', '-73.88695045'],
#  ['40.70556938', '-73.82133897'],
#  ['40.57461702', '-74.12680328'],
#  ['40.73357762', '-73.97672526'],
#  ['40.67441563', '-73.95314143'],
#  ['40.73346807', '-73.97646308'],
#  ['40.85805147', '-73.88533325'],
#  ['40.72666328', '-73.99941653'],
#  ['40.78227353', '-73.91136021'],
#  ['40.69452585', '-73.96619451'],
#  ['40.65353429', '-73.84344477'],
#  ['40.84571911', '-73.91819074'],
#  ['40.69468728', '-73.97022537'],
#  ['40.7816867', '-73.97549554'],
#  ['40.67763435', '-73.89058092'],
#  ['40.73974645', '-73.9850924'],
#  ['40.68280728', '-73.90979496'],
#  ['40.68111502', '-73.9114682'],
#  ['40.63440847', '-73.92809354'],
#  ['40.72403951', '-73.83980528'],
#  ['40.65189344', '-73.96023354'],
#  ['40.85663542', '-73.89013512'],
#  ['40.57237894', '-74.08885094'],
#  ['40.70378287', '-73.94425849'],
#  ['40.70744575', '-73.95201546'],
#  ['40.85912362', '-73.89424406'],
#  ['40.65364723', '-73.95912524'],
#  ['40.71011368', '-74.01235235'],
#  ['40.8494875', '-73.89261605'],
#  ['40.74791179', '-73.98052056'],
#  ['40.59061304', '-73.79683634'],
#  ['40.590643', '-73.79673994'],
#  ['40.72606121', '-73.94815262'],
#  ['40.67607533', '-73.95725929'],
#  ['40.67640772', '-73.95581738'],
#  ['40.71751014', '-73.99597274'],
#  ['40.72224466', '-73.86131975'],
#  ['40.70687246', '-73.90344945'],
#  ['40.74040845', '-73.92842895'],
#  ['40.59570647', '-73.74664284'],
#  ['40.76395531', '-73.96078214'],
#  ['40.76382569', '-73.96047463'],
#  ['40.7206881', '-73.98224174'],
#  ['40.857482', '-73.89295364'],
#  ['40.74912139', '-73.88962284'],
#  ['40.55017691', '-74.18409536'],
#  ['40.61227657', '-73.97144407'],
#  ['40.58868167', '-74.18913181'],
#  ['40.58804692', '-74.18811275'],
#  ['40.77817309', '-73.90396581'],
#  ['40.58451588', '-74.08802746'],
#  ['40.74831191', '-73.82669147'],
#  ['40.80754134', '-73.95861206'],
#  ['40.84272939', '-73.89970654'],
#  ['40.74797175', '-74.00705779'],
#  ['40.67232211', '-73.98687389'],
#  ['40.67236842', '-73.98683519'],
#  ['40.62335909', '-73.95630455'],
#  ['40.80797914', '-73.95964901'],
#  ['40.65173426', '-73.9602033'],
#  ['40.57030076', '-73.86052984'],
#  ['40.57035358', '-73.86056009'],
#  ['40.63745394', '-73.95382789'],
#  ['40.73617912', '-73.95234583'],
#  ['40.67179932', '-73.98398918'],
#  ['40.62775076', '-73.95962942'],
#  ['40.66938935', '-73.97936698'],
#  ['40.60327057', '-73.93529399'],
#  ['40.85424737', '-73.90126028'],
#  ['40.85696595', '-73.8875335'],
#  ['40.76996863', '-73.98208864'],
#  ['40.59406603', '-73.99007878'],
#  ['40.76310829', '-73.96071138'],
#  ['40.70095558', '-73.8918285'],
#  ['40.84754857', '-73.89560728'],
#  ['40.78326889', '-73.83996684'],
#  ['40.55912312', '-74.10598289'],
#  ['40.59447845', '-73.98622844'],
#  ['40.70807232', '-74.01779961'],
#  ['40.73951749', '-74.00396884'],
#  ['40.62051591', '-73.95874411'],
#  ['40.69025667', '-73.97234135'],
#  ['40.80402101', '-73.95281041'],
#  ['40.78281017', '-73.95150745'],
#  ['40.65017866', '-73.95962391'],
#  ['40.7226696', '-73.97718111'],
#  ['40.75013519', '-73.89095085'],
#  ['40.64054291', '-73.97750284'],
#  ['40.76726396', '-73.99030242'],
#  ['40.85845785', '-73.90160792'],
#  ['40.70830057', '-73.82844596'],
#  ['40.54960722', '-74.18440182'],
#  ['40.67404279', '-73.95395422'],
#  ['40.5924681', '-73.79713579'],
#  ['40.59354536', '-73.99184925'],
#  ['40.67813083', '-73.89650861'],
#  ['40.77036254', '-73.98154552'],
#  ['40.77123388', '-73.95966713'],
#  ['40.71149979', '-73.90753082'],
#  ['40.72528947', '-73.946732'],
#  ['40.77047459', '-73.98596471'],
#  ['40.73616366', '-73.98067313'],
#  ['40.80732247', '-73.96719944'],
#  ['40.72569708', '-73.97909807'],
#  ['40.64205589', '-74.00236598'],
#  ['40.64673764', '-73.95123356'],
#  ['40.67625398', '-73.95798142'],
#  ['40.7770893', '-73.91769088'],
#  ['40.59370116', '-73.99168684'],
#  ['40.59969829', '-73.75622313'],
#  ['40.76422556', '-73.92975138'],
#  ['40.75498147', '-73.83427783'],
#  ['40.76879797', '-73.90442392'],
#  ['40.5834737', '-73.82397193'],
#  ['40.71794872', '-73.93677211'],
#  ['40.75188675', '-73.88843106'],
#  ['40.73588436', '-73.9995854'],
#  ['40.77679762', '-73.91694035'],
#  ['40.77066826', '-73.98642287'],
#  ['40.69154585', '-73.97259679'],
#  ['40.84669493', '-73.91603248'],
#  ['40.69544412', '-73.94799785'],
#  ['40.7665429', '-73.98637067'],
#  ['40.64360575', '-73.96683229'],
#  ['40.6493897', '-73.95835615'],
#  ['40.8563235', '-73.88672874'],
#  ['40.58283323', '-74.08651136'],
#  ['40.54093888', '-74.18923615'],
#  ['40.71724309', '-73.94544886'],
#  ['40.77774504', '-73.96095697'],
#  ['40.83327795', '-73.90690109'],
#  ['40.83884369', '-73.87001251'],
#  ['40.83912378', '-73.87002412'],
#  ['40.75685573', '-73.98308165'],
#  ['40.7995744', '-73.96953689'],
#  ['40.64923077', '-73.95568857'],
#  ['40.69361445', '-73.96798361'],
#  ['40.69375722', '-73.96591657'],
#  ['40.85640447', '-73.89090157'],
#  ['40.57672003', '-73.85048877'],
#  ['40.67506176', '-73.97196016'],
#  ['40.58138308', '-73.82478884'],
#  ['40.73563404', '-73.98266889'],
#  ['40.76925783', '-73.95922788'],
#  ['40.76497172', '-73.99067638'],
#  ['40.72846888', '-73.95207231'],
#  ['40.72217808', '-73.8392081'],
#  ['40.77164614', '-73.91826096'],
#  ['40.75988228', '-73.87914913'],
#  ['40.90326351', '-73.84751149'],
#  ['40.781923', '-73.97532346'],
#  ['40.80239611', '-73.96230577'],
#  ['40.56047015', '-74.16271888'],
#  ['40.69613647', '-73.84348029'],
#  ['40.74990774', '-73.97654061'],
#  ['40.71290601', '-73.93971598'],
#  ['40.64210174', '-73.95815085'],
#  ['40.59241447', '-73.79713028'],
#  ['40.61825744', '-74.1369948'],
#  ['40.8155017', '-73.80829414'],
#  ['40.57879235', '-74.11074526'],
#  ['40.76161142', '-73.73587477'],
#  ['40.58154317', '-73.82422549'],
#  ['40.58145546', '-73.82453415'],
#  ['40.76427225', '-73.95933547'],
#  ['40.74452808', '-73.9854111'],
#  ['40.70789509', '-73.9156455'],
#  ['40.66965472', '-73.97273925'],
#  ['40.72232476', '-73.99073674'],
#  ['40.61352449', '-74.00698867'],
#  ['40.5998708', '-73.75621645'],
#  ['40.80929314', '-73.9654983'],
#  ['40.77241673', '-73.95684834'],
#  ['40.77346065', '-73.95804293'],
#  ['40.61133243', '-73.91197789'],
#  ['40.69144734', '-73.96061055'],
#  ['40.71275528', '-73.94033809'],
#  ['40.58826637', '-74.0869796'],
#  ['40.77117978', '-73.94736721'],
#  ['40.77823873', '-73.91004856'],
#  ['40.77828292', '-73.90999443'],
#  ['40.65156871', '-73.83203526'],
#  ['40.6756903', '-73.74783797'],
#  ['40.75860289', '-73.911641'],
#  ['40.75700789', '-73.88569126'],
#  ['40.61274488', '-73.97659555'],
#  ['40.51767689', '-74.19492804'],
#  ['40.63735751', '-73.96085162'],
#  ['40.756668', '-73.88562979'],
#  ['40.89168961', '-73.83378198'],
#  ['40.89025307', '-73.8341502'],
#  ['40.73525459', '-73.90008335'],
#  ['40.84777132', '-73.89364334'],
#  ['40.78120648', '-73.91780195'],
#  ['40.68626385', '-73.93661699'],
#  ['40.67580693', '-73.96480788'],
#  ['40.67605266', '-73.96598813'],
#  ['40.73285768', '-73.85493494'],
#  ['40.74828904', '-73.82639561'],
#  ['40.69072505', '-73.96045172'],
#  ['40.72154116', '-73.83878859'],
#  ['40.58438465', '-73.93170769'],
#  ['40.68509717', '-73.99900595'],
#  ['40.53002283', '-74.15949734'],
#  ['40.61894727', '-73.95640821'],
#  ['40.70476184', '-73.82141586'],
#  ['40.76908787', '-73.8981877'],
#  ['40.69535849', '-73.85850254'],
#  ['40.74210637', '-73.80939869'],
#  ['40.5794322', '-74.11194146'],
#  ['40.63777618', '-73.95579397'],
#  ['40.68558461', '-73.9946808'],
#  ['40.7231189', '-73.84446066'],
#  ['40.73151608', '-73.79034473'],
#  ['40.7635974', '-73.86800833'],
#  ['40.55892863', '-74.10615445'],
#  ['40.7327581', '-73.9847638'],
#  ['40.87016683', '-73.90441916'],
#  ['40.6713558', '-73.9713605'],
#  ['40.72151375', '-73.83630676'],
#  ['40.78280478', '-73.97468132'],
#  ['40.78240423', '-73.97497302'],
#  ['40.75165373', '-73.82942852'],
#  ['40.7511412', '-73.88734613'],
#  ['40.64390376', '-73.96098443'],
#  ['40.74255628', '-73.866793'],
#  ['40.71923851', '-73.83747603'],
#  ['40.52989284', '-74.16544644'],
#  ['40.7855742', '-73.85411981'],
#  ['40.61094838', '-73.96552793'],
#  ['40.78294953', '-73.91597681'],
#  ['40.6625075', '-73.95982735'],
#  ['40.73348329', '-73.75595235'],
#  ['40.84933525', '-73.85172194'],
#  ['40.76910085', '-73.9055467'],
#  ['40.58823855', '-74.08850458'],
#  ['40.73689499', '-74.00358611'],
#  ['40.60046522', '-73.74663781'],
#  ['40.72636133', '-73.94635859'],
#  ['40.59284161', '-74.16353728'],
#  ['40.59542651', '-73.7582516'],
#  ['40.7357081', '-73.99817893'],
#  ['40.76362307', '-73.96388853'],
#  ['40.74243039', '-73.92826539'],
#  ['40.85909696', '-73.89254967'],
#  ['40.63904098', '-73.9600716'],
#  ['40.71650512', '-73.83319329'],
#  ['40.72572233', '-73.78817631'],
#  ['40.76089849', '-73.82182411'],
#  ['40.84797529', '-73.8935215'],
#  ['40.76966936', '-73.89083846'],
#  ['40.78041662', '-73.96007527'],
#  ['40.72322904', '-73.8437543'],
#  ['40.76437966', '-73.9892713'],
#  ['40.62117761', '-74.03768117'],
#  ['40.52700726', '-74.16670128'],
#  ['40.78061277', '-73.98415749'],
#  ['40.73791181', '-74.00199676'],
#  ['40.604731', '-73.93853749'],
#  ['40.85945752', '-73.88558278'],
#  ['40.57708625', '-73.85070039'],
#  ['40.74865418', '-73.97795891'],
#  ['40.6883251', '-73.8665587'],
#  ['40.7859023', '-73.97246071'],
#  ['40.71991019', '-73.99005439'],
#  ['40.70866955', '-73.91485148'],
#  ['40.67524603', '-73.96001125'],
#  ['40.63749057', '-73.95578896'],
#  ['40.73804388', '-73.92155189'],
#  ['40.63737897', '-73.95381354'],
#  ['40.73986146', '-73.98536217'],
#  ['40.7398883', '-73.98542513'],
#  ['40.72529977', '-73.83937578'],
#  ['40.85787584', '-73.8878503'],
#  ['40.76491371', '-73.96085724'],
#  ['40.68802636', '-73.93896269'],
#  ['40.57133138', '-73.85807161'],
#  ['40.75838199', '-73.88783889'],
#  ['40.76439762', '-73.95963287'],
#  ['40.72309432', '-73.94762396'],
#  ['40.71946253', '-73.83582154'],
#  ['40.5589637', '-74.10612351'],
#  ['40.67665163', '-73.97387774'],
#  ['40.73726943', '-73.85940096'],
#  ['40.77018175', '-73.98110854'],
#  ['40.58341923', '-73.82415968'],
#  ['40.67661734', '-73.97237645'],
#  ['40.64883525', '-73.9644026'],
#  ['40.72534747', '-73.94676476'],
#  ['40.64537755', '-73.9574176'],
#  ['40.77029022', '-73.98329815'],
#  ['40.81976492', '-73.90658662'],
#  ['40.60808805', '-73.96607842'],
#  ['40.77339058', '-73.96333908'],
#  ['40.6954766', '-73.94771655'],
#  ['40.59634054', '-74.07730025'],
#  ['40.84668434', '-73.91548543'],
#  ['40.85123953', '-73.90424248'],
#  ['40.83705856', '-73.86916936'],
#  ['40.72468738', '-73.94780775'],
#  ['40.71684085', '-73.83802679'],
#  ['40.80528416', '-73.96134249'],
#  ['40.77040139', '-73.96611252'],
#  ['40.78093706', '-73.98492381'],
#  ['40.7286262', '-73.85652381'],
#  ['40.67304609', '-73.98627025'],
#  ['40.67316296', '-73.98617237'],
#  ['40.63617195', '-73.95358258'],
#  ['40.73722897', '-74.00564484'],
#  ['40.60159686', '-73.7426115'],
#  ['40.62097757', '-74.03492543'],
#  ['40.85495156', '-73.8910154'],
#  ['40.81739985', '-73.81161124'],
#  ['40.7140375', '-73.95955864'],
#  ['40.75376323', '-73.96638946'],
#  ['40.85102934', '-73.88707942'],
#  ['40.74209538', '-73.86612681'],
#  ['40.74006322', '-73.86634202'],
#  ['40.74044911', '-73.8051915'],
#  ['40.63894718', '-73.95683062'],
#  ['40.6036605', '-73.93572858'],
#  ['40.60470143', '-73.93688875'],
#  ['40.60503697', '-73.93726274'],
#  ['40.67491391', '-73.96310905'],
#  ['40.67142439', '-73.98453427'],
#  ['40.7628057', '-73.82758364'],
#  ['40.60796812', '-73.93855748'],
#  ['40.59577276', '-73.75920637'],
#  ['40.70809554', '-73.94510026'],
#  ['40.70838164', '-73.94502063'],
#  ['40.52602882', '-74.16740146'],
#  ['40.52906867', '-74.1595633'],
#  ['40.71431739', '-73.93882398'],
#  ['40.74704876', '-73.99280743'],
#  ['40.58357808', '-74.08816078'],
#  ['40.64313217', '-73.96674314'],
#  ['40.66664326', '-73.98269482'],
#  ['40.69600763', '-73.85730313'],
#  ['40.74429618', '-73.93064686'],
#  ['40.7940205', '-73.97446103'],
#  ['40.62501519', '-73.96340403'],
#  ['40.74194208', '-73.81005461'],
#  ['40.70801816', '-73.94508787'],
#  ['40.52600128', '-74.16746534'],
#  ['40.83201885', '-73.9283925'],
#  ['40.77010497', '-73.89883708'],
#  ['40.78033313', '-73.90860089'],
#  ['40.60680761', '-73.94007692'],
#  ['40.78288706', '-73.9189421'],
#  ['40.72058608', '-73.98520399'],
#  ['40.68919765', '-73.86677694'],
#  ['40.75698134', '-73.89408742'],
#  ['40.70888305', '-73.82786478'],
#  ['40.75071921', '-73.89012366'],
#  ['40.68587944', '-73.76874634'],
#  ['40.69464742', '-73.96899418'],
#  ['40.73818553', '-73.86632135'],
#  ['40.60460353', '-73.93677963'],
#  ['40.60573566', '-73.9380415'],
#  ['40.69363817', '-73.95913016'],
#  ['40.6644649', '-73.74983601'],
#  ['40.79637945', '-73.96197027'],
#  ['40.5222291', '-74.18562598'],
#  ['40.67136737', '-73.98458177'],
#  ['40.85262544', '-73.9001711'],
#  ['40.70819667', '-74.01770609'],
#  ['40.71299279', '-73.83143392'],
#  ['40.60403708', '-73.93783487'],
#  ['40.67088136', '-73.9774838'],
#  ['40.70844239', '-73.94503039'],
#  ['40.62049439', '-73.95894021'],
#  ['40.57220936', '-74.12585102'],
#  ['40.71179418', '-73.96524572'],
#  ['40.71065226', '-73.96627038'],
#  ['40.73520205', '-74.00582898'],
#  ['40.64429756', '-73.95317464'],
#  ['40.59374122', '-73.75914553'],
#  ['40.64306105', '-73.96919109'],
#  ['40.85793032', '-73.90128905'],
#  ['40.85804344', '-73.90161922'],
#  ['40.63859132', '-73.96558741'],
#  ['40.77693481', '-73.92211666'],
#  ['40.6720516', '-73.89421585'],
#  ['40.77841237', '-73.91382885'],
#  ['40.74033544', '-73.97729531'],
#  ['40.57574445', '-73.84992502'],
#  ['40.78374081', '-73.97382001'],
#  ['40.87023146', '-73.90092157'],
#  ['40.68154228', '-74.00443051'],
#  ['40.75765083', '-73.98304478'],
#  ['40.71270506', '-73.99758497'],
#  ['40.63536134', '-73.98352687'],
#  ['40.59359221', '-73.99180041'],
#  ['40.63438803', '-73.97909081'],
#  ['40.77323496', '-73.95820514'],
#  ['40.67619193', '-73.97362609'],
#  ['40.69115758', '-73.96054759'],
#  ['40.7128807', '-73.93982047'],
#  ['40.80805619', '-73.95983152'],
#  ['40.8428596', '-73.9001112'],
#  ['40.84681332', '-73.9155004'],
#  ['40.84757193', '-73.891431'],
#  ['40.84757796', '-73.90664068'],
#  ['40.62504975', '-73.96309381'],
#  ['40.58303831', '-74.08690965'],
#  ['40.74467888', '-73.92781655'],
#  ['40.70525958', '-73.90526215'],
#  ['40.7367644', '-73.86561807'],
#  ['40.67244571', '-73.97427583'],
#  ['40.72504083', '-73.95055819'],
#  ['40.76178034', '-73.98700411'],
#  ['40.74070592', '-73.93218262'],
#  ['40.67404231', '-73.95639612'],
#  ['40.57367535', '-74.12681887'],
#  ['40.59869603', '-74.16260123'],
#  ['40.67294194', '-73.98635746'],
#  ['40.6731051', '-73.98622083'],
#  ['40.64449024', '-73.97398609'],
#  ['40.76606034', '-73.77951459'],
#  ['40.62881554', '-73.95910694'],
#  ['40.73712447', '-74.00566547'],
#  ['40.85539038', '-73.88760376'],
#  ['40.60927794', '-74.00402241'],
#  ['40.57291654', '-74.00098899'],
#  ['40.52978381', '-74.16570859'],
#  ['40.69015151', '-73.866157'],
#  ['40.74294502', '-73.8660454'],
#  ['40.77217749', '-73.89743132'],
#  ['40.76849831', '-73.79633086'],
#  ['40.58836456', '-74.1886227'],
#  ['40.61561939', '-73.99384165'],
#  ['40.56962266', '-74.13854027'],
#  ['40.77160911', '-73.95939435'],
#  ['40.6085261', '-73.96616266'],
#  ['40.54164762', '-74.18786422'],
#  ['40.59337939', '-73.99340376'],
#  ['40.59357857', '-73.99378974'],
#  ['40.51732552', '-74.19518295'],
#  ['40.51810424', '-74.19551987'],
#  ['40.84658065', '-73.91594409'],
#  ['40.70984798', '-73.82898972'],
#  ['40.52848799', '-74.19948556'],
#  ['40.76808416', '-73.99225614'],
#  ['40.74841098', '-73.894002'],
#  ['40.78532206', '-73.84240573'],
#  ['40.75742773', '-73.88576718'],
#  ['40.60067263', '-73.76723764'],
#  ['40.76186626', '-73.73603575'],
#  ['40.84209556', '-73.8314239'],
#  ['40.57185183', '-74.121545'],
#  ['40.68119452', '-74.00230396'],
#  ['40.68618229', '-73.97546825'],
#  ['40.73745047', '-73.95234853'],
#  ['40.630186', '-73.99155782'],
#  ['40.84958242', '-73.89255913'],
#  ['40.66127251', '-73.98594537'],
#  ['40.78290966', '-73.91203277'],
#  ['40.77017766', '-73.98303059'],
#  ['40.72185073', '-73.84123676'],
#  ['40.80393434', '-73.95280608'],
#  ['40.80378267', '-73.95279851'],
#  ['40.66984888', '-73.97257729'],
#  ['40.61478835', '-73.96658193'],
#  ['40.59512186', '-73.75189789'],
#  ['40.7575093', '-73.88578194'],
#  ['40.590101', '-73.97292044'],
#  ['40.68121631', '-74.00238256'],
#  ['40.7700564', '-73.89757741'],
#  ['40.62990671', '-73.99109537'],
#  ['40.71385547', '-73.9397681'],
#  ['40.7492629', '-73.88617689'],
#  ['40.57688556', '-73.85058442'],
#  ['40.72527988', '-73.94967899'],
#  ['40.62066188', '-74.03799246'],
#  ['40.61472536', '-73.96713406'],
#  ['40.72130539', '-73.83957849'],
#  ['40.78531604', '-73.85243355'],
#  ['40.58436482', '-73.93188582'],
#  ['40.6385425', '-73.96107492'],
#  ['40.72999096', '-73.98829794'],
#  ['40.7404012', '-73.86641802'],
#  ['40.61467596', '-73.96761588'],
#  ['40.85796113', '-73.88445607'],
#  ['40.67435213', '-73.97739122'],
#  ['40.66732765', '-73.75067831'],
#  ['40.68159159', '-73.88984528'],
#  ['40.61093835', '-74.00100057'],
#  ['40.78479805', '-73.91524289'],
#  ['40.71736609', '-73.83226394'],
#  ['40.71012681', '-73.82739421'],
#  ['40.7683863', '-73.8980611'],
#  ['40.78933924', '-73.84452964'],
#  ['40.76076999', '-73.73547397'],
#  ['40.62765021', '-73.90189217'],
#  ['40.6087057', '-73.93755074'],
#  ['40.5981597', '-74.1624929'],
#  ['40.85866333', '-73.8928645'],
#  ['40.71098678', '-73.90757284'],
#  ['40.77043849', '-73.98209704'],
#  ['40.76294435', '-73.9603253'],
#  ['40.76319395', '-73.96091309'],
#  ['40.76253995', '-73.96324927'],
#  ['40.78028829', '-73.98365234'],
#  ['40.70256662', '-73.91498455'],
#  ['40.72083876', '-73.83682648'],
#  ['40.72854473', '-73.95184262'],
#  ['40.69576999', '-73.97061751'],
#  ['40.55904478', '-74.10605199'],
#  ['40.61432535', '-73.91246247'],
#  ['40.72392665', '-73.94978382'],
#  ['40.62004591', '-74.03289656'],
#  ['40.70689483', '-73.83138941'],
#  ['40.57200096', '-74.12839965'],
#  ['40.72892773', '-73.8555042'],
#  ['40.75715997', '-73.98223654'],
#  ['40.56070548', '-74.10683377'],
#  ['40.8484847', '-73.8940997'],
#  ['40.76472406', '-73.87020402'],
#  ['40.76470539', '-73.87037993'],
#  ['40.60331491', '-73.93710726'],
#  ['40.59660932', '-74.0793197'],
#  ['40.57151101', '-74.12324985'],
#  ['40.70318127', '-73.91127377'],
#  ['40.66131304', '-73.75711256'],
#  ['40.6882743', '-73.86584183'],
#  ['40.67496432', '-73.97895477'],
#  ['40.85054989', '-73.88669619'],
#  ['40.6514594', '-74.00759033'],
#  ['40.70447953', '-73.83230048'],
#  ['40.75716887', '-73.88572037'],
#  ['40.69377783', '-73.96885544'],
#  ['40.84951986', '-73.85186614'],
#  ['40.57164797', '-74.12163399'],
#  ['40.76916626', '-73.80944784'],
#  ['40.76650458', '-73.92878905'],
#  ['40.78276884', '-73.97371081'],
#  ['40.74962953', '-73.88470554'],
#  ['40.69118518', '-73.96039364'],
#  ['40.69102388', '-73.96035777'],
#  ['40.84579634', '-73.91928499'],
#  ['40.77223224', '-73.95222734'],
#  ['40.78311946', '-73.9156675'],
#  ['40.70261344', '-73.91509437'],
#  ['40.77201829', '-73.95909467'],
#  ['40.76256232', '-73.98946512'],
#  ['40.65069212', '-74.00285913'],
#  ['40.70666407', '-73.91690669'],
#  ['40.84066107', '-73.93833216'],
#  ['40.7173467', '-73.83453669'],
#  ['40.78283785', '-73.91611522'],
#  ['40.78268422', '-73.91630563'],
#  ['40.75767012', '-73.88947698'],
#  ['40.78557727', '-73.85320672'],
#  ['40.85099888', '-73.89446423'],
#  ['40.62603904', '-73.95870599'],
#  ['40.71977225', '-73.83775215'],
#  ['40.71506273', '-73.83505032'],
#  ['40.68921942', '-73.86734175'],
#  ['40.76238265', '-73.73721551'],
#  ['40.78345132', '-73.91844344'],
#  ['40.78324466', '-73.91875423'],
#  ['40.77253263', '-73.95840918'],
#  ['40.7258453', '-73.95101633'],
#  ['40.74021106', '-73.97738586'],
#  ['40.87395035', '-73.88131029'],
#  ['40.87384782', '-73.88122629'],
#  ['40.63620792', '-73.98210588'],
#  ['40.76957581', '-73.90726608'],
#  ['40.85595972', '-73.89055519'],
#  ['40.84993597', '-73.89012718'],
#  ['40.71762171', '-73.83260139'],
#  ['40.78564187', '-73.85397242'],
#  ['40.63827651', '-73.96600619'],
#  ['40.71571421', '-73.83154617'],
#  ['40.64922339', '-73.96379946'],
#  ['40.85239923', '-73.90097471'],
#  ['40.72503588', '-73.78472973'],
#  ['40.68713274', '-73.97270269'],
#  ['40.64273828', '-73.96465201'],
#  ['40.89126258', '-73.83389144'],
#  ['40.89033389', '-73.83412948'],
#  ['40.759994', '-73.82326355'],
#  ['40.76922814', '-73.89063016'],
#  ['40.84771733', '-73.89470051'],
#  ['40.75799481', '-73.8942729'],
#  ['40.71239072', '-73.96592316'],
#  ['40.76181351', '-73.73690826'],
#  ['40.63009154', '-73.99140141'],
#  ['40.64659769', '-73.95472132'],
#  ['40.75795579', '-73.8973693'],
#  ['40.65080674', '-73.83481023'],
#  ['40.83746668', '-73.93929338'],
#  ['40.60288727', '-73.74476239'],
#  ['40.61169703', '-73.9698354'],
#  ['40.75359561', '-73.89265187'],
#  ['40.70019272', '-73.89246318'],
#  ['40.71676785', '-73.94389672'],
#  ['40.65260281', '-73.9519308'],
#  ['40.85237441', '-73.88430921'],
#  ['40.61418686', '-74.16572026'],
#  ['40.724458', '-73.84186154'],
#  ['40.68135923', '-74.00326304'],
#  ['40.59511949', '-73.75157132'],
#  ['40.74668938', '-73.98064292'],
#  ['40.58737262', '-73.80683746'],
#  ['40.58727548', '-73.8067564'],
#  ['40.61832736', '-74.13697606'],
#  ['40.74046863', '-73.9289544'],
#  ['40.73239967', '-73.78763771'],
#  ['40.72670253', '-73.94655129'],
#  ['40.55685881', '-74.16930095'],
#  ['40.74069753', '-73.93211057'],
#  ['40.72644205', '-73.78695686'],
#  ['40.62595465', '-73.95657608'],
#  ['40.77098167', '-73.95762928'],
#  ['40.83711137', '-73.87007198'],
#  ['40.66926302', '-73.98942211'],
#  ['40.62369892', '-73.95925314'],
#  ['40.71846392', '-73.98291922'],
#  ['40.72813901', '-74.00239005'],
#  ['40.63798574', '-73.95392965'],
#  ['40.69698002', '-73.91503243'],
#  ['40.56261546', '-74.18192346'],
#  ['40.5625945', '-74.18209838'],
#  ['40.56929363', '-74.12944305'],
#  ['40.68505281', '-74.00015216'],
#  ['40.62479203', '-73.95751667'],
#  ...]

# %%
#take the text from my favorite books and render all the passages 
#create javascript bookmarklets and execute on them on pages
#make a chrome extension -> extract text from book and visualie and make notes
#make flash cards 
#make actions and functions that dont exist in programming languages 

# render a 3d model
# simplify the triangles from center to right side
# add a bezel on left hand corner - line by line execution -> CR line by line 



# for all news articles in Economist for last year
# find which ones have most relevance to astrophysics 


# make a game

# play a game 
# run forward 
# shoot lemons 
# jump every 5 seconds


# when i leave home
# ask rosy to wash dishes, clean bed, and empty litter box
# if run out of litter or laundry detergent or tortillas, order from instacart 






##https://www.zenrows.com/blog/pyppeteer#use

#how to make best magic english notebook ever
#write 5 noetbooks -> make code super clean and well documented -> use cursor -> relearn emacs 
#make it so people can easily contribute by reading notebook and adding their own function






def trees_map():
    trees_CSV = 'data/2015_Street_Tree_Census_-_Tree_Data.csv'
    from collections import defaultdict
    pointList = []

    with open(trees_CSV) as file:
        for sentence in file:
            parameters = sentence.split(',')
            pointList.append(parameters[-8:-6])
    return pointList[1:]


def trees_histogram():
    trees_CSV = 'data/2015_Street_Tree_Census_-_Tree_Data.csv'
    from collections import defaultdict
    counter = defaultdict(int)

    with open(trees_CSV) as file:
        for sentence in file:
            parameters = sentence.split(',')
            count = parameters[8]
            counter[count] += 1
    return counter
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
#        health                           spc_latin           spc_common  ...  \
# 0        Fair                         Acer rubrum            red maple  ...
# 1        Fair                   Quercus palustris              pin oak  ...
# 2        Good  Gleditsia triacanthos var. inermis          honeylocust  ...
# 3        Good  Gleditsia triacanthos var. inermis          honeylocust  ...
# 4        Good                     Tilia americana      American linden  ...
# ...       ...                                 ...                  ...  ...
# 683783   Good                   Quercus palustris              pin oak  ...
# 683784   Good                 Cladrastis kentukea  Kentucky yellowwood  ...
# 683785   Good                         Acer rubrum            red maple  ...
# 683786   Good                         Acer rubrum            red maple  ...
# 683787   Fair                         Acer rubrum            red maple  ...
#
#         boro_ct     state   latitude  longitude          x_sp         y_sp  \
# 0       4073900  New York  40.723092 -73.844215  1.027431e+06  202756.7687
# 1       4097300  New York  40.794111 -73.818679  1.034456e+06  228644.8374
# 2       3044900  New York  40.717581 -73.936608  1.001823e+06  200716.8913
# 3       3044900  New York  40.713537 -73.934456  1.002420e+06  199244.2531
# 4       3016500  New York  40.666778 -73.975979  9.909138e+05  182202.4260
# ...         ...       ...        ...        ...           ...          ...
# 683783  3051900  New York  40.713211 -73.954944  9.967407e+05  199121.6363
# 683784  4070700  New York  40.715194 -73.856650  1.023989e+06  199873.6475
# 683785  5020100  New York  40.620762 -74.136517  9.463514e+05  165466.0763
# 683786  2023502  New York  40.850828 -73.903115  1.011054e+06  249271.9507
# 683787  4134100  New York  40.732165 -73.787526  1.043136e+06  206095.5383
#
#        council district census tract        bin           bbl
# 0                  29.0        739.0  4052307.0  4.022210e+09
# 1                  19.0        973.0  4101931.0  4.044750e+09
# 2                  34.0        449.0  3338310.0  3.028870e+09
# 3                  34.0        449.0  3338342.0  3.029250e+09
# 4                  39.0        165.0  3025654.0  3.010850e+09
# ...                 ...          ...        ...           ...
# 683783             34.0        519.0  3062513.0  3.023690e+09
# 683784             29.0        707.0  4075448.0  4.031810e+09
# 683785             50.0        201.0  5011657.0  5.004080e+09
# 683786             15.0      23502.0  2007757.0  2.028120e+09
# 683787             24.0       1341.0  4153657.0  4.071360e+09
#
# [683788 rows x 45 columns]

# %%
json.load(open('./data/twitch.json', 'r'))
# Out:
# ['blah blah blah',
#  'Welcome to the chat room!',
#  'Iilysan: deppCanRead',
#  'animus_altia: Violet petals',
#  'Garklavs: femur breaker monkaW',
#  'Archaestra: geez',
#  'Argoniek: @zackrawrr You still need to break that wall where you raised the platform, you were doing fine',
#  "K_ree: i don't remember good luck",
#  'PersonalHateWatcher: HUH',
#  'notxill: how do ppl find out about these things lol @zackrawrr @chat',
#  'sanaekochiya22: Violet petals',
#  'ZulxGaming: or wait maybe near 1st elevator',
#  "Dark_Shadow_Moon: still don't know why crouch?",
#  'Welcome to the chat room!',
#  'KarLord_: to the twon and go ritgh',
#  'starb0y18: JUST WRECK ME NOW ASMON BABY',
#  'LeEnfantTerrible: below the city',
#  'hrisandre: This is the room right of the city below',
#  'el_dongo: YOU THE KISS ON THIS AREA BRO',
#  'Archaestra: ',
#  'Welcome to the chat room!',
#  'iGam3r_: no',
#  'xtorgex: Blessed name city',
#  'barusaja: yes',
#  'notxill: @lilysan and how did google find out?',
#  'derikoza: No',
#  'LheimZero: yes',
#  'iGam3r_: yesss',
#  'ilikedealdough: NO',
#  'gunrunnerhk45: yes',
#  'Argoniek: @zackrawrr Open that for the last kiss',
#  'MighttyGamerM: yes',
#  'LempkoTear: maybe',
#  'Sm00th3mi1: No other platform first from this side',
#  'Welcome to the chat room!',
#  'toddhoward41069: widepeepoHappy',
#  'sundance_16: Kissahomie',
#  'Fluff_Shake: ',
#  'Replying to @Jarlan23: how come your guys wears a bugle on he headorgulloalienigena: to hide the baldiness',
#  '360Fov: Has he been getting mad?',
#  'priyanshu14286f: You have to navigate to the upper ledge from another fountain upside down',
#  'Welcome to the chat room!',
#  'kerschi17: its not',
#  'notxill: @lilysan im left with no answer Sadge',
#  'Dobriy_Osan: ',
#  'sanaekochiya22: @zackrawrr just go to profundo lamento',
#  'NPCsz: Chat, please stop backseating ',
#  'Argoniek: Up, left up right',
#  'Welcome to the chat room!',
#  'Replying to @NPCsz: Chat, please stop backseating NotLikeThisarpyzone: he ask for it xdd',
#  'blackjackrc: wht that ledge was for',
#  'PiJamancer: what are you looking for rn zack?',
#  'dakmon5: is there mod here',
#  'Welcome to the chat room!',
#  'dakmon5: modLeave',
#  'Jgourmet69: Finally I get to catch you live! PagChomp',
#  'theycallmeschmii: Chat plays but its just us fucking with asmon',
#  'hrisandre: Just go right',
#  'LheimZero: go right',
#  'Argoniek: Go to the right',
#  'K_ree: go right',
#  'Welcome to the chat room!',
#  'Replying to @dakmon5: is there mod hereBarrosy: No PepeLaugh',
#  'atenbobi: KEKL',
#  'shadowreth: asmonThink asmonThink asmonThink',
#  'orcmago: pepeDent',
#  'Replying to @NPCsz: Chat, please stop backseating NotLikeThisKhyiror: N OMEGALUL',
#  'el_dongo: PEPEGA',
#  'AANNDO: Right and drop down',
#  'Argoniek: Stand at the edge for few seconds',
#  'LheimZero: go right and stand still',
#  'Brandoh: stand on edge',
#  'PersonalHateWatcher: THIS guy',
#  'Welcome to the chat room!',
#  'MighttyGamerM: upp',
#  'hrisandre: Its the room abov',
#  'Fubi___: lookUp',
#  'minergii: stand near the broken bridge',
#  'elduran9: Up',
#  'dakmon5: up up',
#  'Pistol_: up,up,down,down,left,right,left,right,select,start',
#  'boodham: go back up',
#  'Welcome to the chat room!',
#  'Arckedo: stand on the left platforn next to the ladder platform',
#  'clandestinemerkaba: Game needs better lootboxes.',
#  'Pogchampagner: circle',
#  'itsmepong2: Stand on the edge near the metal platform in the city',
#  'Argoniek: stand on the edge',
#  'PersonalHateWatcher: KEKL what is he doinnggg',
#  'SuperQuintendo: this shit looks amazing',
#  'orgulloalienigena: up',
#  'Welcome to the chat room!',
#  'Brandoh: the ledge on the left of that area down',
#  'Parcelazo: scrajj',
#  'arpyzone: the edge at below',
#  'iGam3r_: down',
#  'hrisandre: The left platform just as you enter the room',
#  'spc120: Steak, potato, and ice cream sandwich diet probably lol',
#  'el_dongo: LOL',
#  'Replying to @sundance_16: this game is so painful to look atsundance_16: fortnite looks 10x better than this',
#  'Arckedo: down the ladder, then the left platform',
#  'K_ree: :tf:',
#  'MighttyGamerM: at the door',
#  'boodham: no below, to the left of the bridge below',
#  'kerschi17: just stand next to the hole',
#  'Yace__: Waiting',
#  'Arckedo: more left',
#  'Brandoh: over',
#  'Welcome to the chat room!',
#  'Welcome to the chat room!',
#  'Welcome to the chat room!',
#  'basabox: PepeLa',
#  'GennPen: PepeLa TeaTime',
#  'Replying to @HappysFunPalace: im lvl 12pashpaliga: Salut',
#  '8loux: OnlyUp',
#  'Replying to @HappysFunPalace: im lvl 12thunderplains1: RIPBOZO',
#  '8loux: OnlyUp \U000e0000',
#  'pnutbttrspice: PogU',
#  'Ngzpro: PogU',
#  'ZeroHP01: Pog \U000e0000',
#  'pepegacharge: missed legendary shortcut PepeLa',
#  '00RedStar: Pog',
#  'ZeroHP01: Cla',
#  'saucy_beef: Pog god gamer',
#  'drontuffe: PPogo',
#  'johnpogchamp: ppHop',
#  'Replying to @HappysFunPalace: im lvl 12Danath_bym: RIPBOZO',
#  "NightLander: Hi guys I'm new here  Why are there random assets all over in this game? Are they stolen?",
#  'Mauserek: monakS eye',
#  'Raeydor: game so ez... where jump king',
#  'Replying to @HappysFunPalace: im lvl 12Coffeekit: DOCBOZO',
#  'Replying to @HappysFunPalace: im lvl 12vinc2346: bozoDance',
#  'Replying to @HappysFunPalace: im lvl 12Iilysan: ?? HUH',
#  'Cofic: WTFF',
#  'zenophi: Sick of Minecraft already, Bajs?  Sick of Minecraft already, Bajs?  Sick of Minecraft already, Bajs?  Sick of Minecraft already, Bajs? ',
#  'ShadeOfMidgar: @NightLander its a gray area',
#  'Oragee: WTFF',
#  'pepegacharge: Pog',
#  'pnutbttrspice: PogU HOLY',
#  'chattenw: clean',
#  'Microrazor117: Starege',
#  'TodaysTheDayEh: monkaS',
#  'BeCore92: WTFF',
#  "Replying to @NightLander: Hi guys I'm new here :) Why are there random assets all over in this game? Are they stolen?thunderplains1: Suseg",
#  'Goanfy: god gamer',
#  'furi321: NELLY',
#  'knottsogood: PauseChamp',
#  'J3TS0N_: PogU',
#  'poenjoyer: WTFF',
#  'Replying to @lil_mixtape12: @HappysFunPalace RIPBOZOKaitojutsu: illiterate chatter LOLW',
#  'Welcome to the chat room!',
#  'qubitg: no mans sky no mans sky no mans sky no mans sky',
#  'stonaholic420: 40 hours holy fucking shit',
#  'eagleswintwitch: LOLW',
#  'HitM4chin3: Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp',
#  'knottsogood: LOLW',
#  'doug_as: D:',
#  'drontuffe: peepoBrazil BRO?',
#  'WunchleR: message deleted by a moderator.',
#  'DeathMascot: 36.9 hrs OMEGALUL',
#  'HappysFunPalace: NEW GAME AFTER! 🚨 GOOD TAKES 🚨',
#  'otizly: message deleted by a moderator.',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN.',
#  'TerraPhy: JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive JUMP KING DLC docArrive',
#  'alexiwylde: TERRARIA',
#  'carrot1337: ai discussion for 2 hours into end stream now PainChamp',
#  'heAVen93: message deleted by a moderator.',
#  'epicprankzz: message deleted by a moderator.',
#  'Spudnubs: PPogo Glizzy POGOSTUCK TIME PogU PPogo Glizzy POGOSTUCK TIME PogU PPogo Glizzy POGOSTUCK TIME PogU PPogo Glizzy POGOSTUCK TIME PogU PPogo Glizzy POGOSTUCK TIME PogU PPogo Glizzy POGOSTUCK TIME PogU PPogo Glizzy POGOSTUCK TIME PogU',
#  'pala55555: peepoSHAKE JUMP KING WHEN?! peepoSHAKE JUMP KING WHEN?! peepoSHAKE JUMP KING WHEN?! peepoSHAKE JUMP KING WHEN?! peepoSHAKE JUMP KING WHEN?!',
#  "Aishiki: no NFT's ? Madge",
#  'notclariity: docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive WOW HC docArrive',
#  'Alakolaz: @Quin69 check out the speedrun',
#  'Seix__: https://www.youtube.com/watch?v=k5Dx_M4Lpfc&ab_channel=YuraYakudza',
#  'shopherodobrasil: REFUND REFUND REFUND REFUND REFUND',
#  'Hobobloke: classic WOW HC LOGIN',
#  'Welcome to the chat room!',
#  'jakzh: PepeLa',
#  'InkkiFPS: why not just start another game?',
#  'AramoS: PepeLa \U000e0000',
#  'charliesheenn1: NEW GAME IMMEDIATELY',
#  'meazey3: glitch run you mean',
#  'eagleswintwitch: PepegaCredit',
#  'toaw: watch world record',
#  'be_g0d: peepoBrazil',
#  'Kithe__: PepeLa',
#  'lil_mixtape12: PepeLa',
#  'insomniakakak: LOLW',
#  'Magekiller84: LOLW',
#  'SuitedConnector: Pog',
#  'Brevlty: LAST EPOCH',
#  'Obedient_potato: PepeLa',
#  'Dishftw: Fuck around in Dark and Darker? PauseChamp',
#  'knottsogood: EZ',
#  'エーギル (tamate): Pog',
#  'pandagreenmonk: Baseg',
#  'blauli: PepegaCredit',
#  'Lavastar46: PepegaCredit',
#  'HitM4chin3: Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp @Quin69',
#  'insomniakakak: not a brand risk LOLW',
#  'SanguineOD: LOLW',
#  'Comitatvs: PepegaCredit',
#  'Owyui: PainChamp',
#  'qiwwy: LOGIN',
#  'ValkyW: LOLW',
#  'Meleko: HarvestDetected',
#  'pizzacody: LOLW',
#  'Sh4dge: PainChamp',
#  'Welcome to the chat room!',
#  'Brevlty: LAST EPOCH',
#  'Obedient_potato: PepeLa',
#  'Dishftw: Fuck around in Dark and Darker? PauseChamp',
#  'knottsogood: EZ',
#  'エーギル (tamate): Pog',
#  'pandagreenmonk: Baseg',
#  'blauli: PepegaCredit',
#  'Lavastar46: PepegaCredit',
#  'HitM4chin3: Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp @Quin69',
#  'insomniakakak: not a brand risk LOLW',
#  'SanguineOD: LOLW',
#  'Comitatvs: PepegaCredit',
#  'Owyui: PainChamp',
#  'qiwwy: LOGIN',
#  'ValkyW: LOLW',
#  'Meleko: HarvestDetected',
#  'pizzacody: LOLW',
#  'Sh4dge: PainChamp',
#  'Magekiller84: EZ',
#  'Fedelta: EZ',
#  'Capsuleer: PainChamp',
#  'eagleswintwitch: Baseg',
#  'gang_juul: PoE LOGIN',
#  'wyrmroot: Have you played the game Control? Good combo of story + cool combat mechanics',
#  'poenjoyer: EZ',
#  'zRaayan: PainChamp',
#  'Welcome to the chat room!',
#  'Fogo_: distortion 16 min',
#  'Falkonfx: peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS peepoIronman RANKED AWAITS',
#  'Incognymous: Play nms',
#  'lindwormen: 3rd video',
#  'MaisbauerMalte: YEP all of them',
#  'kaesoni: 1 minute one',
#  'MisterHiNRG: HIGHER',
#  'RefinedAutist: 13:10',
#  'Deathclaim: distortion GIGACHAD',
#  'Entoren: no faster one',
#  'single0player2: third',
#  'incognitor: watch a distortion2 one',
#  'Wagag: PainChamp',
#  'stonaholic420: former ICANT',
#  'Niller2005: https://www.bilibili.com/video/BV1Mu411E7ME/?spm_id_from=888.80997.embed_other.whitelist&t=2 this is WR',
#  'Appias_Nero: 13min',
#  'insomniakakak: NOPE',
#  'Cofic: 13 minute',
#  'Owyui: there are faster ones',
#  'Sean_Bombadil: nooooooooooooooo',
#  'FeRust: Shrugeg just pick one',
#  'LukaTee: REACT MERCHANT LOLW',
#  'aidsrain: pokimane naked busty',
#  'God_of_Casuals: too slow',
#  'flashpump: 13',
#  'D5bad: @Quin69 13 minutes',
#  'morthiius: 13 mins',
#  'Tovello: 13 min one',
#  'para011: he has better',
#  'LuckyLlamaLiam_: PainChamp',
#  'octolv: noo',
#  'rerunthefun: 13 minute one',
#  'toaw: not that one',
#  'afklordz: no',
#  'Kelthiz: 13 minute one',
#  'adnan_junior: 13 min is wr',
#  'FlinnRED: No',
#  'HitM4chin3: Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp Terraria ! PauseChamp d',
#  'EvilMogu: PainChamp',
#  'wishmaker50: 13:10',
#  'Ash00182: 13:10',
#  'chocopainwastaken: 19 is not best',
#  'mastaz: 13',
#  'DirtyUsername: do 13 min one @Quin69',
#  'Sheshantol: 13 minute Stare',
#  'knottsogood: 13min YEP',
#  'scurr_lobster: 3rd video',
#  'hybridsr: no PainChamp',
#  'HeyRaynor: its slow as fuck',
#  'grizzlywood: ???',
#  'Kadapubo: 13:10',
#  "Sudo_Nym_: It's really good",
#  'devb0ne: message deleted by a moderator.',
#  'McWinSauce: watch the fastest one',
#  'Drizz_36: just go to speedrun dot com and look it up',
#  'Comitatvs: NOPE',
#  'Welcome to the chat room!',
#  'grizzlywood: you know?',
#  'LuckyLuc84: ????????????',
#  'Sambhaid: D:',
#  'mastaz: FUCK THAT GUY',
#  'aariiiiiiiiiiiiiiiiiiiii: LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW LOLW',
#  'internetbaconmachine: Wokege',
#  'stupidguycostume: quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic',
#  'drontuffe: quinEatingHisMic quinEatingHisMic quinEatingHisMic',
#  'Grumahr: WHY WATCH SOMEONE SLOW LOLW',
#  'rsn26_: WATCH THE 13:10 U CUNT ITS FROM HIM',
#  'lil_p0p0: Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic',
#  'facegen: Baseg Baseg Baseg Baseg Baseg Baseg Baseg Baseg',
#  'Prour: OH YEAH EAT THAT MIC gachiHYPER',
#  'LukaTee: LOLW hahahaha',
#  'culliganman76: WHAT A BOJO',
#  'Dix3n: 2Header',
#  'Sambhaid: D: wtf',
#  'Akmarum: ??????????',
#  'xHydro12: yap',
#  'Cofic: quinEatingHisMic 💢 Wokege',
#  'Torbane: theres a 13 min one dude',
#  'idenlinelol: eat the mic LuL',
#  'Kithe__: D:',
#  'Ngzpro: ???????',
#  'b_o_o_f: quinEatingHisMic DUMB RETARD',
#  'epicprankzz: ?????????',
#  'ogpurpledaddy: LOLW',
#  'dimmitsaras: ?????',
#  'bombey01: quinEatingHisMic dum fucks',
#  'Grunton: you know them LOLW',
#  'unfathomable_cringe: HUH',
#  "McWinSauce: we'd rather watch the best one",
#  'GetJjuiced: PainChamp',
#  'lidrix0: LOLW LOLW LOLW',
#  'facegen: Baseg Baseg Baseg Baseg Baseg Baseg Baseg Baseg \U000e0000',
#  'suprsand: ??????????',
#  'pootietrain: Wokege',
#  'Instability01: VIEWER ANDY LOLW',
#  'D3FT: why are you screaming',
#  'drontuffe: quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic quinEatingHisMic',
#  'bruhSit_farmer: loud = funny',
#  'mastaz: ??????????',
#  'h0go: my neighbours wtf',
#  'Sambhaid: D:',
#  'Cofic: quinEatingHisMic 💢 Wokege \U000e0000',
#  'nudegoblin: OneGuy',
#  'xHydro12: YAP',
#  'noreasonwhy42: Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK',
#  'UninstallDota: quinXD',
#  'sorrysmurf: 3 MINUTES FASTER IS CRAZY',
#  'epicprankzz: ????????????????',
#  'nullpntr: what is wrong with this guy',
#  'Speyll: classic',
#  'Zen_gamer_: ???',
#  'Kithe__: TAUNTED KEKW',
#  'GennPen: quinEatingHisMic SPEED',
#  'pizzacody: LOLW',
#  'leodebeer: PARASOCIAL ANDY LOLW SOMEONE I KNOW',
#  'Welcome to the chat room!',
#  'noreasonwhy42: Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK Strongge Clap FUTACOCK',
#  'UninstallDota: quinXD',
#  'sorrysmurf: 3 MINUTES FASTER IS CRAZY',
#  'epicprankzz: ????????????????',
#  'nullpntr: what is wrong with this guy',
#  'Speyll: classic',
#  'Zen_gamer_: ???',
#  'Kithe__: TAUNTED KEKW',
#  'GennPen: quinEatingHisMic SPEED',
#  'pizzacody: LOLW',
#  'leodebeer: PARASOCIAL ANDY LOLW SOMEONE I KNOW',
#  'Narks__: braindead',
#  'Magekiller84: Okayeg NEPOTISM',
#  'ravianc: agree',
#  'drontuffe: quinXD',
#  'unfathomable_cringe: HUH ????',
#  'Sambhaid: D: too far',
#  'thingkin: UHM',
#  'Dunkingsonn: quinXD',
#  'M1ndK1ller: skin in the game',
#  'HeyRaynor: sounds retarded',
#  'mavkooo: Baseg',
#  'xlMonumentlx: TRUE YEP',
#  'sarumandestroyer: quinEatingHisMic',
#  'captainjoeyletsgo: random guy GIGACHAD',
#  'dwaynefrogsky: Baseg',
#  'Sharpie994: LOLW',
#  'twoip: retard',
#  'Anariina: waytodank',
#  'AllLucky7s: quinXD',
#  '09009: D:',
#  'bombey01: quinEatingHisMic dum fucks',
#  'qubitg: scripted',
#  'katsuhito94: quinEatingHisMic',
#  'sorairodays_: quinXD',
#  'exiledbutcher: SCHIZO',
#  'Mauserek: THEN GO TO SPEEDRUN COM AND CHECK THE CURRENTR WR',
#  'T_Eggy: ???????????',
#  'mara_Smug: quinXD',
#  'enslavedEmperor: Baseg',
#  'TORTELLUCI: Why',
#  'meazey3: stopbeingMean',
#  'CyB3Rk1ll: PepeLa',
#  'MrManBloke: viewer andy',
#  'mastaz: VIEWER ANDY LOLW',
#  'FrozenPrimordial: U ARE STUPI',
#  'Ogalos: quinXD',
#  'TerroristWookiee: true',
#  'From_Zero: ??????',
#  'Instability01: VIEWER ANDY LOLW',
#  'Sheshantol: Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic Pepegaphone quinEatingHisMic',
#  'RaunoRepomies: quinXD',
#  'Braamberg: watching slow guy LOLW',
#  'Vaydra_: D:',
#  'HappysFunPalace: ???????????????',
#  'Kithe__: TAUNTED KEKW TAUNTED KEKW TAUNTED KEKW TAUNTED KEKW TAUNTED KEKW',
#  'leodebeer: PARASOCIAL ANDY LOLW SOMEONE I KNOW PARASOCIAL ANDY LOLW SOMEONE I KNOW PARASOCIAL ANDY LOLW SOMEONE I KNOW PARASOCIAL ANDY LOLW SOMEONE I KNOW PARASOCIAL ANDY LOLW SOMEONE I KNOW PARASOCIAL ANDY LOLW SOMEONE I KNOW',
#  'shitsack42: parasocial fuck',
#  'bombey01: quinEatingHisMic dum fucks',
#  'heAVen93: quinXD',
#  'es0teric: WHAT ARE YOU EVEN ON ABOUT?',
#  'huuzera: quinXD',
#  'dhaart_: ??',
#  'StripedPj: relax clown',
#  'Wildzeeh: LOUD = TRUE',
#  'baoxrs: Distortion2 vegan',
#  'facegen: Baseg',
#  'Akmarum: VIEWER ANDY classic',
#  'Sambhaid: D: the 13min is good',
#  'vandy294: WAYTOOLOUD WAYTOOLOUD',
#  'drontuffe: quinXD WHAT ARE YOU EVEN ON ABOUT?',
#  'aurexmasino: TRUE',
#  'LittleRocket: ANYONE ELSE HAD DEJA VU',
#  'epicprankzz: SHIT TAKE LOLW',
#  'charliesheenn1: NEW GAME IMMEDIATELY',
#  'ogpurpledaddy: Wokege',
#  'hi_im_robbie: BabyChat BabyChat BabyChat BabyChat bidenBlast',
#  'CakeButt111: shut up retard',
#  'UninstallDota: sickend',
#  'argilesmithford: toxic bro',
#  'bombey01: quinEatingHisMic dum fucks',
#  'Welcome to the chat room!',
#  'bombey01: Aware of',
#  'Zen_gamer_: parasocial LOLW',
#  'johnyoakman: ????',
#  'Triple_Chain_Gang: 13:10 IS DINO SKIPS CHAT RETARDSS',
#  'argilesmithford: so toxic bro',
#  'GarbrielMelo: viewer andy classic',
#  'Kuiper222: viewer andy',
#  'akemi27: IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW IEWER ANDY LOLW',
#  'Sambhaid: Aware',
#  'culliganman76: SO RETARDED',
#  'Grunton: COPIUM',
#  'Triple_Chain_Gang: 13:10 IS DINO SKIPS CHAT RETARDSS13:10 IS DINO SKIPS CHAT RETARDSS',
#  'cloakheart: dist is a GIGACHAD',
#  'ChemicaaLz: PEPW',
#  'epicprankzz: SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW SHIT TAKE LOLW',
#  'TheBaldrus: SHUT UP NOW',
#  'Zorumero: Kapp',
#  'clubs1216: viewer andy',
#  "SNIFFAxdd: quin prefers entertainment more than skill and that's ok ",
#  'CENSOR_FREE_THOUGHT: hes gonna react to like 5 then upload them all KEKW hes gonna react to like 5 then upload them all KEKW hes gonna react to like 5 then upload them all KEKW hes gonna react to like 5 then upload them all KEKW hes gonna react to like 5 then upload them all KEKW',
#  'BigRudeBoi: WHY ARE YOU SHOUTING AT US?!?!',
#  'Triple_Chain_Gang: 13:10 IS DINO SKIPS CHAT RETARDSS13:10 IS DINO SKIPS CHAT RETARDSS13:10 IS DINO SKIPS CHAT RETARDSS',
#  'Fjumre: he has so mush seen that one',
#  'icedfierytree: There is 4 second runs Aware',
#  'fonss1: parasocial andy ICANT',
#  'JBallsMahoney: ',
#  'rubenlwd: #ad',
#  'knottsogood: viewer andy vegan andy',
#  "Mez42: wow, let's expose new people... nope,",
#  'flashpump: So slow',
#  'jace7z: he barely talks anyway',
#  'victorbechas: “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW “I KNOW” PARASOCIAL LOLW',
#  'Sheshantol: quin being a viewer andy classic',
#  'mastaz: WOW HE TALKS SO MUCH KEKW',
#  'Vengos: viewer andy',
#  'EarWaxSnacks: VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW VIEWER ANDY LOLW',
#  'Welcome to the chat room!',
#  'EarWaxSnacks: COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU COMMENTARY PogU',
#  'SheepFarmer: ▶️',
#  'poenjoyer: COPIUM',
#  'Hobobloke: NICE COMMENTARY LOLW NICE COMMENTARY LOLW NICE COMMENTARY LOLW NICE COMMENTARY LOLW NICE COMMENTARY LOLW NICE COMMENTARY LOLW NICE COMMENTARY LOLW NICE COMMENTARY LOLW',
#  'okihsam: not robot btw KEKW',
#  'Sheshantol: muted? Aware',
#  'knottsogood: slow mo in speed run ICANT',
#  'razorback501: react harder man',
#  'fonss1: REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM',
#  'es0teric: REACT HARDER STREAMER',
#  'Arcaddia_: no shit',
#  'iiCON234: COPIUM I COULD DO THIS',
#  'B_Gonzo: Not talking',
#  'Zobiris: LOLW NO SHIT',
#  'Ogalos: PepeLa',
#  'zRaayan: no sound?',
#  'vengerwow: lmao',
#  'Defekter: its a speed run quin',
#  'lil_p0p0: COPIUM',
#  'mastaz: wow HE TALKS SO MUCH KEKW WOW HE TALKS SO MUCH KEKW wow HE TALKS SO MUCH KEKW WOW HE TALKS SO MUCH KEKW wow HE TALKS SO MUCH KEKW WOW HE TALKS SO MUCH KEKW wow HE TALKS SO MUCH KEKW WOW HE TALKS SO MUCH KEKW wow HE TALKS SO MUCH KEKW WOW HE TALKS SO MUCH KEKW wow HE TALKS SO MUCH KEKW WOW HE TALKS SO MUCH KEKW',
#  'alimoncho: wideVIBE',
#  'Sambhaid: COPIUM',
#  'lupi_the_chatter: PauseChamp',
#  'Grunton: he wont',
#  'Jcube23: Muted',
#  'Smocaine: PauseChamp when does the talking start PauseChamp when does the talking start PauseChamp when does the talking start PauseChamp when does the talking start',
#  'hameln: its slows you down',
#  'stonaholic420: PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking? PauseChamp talking?',
#  'Dix3n: HE WONT',
#  'Kelthiz: Slow mo in speedrun LOLW',
#  'Zeeterm: Slow-mo in a speedrun ICANT',
#  'akemi27: nice commentary LOLW',
#  'D3FT: COPIUM',
#  "Traktorq: he won't",
#  'Sambhaid: LOLW',
#  "flipgeneral: dist doesn't talk much",
#  'johnyoakman: React harder',
#  'MOODYRUSE: slowmo in a speedrun 2Header',
#  'unfathomable_cringe: GIGACHAD',
#  'jarost: slowmo in a speedrun ICANT',
#  'hyperhopper: commentary Clueless',
#  'HeyRaynor: slow dog shit run',
#  'seruman1234: slowmo in speed run ICANT',
#  'Breese616: Clueless',
#  'gang_juul: PainChamp stalling',
#  'DoingBusiness: is this video muted?',
#  'HappysFunPalace: COPIUM',
#  'CENSOR_FREE_THOUGHT: reacting the rest of the day KEKW reacting the rest of the day KEKW reacting the rest of the day KEKW reacting the rest of the day KEKW reacting the rest of the day KEKW',
#  'EvilMogu: Clueless',
#  'argilesmithford: angry streamer Quin69',
#  'shitsack42: react streamer Bedge',
#  'DirtyUsername: COPIUM',
#  'Welcome to the chat room!',
#  'Sh4dge: GIGACHAD',
#  'lastofherkind: quinRun nyoooooooom',
#  'bruhSit_farmer: Bedge',
#  'D3FT: EZ',
#  'synamon_: ICANT Non stop talking \U000e0000',
#  'poenjoyer: NOWAY',
#  'wtfblub: no shit',
#  'Zobiris: GIGACHAD',
#  'Sharpie994: GIGACHAD',
#  'hameln: EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls \U000e0000',
#  'vaklovsky: no shit',
#  'hounin: no shit',
#  'gang_juul: Bedge I didnt',
#  'bombey01: NOWAY \U000e0000',
#  'fonss1: NOWAY BED SKIP',
#  'mlgnightowl360: no shit',
#  'sorrysmurf: really',
#  'averagetwitchchatter23: no shit',
#  'Tr4gicSinz: duh',
#  'Owyui: NOWAY',
#  'uglypuncha: LOLW',
#  'journalist_gamer: duh',
#  'albania4everrr: really?',
#  'Prour: No shit LOLW',
#  'baoxrs: Imagine watching this slow run PainChamp',
#  'AllLucky7s: no shit',
#  'poenjoyer: no shit',
#  "nukedbear: Yeah that's what you call a 'god gamer'.",
#  'MaisbauerMalte: no shit',
#  'Lightnin_g: no shit LOLW',
#  'leodebeer: sleep is for the weak GIGACHAD',
#  'SergioLTJ: no shit sherlock',
#  'Dishftw: No shit',
#  'cloakheart: Baseg',
#  'Lorrliss: NOWAY',
#  'Speyll: PagBounce the roll',
#  'Deathclaim: NOWAY',
#  'johnpogchamp: quinRoll',
#  'D3FT: no shit',
#  'EXE121: no shit LOLW',
#  'AYAYAlsMyWaifu: no shit',
#  'TaurenRoguez: no shit',
#  'Welcome to the chat room!',
#  'SuitedConnector: no way nowae',
#  'vanishDD: quinRoll',
#  'ogpurpledaddy: zyzzPls',
#  'ayssence: zyzzPls EDM JIM zyzzPls EDM JIM zyzzPls EDM JIM zyzzPls EDM JIM zyzzPls EDM JIM zyzzPls EDM JIM zyzzPls EDM JIM zyzzPls EDM JIM',
#  'DoingBusiness: LOLW',
#  'poenjoyer: no shit',
#  'M1ndK1ller: stylin on u',
#  'Fabinho7x: NO SHIT SHERLOCK',
#  'Prana87: zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls EDM zyzzPls',
#  'MisterHiNRG: NOWAY',
#  'Chur_Bro: Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls Hakken zyzzPls',
#  'Jee_FX: 5, quin upside down, crooked, reverse, inverted, flipped, suffocation, suffering, falling, highly detailed',
#  'emmokb: YOU DONT FUCKING SAY LMAO',
#  'Dishftw: Hes not a react streamer YEP',
#  'bombey01: quinRoll',
#  'milenskipi4a: GOD GAMER',
#  'SanguineOD: a fetus could do that',
#  "peepohonkers: no shit he's an actual god gamer",
#  'DizzierDizzi: You skipped every bed @Quin69',
#  'Squall_Leonheart_92: YEP',
#  'Sh4dge: 5Head',
#  'fonss1: REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM REACT HARDER UHM',
#  'bomberman2442: @Quin69 try old school runescape hardcore',
#  'Welcome to the chat room!',
#  'unfathomable_cringe: PepeLa',
#  'TheCheeseBorn: PepeLa',
#  'TvAristotle: Clueless',
#  'conploe: POGGERS',
#  'Judders96: PauseChamp windmill skip',
#  'Sheshantol: he has 20 hours played to get a 19 minute speedrun, you have 40 hours for a single 3 hour run ICANT',
#  'Sybrecet: PepeLa',
#  'cryptometoxos: SCAM MOVE NOW',
#  'martin02x: PepeLa',
#  'icedfierytree: PepeLa this part',
#  'Cheozubil: WICKEG',
#  'D3FT: PEPW wait for it',
#  'SuitedConnector: WTF PogU WTF PogU WTF PogU WTF PogU WTF PogU WTF PogU WTF PogU WTF PogU',
#  'Charlie_devil: Dist?',
#  'Manoekin: WTFF \U000e0000',
#  'queenofshwords: ',
#  'loki94y: ???????????',
#  'drontuffe: HOLY Baseg',
#  'Mauserek: GIGACHAD',
#  'Lightnin_g: LOLW',
#  'lastofherkind: PogU',
#  'Welcome to the chat room!',
#  'alyxzlol: !rip',
#  'DraXxico: your poe build guides then basically',
#  'StreamElements: Died https://www.youtube.com/watch?v=5_gWk0unCTI',
#  'KiMLoKO_: YEP',
#  'bombey01: @Quin69 peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'RefinedAutist: yap',
#  'Standinfire: still impressive',
#  'notclariity: any game ever?',
#  'boneweaver99: its like AI BatChesting',
#  'Arnday: like you and your poe builds YEP',
#  'iLLMENTAL:  BatChesting ARTIFICIAL INTELLIGENCE',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'Martin_Woad: like PoE',
#  'loki94y: BRUTE FORCE 69',
#  'FeRust: hivemind iterative AI',
#  'Falkonfx: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'Zrrcu: yep de wae',
#  'Grunton: no',
#  'minime05: AwkwardMonkey mathil builds',
#  'hounin: yap yap',
#  'Qanik: yap HOLY',
#  'djsempai: @Quin69 peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'Tsuuka: no it was just him',
#  'roomblank: he came up with the boat strat',
#  'eagleswintwitch: AwkwardMonkey stealing builds',
#  'eleffi: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'Abitbol: 5, Quin69 as a ((busty)) female paladin in world of warcraft, skimpy shiny armor, gold accents, wielding the hammer of justice, intricate details, holy aura, epic, (massive boobs), (bigger boobs), (biggest boobs), from the back',
#  'Welcome to the chat room!',
#  'smbizzle: Geez you LOVE the buzzword "AI" don\'t you?',
#  'TeknoHamster: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'Falkonfx: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'M1ndK1ller: Soy FM BatChesting \U000e0000',
#  'Belenor89: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'kado______: SOY FM ICANT',
#  'kizilsakal99: VIBE',
#  'DirtyUsername: peepoIronman do this quin @Quin69',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'Welcome to the chat room!',
#  'johnyoakman: Like POE',
#  'Hivani: ',
#  'smbizzle: Geez you LOVE the buzzword "AI" don\'t you?',
#  'TeknoHamster: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'Falkonfx: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'M1ndK1ller: Soy FM BatChesting \U000e0000',
#  'Belenor89: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'kado______: SOY FM ICANT',
#  'kizilsakal99: VIBE',
#  'DirtyUsername: peepoIronman do this quin @Quin69',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'DonZotto: everything is ai',
#  'Jee_FX: 5, quin upside down, crooked, reverse, inverted, full body, pain, suffocation, suffering, highly detailed',
#  'Truckmcdirt: Yap EXCUSES yap',
#  'Falkonfx: peepoIronman COME BACK QUIN',
#  'Hawkspeed: SOY MUSIC',
#  'uglypuncha: batPls',
#  'djsempai: @Quin69 peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'FCdeO: LOST LEGENDARY JUMP ICANT LOST LEGENDARY JUMP ICANT LOST LEGENDARY JUMP ICANT LOST LEGENDARY JUMP ICANT',
#  'Welcome to the chat room!',
#  'schanes: peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME',
#  'Jee_FX: 5, quin upside down, crooked, reverse, inverted, full body, pain, suffocation, suffering, highly detailed',
#  '09009: peepoIronman',
#  '2160p: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'Saktap: OSRS PagMan OSRS PagMan OSRS PagMan OSRS PagMan OSRS PagMan OSRS PagMan OSRS PagMan OSRS PagMan OSRS PagMan',
#  'wagawaga4k: peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME',
#  'Tsuuka: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69",
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN.',
#  'fx_fiexible_: peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peep',
#  'mastaz: TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW TRAMPOLINE RUINED THE GAME LOLW',
#  '2160p: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'peetNV: LEAGUE FROGS FUCK OFF Baseg LEAGUE FROGS FUCK OFF Baseg LEAGUE FROGS FUCK OFF Baseg',
#  'bombey01: peepoIronman LOGIN',
#  'internetcelebrity: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUI',
#  'RefinedAutist: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN \U000e0000',
#  'iLLMENTAL: peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME peepoIronman HYPERCLAP ITS TIME',
#  'SergioLTJ: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'Careless_Drifter: 3 guys 1 man spamming ICANT',
#  'Welcome to the chat room!',
#  'AYAYAlsMyWaifu: FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage FUCKIN WAOWICK IS WAITING FOR YOU Quin69 peepoRage',
#  'Baby_Smell: COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUINCOME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUINCOME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIron',
#  'fx_fiexible_: peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR .',
#  'djsempai: @Quin69 peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3",
#  'M1ndK1ller: you havent',
#  'QUOTE_ME_IF_DOCLEAVE: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3",
#  'Cheozubil: WICKEG',
#  'Tanazoli: !song',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3",
#  'Madzen8: COPIUM',
#  'sh0cklife: dity 2Header',
#  'crowtor: You fell next to that bed before',
#  'GGitWasMeSmile: LOLW',
#  'SheepFarmer: 🔊 VIBE Mark Sixma - Decibels',
#  'QUOTE_ME_IF_DOCLEAVE: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN .',
#  'fredstep: peepoIronman you should spend some time in practice mode hitting creeps. its seriously embarrassing',
#  'crack_sparrow77: COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP COME HOME peepoIronman HYPERCLAP',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3",
#  'Welcome to the chat room!',
#  'bombey01: COPIUM',
#  'cheesedfrog: you didnt',
#  'FuzzTheDice: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive',
#  'Jacusi69: GAMING',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69",
#  'poenjoyer: COPIUM',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'エーギル (tamate): ',
#  'fredstep: peepoIronman you should spend some time in practice mode hitting creeps. its seriously embarrassing \U000e0000',
#  'Combikorm: WhoAsked',
# ...
#  'kickbackxxx: 2Header',
#  'dabeezneez11: REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman',
#  'internetcelebrity: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN',
#  'mastaz: wass key',
#  'GetJjuiced: 22222222222222',
#  "KerguhlGames: @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69 peepoIronman There's more than 3 @Quin69",
#  'jakethecleaner: !song',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'FuzzTheDice: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive',
#  'shitsack42: was keys',
#  'Meneertje: WASS \U000e0000',
#  'LegitDead: @Quin69 Did you beat it?',
#  'dabeezneez11: REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman REDEMPTION peepoIronman',
#  'fx_fiexible_: peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR peepoIronman HYPERCLAP LOL VR',
#  'knottsogood: WASDing',
#  'Sheshantol: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUINj',
#  'sh0cklife: wadin 2Header',
#  'kitsou_: peepoIronman',
#  'sjampiee: wet ass pussy keys',
#  'Welcome to the chat room!',
#  'Shnup: forsenCD',
#  'Raeydor: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive',
#  'セリ (seri_): GIGACHAD',
#  'HitM4chin3: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive x',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'TeknoHamster: peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK QUIN peepoIronman COME BACK',
#  'maggggus: forsenCD',
#  'Sedlostroy: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive',
#  'HitM4chin3: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive',
#  'zeek_ca: PainChamp slowmo samuel',
#  'johnyoakman: I took some laxatives and couldn’t make it to the toilet, now I have to steam clean the carpet',
#  'cloakheart: COPIUM',
#  'Talamowut: female quin69 as a busty succubus in skimpy outfit short skirt bending over thick',
#  'Replying to @DizzierDizzi: holy fuck forgot this speedrunner was a streamer till he spoke, how fucking boring is this guyNjord__: Baseg',
#  'FuzzTheDice: FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive FINISH TERRARIA docArrive \U000e0000',
#  'knottsogood: Madge',
#  'dimmitsaras: quin are you imitating sssniperwolf on the commentary or what',
#  'Welcome to the chat room!',
#  'icedfierytree: PepeLa this part',
#  'bladdes_00: the one who made the run in less than a minute ',
#  'shizzlemahdizzle: he did',
#  'sendayo: forsenCD simple',
#  'maggggus: EZ',
#  'poenjoyer: he did',
#  'awesomesauce251: forsenCD \U000e0000',
#  'MurderManPsycho: forsenCD',
#  'Kithe__: forsenCD QOL',
#  'WunchleR: forsenCD',
#  'Welcome to the chat room!',
#  'sh0cklife: LOLW',
#  'bombey01: quinCD \U000e0000',
#  'w0kege: OMEGALUL',
#  'lastofherkind: ethical',
#  'poenjoyer: forsenCD',
#  'SparkyChe: hackerCD',
#  'EXE121: forsenCD',
#  'Lavastar46: HUH',
#  'SuitedConnector: literal bug abuse ICANT literal bug abuse ICANT literal bug abuse ICANT literal bug abuse ICANT literal bug abuse ICANT',
#  'doug_as: forsenCD',
#  'sapatoor: WTFF',
#  'doge45: forsenCD',
#  'shitsack42: forsenCD',
#  'EvoXTalhante: LOLW',
#  'Talamowut: quin69 as quasimodo',
#  'Krohnos: forsenCD',
#  'QUOTE_ME_IF_DOCLEAVE: forsenCD',
#  'Bambuskott: LOLW',
#  'WunchleR: forsenCD QOL',
#  'Comitatvs: forsenCD',
#  'bladdes_00: slow mode on slow mode ',
#  'DirtyUsername: forsenCD',
#  'maggggus: forsenCD',
#  'pcgenjin: 5Head',
#  'wtfblub: frame perfect forsenCD',
#  'Welcome to the chat room!',
#  'z241_: LOLW',
#  'queenofshwords:      ',
#  'SuitedConnector: LOLW',
#  'Kithe__: PepeLa VALID',
#  'mr_klint: LOLW',
#  'Proto555: LOLW',
#  'afloat666: ',
#  'halloFicki: LOLW \U000e0000',
#  'FarD0x: BatChesting ASMON REACTS',
#  'AllLucky7s: OMEGALUL',
#  'WyvernU: LOLW',
#  'Mabukboy: LOLW',
#  'Audio724: LOLW',
#  'MultiClowW: LOLW',
#  'flipflapflopflipperflaps: LOLW',
#  'notclariity: LOLW',
#  'Ballsonfire_: LOLW',
#  'Petitbasile: LOLW \U000e0000',
#  'chocopainwastaken: that got fixed',
#  'Fareu5: HUH',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN.',
#  'Slotheus_: 2TIME',
#  'SanguineOD: LOLW \U000e0000',
#  "Xhyoaughn: @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW",
#  'bigmmoenjoyer: message deleted by a moderator.',
#  'iNstABuliTaH01: all of them are hard and you would never pull this off in a 100 years LOLW',
#  'norindu: ',
#  'TheLey95: PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp',
#  'Comitatvs: 2TIME',
#  'dredaan: forsenCD \U000e0000',
#  'FarD0x: BatChesting ASMON REACTS \U000e0000',
#  'poenjoyer: LOLW \U000e0000',
#  'LittleEX: LOLW',
#  'oMarquis: LOLW',
#  'GennPen: forsenCD VALID',
#  '625th: LOLW Asmon react',
#  'Welcome to the chat room!',
#  'pootietrain: OMEGALUL',
#  'lidrix0: the boat skip is teh hardest',
#  'ogpurpledaddy: LOLW',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN',
#  'Proc1: @Quin69 Boat is harder',
#  'Talamowut: anime style quin69 as one punch man',
#  'Lavastar46: LOLW',
#  'FeRust: We are all 0/7 YEP',
#  'SNIFFAxdd: use the website',
#  'nuudelz: docArrive WOW HC docArrive WOW HC docArrive WOW HC',
#  'NickNeem: Shrugeg who even cares about this assetflip run anyways',
#  'poenjoyer: LOLW',
#  'buggfesst: LOLW',
#  'eagleswintwitch: LOLW',
#  'Aeala: GIGACHAD',
#  'mara_Smug: LOLW',
#  'xxx_gigamilkbagman420_xxx: hall of torment ?',
#  'Xandr_Nekomata: BOAT WAS HARD',
#  'bilaros444: barabara',
#  'z241_: LOLW',
#  'queenofshwords:      ',
#  'SuitedConnector: LOLW',
#  'Kithe__: PepeLa VALID',
#  'mr_klint: LOLW',
#  'Proto555: LOLW',
#  'afloat666: ',
#  'halloFicki: LOLW \U000e0000',
#  'FarD0x: BatChesting ASMON REACTS',
#  'AllLucky7s: OMEGALUL',
#  'WyvernU: LOLW',
#  'Mabukboy: LOLW',
#  'Audio724: LOLW',
#  'MultiClowW: LOLW',
#  'flipflapflopflipperflaps: LOLW',
#  'notclariity: LOLW',
#  'Ballsonfire_: LOLW',
#  'Petitbasile: LOLW \U000e0000',
#  'chocopainwastaken: that got fixed',
#  'Fareu5: HUH',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN.',
#  'Slotheus_: 2TIME',
#  'SanguineOD: LOLW \U000e0000',
#  "Xhyoaughn: @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW",
#  'bigmmoenjoyer: message deleted by a moderator.',
#  'iNstABuliTaH01: all of them are hard and you would never pull this off in a 100 years LOLW',
#  'norindu: ',
#  'TheLey95: PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp',
#  'Comitatvs: 2TIME',
#  'dredaan: forsenCD \U000e0000',
#  'FarD0x: BatChesting ASMON REACTS \U000e0000',
#  'poenjoyer: LOLW \U000e0000',
#  'LittleEX: LOLW',
#  'oMarquis: LOLW',
#  'GennPen: forsenCD VALID',
#  '625th: LOLW Asmon react',
#  'Sallekk: lol',
#  'RaunoRepomies: LOLW',
#  'dimmitsaras: its called any%',
#  'moneen_: in pain ',
#  'Welcome to the chat room!',
#  'mara_Smug: LOLW',
#  'xxx_gigamilkbagman420_xxx: hall of torment ?',
#  'Xandr_Nekomata: BOAT WAS HARD',
#  'bilaros444: barabara',
#  'z241_: LOLW',
#  'queenofshwords:      ',
#  'SuitedConnector: LOLW',
#  'Kithe__: PepeLa VALID',
#  'mr_klint: LOLW',
#  'Proto555: LOLW',
#  'afloat666: ',
#  'halloFicki: LOLW \U000e0000',
#  'FarD0x: BatChesting ASMON REACTS',
#  'AllLucky7s: OMEGALUL',
#  'WyvernU: LOLW',
#  'Mabukboy: LOLW',
#  'Audio724: LOLW',
#  'MultiClowW: LOLW',
#  'flipflapflopflipperflaps: LOLW',
#  'notclariity: LOLW',
#  'Ballsonfire_: LOLW',
#  'Petitbasile: LOLW \U000e0000',
#  'chocopainwastaken: that got fixed',
#  'Fareu5: HUH',
#  'djsempai: peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN peepoIronman ITS TIME QUIN.',
#  'Slotheus_: 2TIME',
#  'SanguineOD: LOLW \U000e0000',
#  "Xhyoaughn: @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW @Quin69 there's a 4 second WR LOLW",
#  'bigmmoenjoyer: message deleted by a moderator.',
#  'iNstABuliTaH01: all of them are hard and you would never pull this off in a 100 years LOLW',
#  'norindu: ',
#  'TheLey95: PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp PLAY A GAME PainChamp',
#  'Comitatvs: 2TIME',
#  'dredaan: forsenCD \U000e0000',
#  'FarD0x: BatChesting ASMON REACTS \U000e0000',
#  'poenjoyer: LOLW \U000e0000',
#  'LittleEX: LOLW',
#  'oMarquis: LOLW',
#  'GennPen: forsenCD VALID',
#  '625th: LOLW Asmon react',
#  'Sallekk: lol',
#  'RaunoRepomies: LOLW',
#  'dimmitsaras: its called any%',
#  'moneen_: in pain ',
#  'redkrolick: boat is hard',
#  ...]

# %% [markdown]
# # generate some code -> for values that are missing -> genreate UI inputs and fill them in - pizza - CC
#
#
# make a circle in each corner
# make a line connecting each circle
# # english language programming environment
# #generates python + javascript
#
# #program synthesis
# how to generate new programs that werent possible in previous languages
# when netflix stock price goes up by 1% get me a pizza ->
# #run 20 lines of javascript that exectures like 300 lines of javascript
#
#
# for all uber trips in nyc from 2012-2014
# visualize all the dropoffs  - dont have to know what the data structure is, or where its from, or how its plotted
#
#
# #streams filters maps reduces
#
# watch tweets mentioning pizza
# download the meme
#
#
# for all chemical reactions
# find ones which improve synthesis
# add a trait for purple glow in the dark
# add better biofuels for algae
# and then send me an SGRNA kit
#
#
#
# for all twitch comments
# find topics people talk about like win trading
# when win trading comments goes above 5 in an hour -> record the date in a json
#
#
#
#
# for all stars in the sky, find dates when each can be best observed
#
# for all planets in the solar system
# when they are brightest, send me an email
#
#
#
#
#
# find all papers on arxiv relating to astronomy
# find a time series of citations for each one
# find sentence pairs that are close in semantic similarity
# get all diagrams and create one pdf out of 10,000 pdfs
#
#
#
# #remote year + community automation
# consensus based suitability analysis
# :pollData for library, subway and supermarket
# find all apt in sf with noise < .5 complaints per sq mile
# for each apt, find which ones are closest to library, subway and super market
# for each of those, find 5 PoI for tourists that are in 1 hour train distance
# make a schedule from those PoI

# %%
shit
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
#        health                           spc_latin           spc_common  ...  \
# 0        Fair                         Acer rubrum            red maple  ...
# 1        Fair                   Quercus palustris              pin oak  ...
# 2        Good  Gleditsia triacanthos var. inermis          honeylocust  ...
# 3        Good  Gleditsia triacanthos var. inermis          honeylocust  ...
# 4        Good                     Tilia americana      American linden  ...
# ...       ...                                 ...                  ...  ...
# 683783   Good                   Quercus palustris              pin oak  ...
# 683784   Good                 Cladrastis kentukea  Kentucky yellowwood  ...
# 683785   Good                         Acer rubrum            red maple  ...
# 683786   Good                         Acer rubrum            red maple  ...
# 683787   Fair                         Acer rubrum            red maple  ...
#
#         boro_ct     state   latitude  longitude          x_sp         y_sp  \
# 0       4073900  New York  40.723092 -73.844215  1.027431e+06  202756.7687
# 1       4097300  New York  40.794111 -73.818679  1.034456e+06  228644.8374
# 2       3044900  New York  40.717581 -73.936608  1.001823e+06  200716.8913
# 3       3044900  New York  40.713537 -73.934456  1.002420e+06  199244.2531
# 4       3016500  New York  40.666778 -73.975979  9.909138e+05  182202.4260
# ...         ...       ...        ...        ...           ...          ...
# 683783  3051900  New York  40.713211 -73.954944  9.967407e+05  199121.6363
# 683784  4070700  New York  40.715194 -73.856650  1.023989e+06  199873.6475
OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# silver birch            OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# silver linden           OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# silver maple            OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# smoketree               OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# southern magnolia       OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# southern red oak        OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# spruce                  OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOffs...
# sugar maple             OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# swamp white oak         OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOffsetFrom...
# sweetgum                OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# sycamore maple          OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# tartar maple            OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# tree of heaven          OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOffs...
# trident maple           OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# tulip-poplar            OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# two-winged silverbell   OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOffsetFrom...
# weeping willow          OnCurbOnCurbOnCurbOnCurbOnCurbOffsetFromCurbOn...
# white ash               OffsetFromCurbOnCurbOnCurbOnCurbOnCurbOnCurbOn...
# white oak               OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
# white pine              OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOffs...
# willow oak              OnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCurbOnCu...
#
#                                                                    status  \
# spc_common
# 'Schubert' chokecherry  AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# American beech          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# American elm            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# American hophornbeam    AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# American hornbeam       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# American larch          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# American linden         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Amur cork tree          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Amur maackia            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Amur maple              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Atlantic white cedar    AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Atlas cedar             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Callery pear            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Chinese chestnut        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Chinese elm             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Chinese fringetree      AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Chinese tree lilac      AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Cornelian cherry        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Douglas-fir             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# English oak             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# European alder          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# European beech          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# European hornbeam       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Himalayan cedar         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Japanese hornbeam       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Japanese maple          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Japanese snowbell       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Japanese tree lilac     AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Japanese zelkova        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Kentucky coffeetree     AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Kentucky yellowwood     AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# London planetree        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Norway maple            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Norway spruce           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Ohio buckeye            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Oklahoma redbud         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Osage-orange            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Persian ironwood        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Schumard's oak          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Scots pine              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Shantung maple          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Siberian elm            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Sophora                 AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Turkish hazelnut        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# Virginia pine           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# arborvitae              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# ash                     AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# bald cypress            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# bigtooth aspen          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# black cherry            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# black locust            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# black maple             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# black oak               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# black pine              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# black walnut            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# blackgum                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# blue spruce             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# boxelder                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# bur oak                 AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# catalpa                 AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# cherry                  AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# cockspur hawthorn       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# common hackberry        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# crab apple              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# crepe myrtle            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# crimson king maple      AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# cucumber magnolia       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# dawn redwood            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# eastern cottonwood      AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# eastern hemlock         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# eastern redbud          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# eastern redcedar        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# empress tree            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# false cypress           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# flowering dogwood       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# ginkgo                  AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# golden raintree         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# green ash               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# hardy rubber tree       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# hawthorn                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# hedge maple             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# holly                   AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# honeylocust             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# horse chestnut          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# katsura tree            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# kousa dogwood           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# littleleaf linden       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# magnolia                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# maple                   AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# mimosa                  AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# mulberry                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# northern red oak        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pagoda dogwood          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# paper birch             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# paperbark maple         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pignut hickory          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pin oak                 AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pine                    AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pitch pine              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pond cypress            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# purple-leaf plum        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# quaking aspen           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# red horse chestnut      AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# red maple               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# red pine                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# river birch             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# sassafras               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# sawtooth oak            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# scarlet oak             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# serviceberry            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# shingle oak             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# silver birch            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# silver linden           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# silver maple            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# smoketree               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# southern magnolia       AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# southern red oak        AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# spruce                  AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# sugar maple             AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# swamp white oak         AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# sweetgum                AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# sycamore maple          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# tartar maple            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# tree of heaven          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# trident maple           AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# tulip-poplar            AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# two-winged silverbell   AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# weeping willow          AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# white ash               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# white oak               AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# white pine              AliveAliveAliveAliveAliveAliveAliveAliveAliveA...
# pagoda dogwood          1.058431e+09  1.035583e+12
# paper birch             1.919484e+09  1.884937e+12
# paperbark maple         7.630789e+08  7.474376e+11
# pignut hickory          3.769318e+08  3.702149e+11
# pin oak                 1.855528e+11  1.809794e+14
# pine                    1.107147e+09  1.077167e+12
# pitch pine              1.124183e+08  1.095504e+11
# pond cypress            5.577383e+08  5.378644e+11
# purple-leaf plum        2.679739e+10  2.619230e+13
# quaking aspen           3.191596e+08  3.122009e+11
# red horse chestnut      4.562784e+08  4.469391e+11
# red maple               6.985606e+10  6.880148e+13
# red pine                3.881401e+08  3.801252e+11
# river birch             2.120588e+09  2.071354e+12
# sassafras               5.951448e+08  5.830200e+11
# sawtooth oak            6.747242e+09  6.588728e+12
# scarlet oak             4.558155e+09  4.431158e+12
# serviceberry            7.694498e+09  7.522469e+12
# shingle oak             3.068174e+09  2.993537e+12
# silver birch            1.050085e+09  1.026588e+12
# silver linden           2.778320e+10  2.704285e+13
# silver maple            5.128675e+10  5.039166e+13
# smoketree               2.246261e+08  2.188598e+11
# southern magnolia       4.405281e+08  4.303672e+11
# southern red oak        2.941406e+08  2.878472e+11
# spruce                  7.701900e+08  7.521905e+11
# sugar maple             1.076458e+10  1.054617e+13
# swamp white oak         2.125661e+10  2.071367e+13
# sweetgum                4.372966e+10  4.306730e+13
# sycamore maple          1.042761e+10  1.020401e+13
# tartar maple            5.117372e+08  5.031655e+11
# tree of heaven          2.442056e+09  2.374733e+12
# trident maple           4.510368e+08  4.402458e+11
# tulip-poplar            4.118780e+09  4.030390e+12
# two-winged silverbell   8.103377e+08  7.946020e+11
# weeping willow          1.071835e+09  1.045967e+12
# white ash               3.936637e+09  3.840890e+12
# white oak               5.435046e+09  5.308512e+12
# white pine              7.989340e+08  7.805150e+11
# willow oak              8.693127e+09  8.466922e+12
#
# [132 rows x 44 columns]

# %%
df = shit
bins = [0, 10, 20, 30, 40, 50]

df['ValueBin'] = pd.cut(df['spc_common'], bins, labels=['0-10', '11-20', '21-30', '31-40', '41-50'])

# Group by 'Category' and 'ValueBin' and count frequencies
hist_data = df.groupby(['Category', 'ValueBin']).size().reset_index(name='Frequency')

print(hist_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[245], line 4
#       1 df = shit
#       2 bins = [0, 10, 20, 30, 40, 50]
# ----> 4 df['ValueBin'] = pd.cut(df['spc_common'], bins, labels=['0-10', '11-20', '21-30', '31-40', '41-50'])
#       6 # Group by 'Category' and 'ValueBin' and count frequencies
#       7 hist_data = df.groupby(['Category', 'ValueBin']).size().reset_index(name='Frequency')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/tile.py:293, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290     if (np.diff(bins.astype("float64")) < 0).any():
#     291         raise ValueError("bins must increase monotonically.")
# --> 293 fac, bins = _bins_to_cuts(
#     294     x,
#     295     bins,
#     296     right=right,
#     297     labels=labels,
#     298     precision=precision,
#     299     include_lowest=include_lowest,
#     300     dtype=dtype,
#     301     duplicates=duplicates,
#     302     ordered=ordered,
#     303 )
#     305 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/tile.py:428, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     425     bins = unique_bins
#     427 side: Literal["left", "right"] = "left" if right else "right"
# --> 428 ids = ensure_platform_int(bins.searchsorted(x, side=side))
#     430 if include_lowest:
#     431     ids[np.asarray(x) == bins[0]] = 1
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
#only thing that makes sense is to finish a dmeo 

#figure out how to run similar code on different data -> match columns by snyonym and ask user -> are these the same?
#complaint
CSV_PATH = './311_cases.csv'
import subprocess
from tqdm import tqdm
import pandas as pd 
import os
from h3 import h3
import warnings
warnings.filterwarnings('ignore')

def process_date(df_chunk, key):
    df_chunk[key] = df_chunk[key].str.slice(0, 16)
    #df_chunk[key] = pd.to_datetime(df_chunk[key], utc=True, format='%Y-%m-%d %H:%M')

def binRow(df311):
    APERTURE_SIZE = 9
    hex_col = 'hex'+str(APERTURE_SIZE)
    df311[hex_col] = df311.apply(lambda x: h3.geo_to_h3(x.Latitude,x.Longitude,APERTURE_SIZE),1)
    df311g = df311.groupby(hex_col).size()#.to_frame('cnt').reset_index()
    return (df311g)

def saveComplaint(complaint):
    print(complaint)
    data = pdf.loc[pdf['Category'] ==(complaint)]
    binned = binRow(data)
    complaint = complaint.replace(' ', '-').replace('/','-')
    hi = [(hex, count)  for hex,count in binned.to_dict()]
    with open('./data/'+complaint+'.json', 'w') as outfile: json.dump(hi, outfile)
    
stuff = ['Noise - Residential',                         
'HEAT/HOT WATER' ,                              
'Street Condition',                           
'Illegal Parking ',                              
'Blocked Driveway'  ,                            
'Street Light Condition' ,                       
'HEATING'          ,                             
'PLUMBING'     ,                                 
'Water System'  ,                                
'Noise - Street/Sidewalk' ,                      
'GENERAL CONSTRUCTION'  ,                                                                
'UNSANITARY CONDITION']                          
import json
import os
import requests
#get all the airbnb in sf that are not noisy
#getAirbnb() => geocoding mapbox api => lat/lng => h3a9 => lookup in binned table
#address => geocoe => lat/lng => h3a9 => lookup in binned table 


        
ll = geoCode('450 10th St, San Francisco, CA 94103')
h3Cell = h3.geo_to_h3(ll[0], ll[1], 9)
#figure out how to make fast
#one line to say -> find the least noisy airbnb in SF and NYC
#also fast to say -> find the noisiest airbnb in SF and NYC
#plot both on a map 
#in regular python data analysis -> takes 2-3 hours for an experienced dev
#in english -> takes 16 ms -> onkeypress get instant results
#how to cache 311 -> 3gb for sf and 16gb for nyc -> cant cache on browser
#h3_cells for noise column =
#100ms is probably fine for onKeyPress RPC

#poll = sf, houston, kansas
#get all airbnb in poll.1 if not noisy and near pizza
#AllAirbnbInCityFilteredNoise('sf')
def make_pandas_data_frame():
    print (f'Exact number of rows: {n_rows}')
    df_tmp = pd.read_csv(CSV_PATH, nrows=5)
    df_tmp.head()


    types = {'Category': 'category', 
                  'Longitude': 'float32',
                  'Latitude': 'float32',
            }
    cols = list(types.keys())
    chunksize = 5_000_000

    df_list = [] # list to hold the batch dataframe
    for df_chunk in tqdm(pd.read_csv(CSV_PATH, usecols=cols, dtype=types, chunksize=chunksize)):
        df_list.append(df_chunk) 
    pdf = pd.concat(df_list)
    filtered_df = pdf[(pdf['Latitude'] != 0) & (pdf['Longitude'] != 0)]
    pdf = filtered_df
    del df_list

    APERTURE_SIZE = 9
    hex_col = 'hex'+str(APERTURE_SIZE)
    pdf[hex_col] = 0
    return pdf

def getNoisyCells():
    fp = './data/sf-noise-regions.csv'
    if os.path.isfile(fp):
        print('cached')
        return json.loads(open(fp).read())
    pdf = make_pandas_data_frame()
    data = pdf.loc[pdf['Category'] ==('Noise Report')]
    binned = binRow(data)
    with open(fp, 'w') as f:
        f.write(binned.to_json())
    return binned
getNoisyCells()

def meanDict(_): return sum([_[v] for v in _.keys()]) / len(_)


def isNoisy(nc, apt):
    #latlong = geoCode(addr)
    h3Cell = h3.geo_to_h3(apt['latitude'], apt['longitude'], 9) #.1 square kilometers
    return nc[h3Cell] < meanDict(nc)


def getAirbnbForCity():
    df = pd.read_csv('./data/sf_airbnb.csv')
    airbnb = df[['latitude', 'longitude', 'id', 'listing_url']].to_dict('records')
    return airbnb

def getAllAirbnbInCityThatAreNotNoisy(LTorGT):
    from collections import defaultdict
    all_airbnb = getAirbnbForCity() #make this get for different cities 
    nc = defaultdict(int, getNoisyCells())
    mean = meanDict(nc)
    filtered = [apt for apt in all_airbnb if 
                isNoisy(nc, apt) == LTorGT
                #nc[h3.geo_to_h3(apt['latitude'], apt['longitude'],9)] < mean
               ]
    listing_url = [apt['listing_url'] for apt in filtered]
    return listing_url

one= getAllAirbnbInCityThatAreNotNoisy()
two = airbnb
#one
one
# Out:
# cached
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 148
#     145     listing_url = [apt['listing_url'] for apt in filtered]
#     146     return listing_url
# --> 148 one= getAllAirbnbInCityThatAreNotNoisy()
#     149 two = airbnb
#     150 #one
#
# TypeError: getAllAirbnbInCityThatAreNotNoisy() missing 1 required positional argument: 'LTorGT'

# %%
'airbnb' in 'find all airbnb that are not noisy and are near a yoga studio'
# Out:
# True

# %%
# with open('./asdf.txt', 'w') as f:
#     json.dump(dict(binned), f)
from collections import defaultdict
#json.loads(getNoisyCells())
#meanDict(getNoisyCells())
# Out:
# cached

# %%
data = pdf.loc[pdf['Category'] ==('Noise Report')]
binned = binRow(data)
# with open(fp, 'w') as f:
#     json.dump(binned.to_csv(), f)
#dict(binned)

binned
# Out:
# hex9
# 89283080c83ffff      8
# 89283080c87ffff     23
# 89283080c8fffff      1
# 89283080c93ffff     74
# 89283080c97ffff     69
# 89283080c9bffff      2
# 89283080ca3ffff     27
# 89283080ca7ffff     14
# 89283080cafffff      1
# 89283080cb3ffff     47
# 89283080cb7ffff     55
# 89283080cbbffff     30
# 89283080d93ffff     39
# 89283080d97ffff      2
# 89283080d9bffff      6
# 89283080dd3ffff     11
# 89283080dd7ffff     90
# 89283080ddbffff      1
# 89283080e07ffff      1
# 89283080e0fffff      4
# 89283080e13ffff      2
# 89283080e23ffff      1
# 89283080e2bffff      9
# 89283080e3bffff      6
# 89283080e77ffff      4
# 89283082003ffff      1
# 89283082013ffff      1
# 89283082017ffff      6
# 89283082027ffff      1
# 8928308202fffff      1
# 8928308208bffff      7
# 8928308208fffff     56
# 89283082093ffff      1
# 89283082097ffff      1
# 892830820a3ffff      5
# 89283095c2bffff      9
# 89283095c2fffff     12
# 89283095c33ffff     11
# 89283095c37ffff     22
# 89283095c3bffff      8
# 89283095c43ffff      6
# 89283095c47ffff      8
# 89283095c4bffff      9
# 89283095c4fffff     12
# 89283095c53ffff      7
# 89283095c57ffff      8
# 89283095c5bffff      5
# 89283095c63ffff     21
# 89283095c67ffff      6
# 89283095c6bffff     16
# 89283095c6fffff     13
# 89283095c73ffff     15
# 89283095c77ffff     16
# 89283095c7bffff     31
# 89283095c8fffff      1
# 89283095cabffff      4
# 89283095cafffff      8
# 89283095cb7ffff      1
# 89283095cbbffff      5
# 89283095ccbffff      2
# 89283095ccfffff     17
# 89283095cdbffff     10
# 89283095d43ffff     12
# 89283095d47ffff      5
# 89283095d4bffff     18
# 89283095d4fffff      4
# 89283095d53ffff     29
# 89283095d57ffff     29
# 89283095d5bffff     15
# 89283095d6bffff     11
# 89283095d73ffff      1
# 89283095d7bffff     11
# 89283095dc3ffff     10
# 89283095dcbffff     10
# 89283095dcfffff      3
# 89283095dd3ffff      9
# 89283095ddbffff     15
# 89283095e03ffff      7
# 89283095e07ffff      5
# 89283095e0bffff      5
# 89283095e0fffff     16
# 89283095e13ffff      3
# 89283095e17ffff      8
# 89283095e1bffff      3
# 89283095e23ffff      7
# 89283095e27ffff     25
# 89283095e2bffff      9
# 89283095e2fffff      4
# 89283095e33ffff      9
# 89283095e37ffff      9
# 89283095e3bffff      3
# 89283095e43ffff      4
# 89283095e4bffff      3
# 89283095e4fffff      9
# 89283095e53ffff      4
# 89283095e57ffff      5
# 89283095e63ffff      5
# 89283095e67ffff     38
# 89283095e6fffff     31
# 89283095e73ffff      2
# 89283095e77ffff     26
# 89283095e7bffff      4
# 89283095e83ffff     21
# 89283095e87ffff      4
# 89283095e8bffff     16
# 89283095e8fffff      9
# 89283095e93ffff      6
# 89283095e97ffff      2
# 89283095e9bffff      1
# 89283095ea3ffff     13
# 89283095ea7ffff      4
# 89283095eabffff      7
# 89283095eafffff      8
# 89283095eb3ffff     35
# 89283095eb7ffff     36
# 89283095ebbffff     16
# 89283095ec3ffff      6
# 89283095ec7ffff      4
# 89283095ecbffff      9
# 89283095ecfffff      4
# 89283095ed3ffff      4
# 89283095ed7ffff      3
# 89283095edbffff      9
# dtype: int64

# %%
import csv
# with open('./data/sf_airbnb.csv', newline='') as csvfile:
#     #csvreader = csv.(csvfile, delimiter=' ', quotechar='|')
#     for k in csvfile:
#         print(k)
        
        
import pandas as pd

# Load a CSV file into a DataFrame

# Show the DataFrame

df.columns.tolist() #street, city, state, szpcode


df.latitude
df.longitude
df.id



df[['latitude', 'longitude', 'id']]

# Convert the DataFrame to a list of dictionaries
#list_of_dicts = filtered_df.to_dict('records')
#convert df to {latitude: _, longitude: _, listing_id}
#find a list of airbnb that are not noisy -> get a list of links back + a data browser
#df.columns.tolist()

def approxMatch(one, two):
    #get all synonyms for one and two
    return set(one + two)

# %%
#saveComplaint('Noise Report')

with open('complaint.csv', 'w') as file:
    file.write(nc.to_csv())
